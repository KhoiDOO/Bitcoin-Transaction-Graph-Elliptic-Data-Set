# %%
# Data Manipulation and Representation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import networkx as nx
import json
import pickle

# Mathematics
from random import randint
import math 
import time
from datetime import datetime

# Training Implementation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
import joblib

# Validation Implementation
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Data Preparation

# %%
main_data_dir = "D:/GitCloneProject/Bitcoin-Transaction-Graph-Elliptic-Data-Set/Data/Elliptic Data Set/elliptic_bitcoin_dataset"
features_data_path = main_data_dir + "/elliptic_txs_features.csv"
class_data_path = main_data_dir + "/elliptic_txs_classes.csv"
egdelist_data_path = main_data_dir + "/elliptic_txs_edgelist.csv"

# %%
features_df = pd.read_csv(features_data_path)
classes_df = pd.read_csv(class_data_path)
edges_df = pd.read_csv(egdelist_data_path)

# %%
features_df.head()
# Out:
#    txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  1076         48        -0.168500         0.270909        -0.091383
# 1  2534          6        -0.170834        -0.131425         1.018602
# 2  3181         34         1.305212        -0.210553        -1.756361
# 3  3321          1        -0.169615        -0.184668        -1.201369
# 4  3889         48        -0.086232        -0.101835        -0.646376
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.046932        -0.043875        -0.029140        -0.061584
# 1         0.028105         0.055376         0.054722        -0.061584
# 2        -0.121970        97.300650        -0.113002        -0.061584
# 3        -0.121970        -0.043875        -0.113002        -0.061584
# 4        -0.121970        17.046997        -0.113002        -0.061584
#
#    Local_feature_8  ...  Aggregate_feature_63  Aggregate_feature_64  \
# 0        -0.163591  ...              0.073047             -0.039637
# 1        -0.163572  ...              1.228858              0.379357
# 2         1.348765  ...              1.348450              1.590664
# 3        -0.160199  ...             -0.577099             -0.500080
# 4        -0.074885  ...              0.501062              0.362510
#
#    Aggregate_feature_65  Aggregate_feature_66  Aggregate_feature_67  \
# 0              1.461330              1.461369              0.018279
# 1              0.955101              0.459257             -0.098889
# 2              0.059948              0.113967             -0.098889
# 3              0.241128              0.241406             -0.098889
# 4              0.082065              0.114773             -0.098889
#
#    Aggregate_feature_68  Aggregate_feature_69  Aggregate_feature_70  \
# 0              0.470019              1.216796              1.151607
# 1             -0.087490             -0.099080             -0.122137
# 2              1.969527              0.037532             -0.131010
# 3             -0.087490             -0.084674             -0.140597
# 4              8.948005              1.024948             -0.009570
#
#    Aggregate_feature_71  Aggregate_feature_72
# 0              1.519700              1.521399
# 1             -0.379970             -0.379288
# 2              0.006994              0.017772
# 3              1.519700              1.521399
# 4             -0.080708             -0.123601
#
# [5 rows x 167 columns]

# %%
classes_df.head()
# Out:
#    txId  class
# 0  1076      3
# 1  2534      2
# 2  3181      2
# 3  3321      3
# 4  3889      3

# %%
edges_df.head()
# Out:
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %%
df_class_feature = pd.merge(classes_df, features_df)
df_class_feature.head()
# Out:
#    txId  class  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  1076      3         48        -0.168500         0.270909        -0.091383
# 1  2534      2          6        -0.170834        -0.131425         1.018602
# 2  3181      2         34         1.305212        -0.210553        -1.756361
# 3  3321      3          1        -0.169615        -0.184668        -1.201369
# 4  3889      3         48        -0.086232        -0.101835        -0.646376
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  ...  \
# 0        -0.046932        -0.043875        -0.029140        -0.061584  ...
# 1         0.028105         0.055376         0.054722        -0.061584  ...
# 2        -0.121970        97.300650        -0.113002        -0.061584  ...
# 3        -0.121970        -0.043875        -0.113002        -0.061584  ...
# 4        -0.121970        17.046997        -0.113002        -0.061584  ...
#
#    Aggregate_feature_63  Aggregate_feature_64  Aggregate_feature_65  \
# 0              0.073047             -0.039637              1.461330
# 1              1.228858              0.379357              0.955101
# 2              1.348450              1.590664              0.059948
# 3             -0.577099             -0.500080              0.241128
# 4              0.501062              0.362510              0.082065
#
#    Aggregate_feature_66  Aggregate_feature_67  Aggregate_feature_68  \
# 0              1.461369              0.018279              0.470019
# 1              0.459257             -0.098889             -0.087490
# 2              0.113967             -0.098889              1.969527
# 3              0.241406             -0.098889             -0.087490
# 4              0.114773             -0.098889              8.948005
#
#    Aggregate_feature_69  Aggregate_feature_70  Aggregate_feature_71  \
# 0              1.216796              1.151607              1.519700
# 1             -0.099080             -0.122137             -0.379970
# 2              0.037532             -0.131010              0.006994
# 3             -0.084674             -0.140597              1.519700
# 4              1.024948             -0.009570             -0.080708
#
#    Aggregate_feature_72
# 0              1.521399
# 1             -0.379288
# 2              0.017772
# 3              1.521399
# 4             -0.123601
#
# [5 rows x 168 columns]

# %%
selected_ids = df_class_feature.loc[(df_class_feature['class'] != 3), 'txId']
df_edges_selected = edges_df.loc[edges_df['txId1'].isin(selected_ids)]
df_classes_selected = classes_df.loc[classes_df['txId'].isin(selected_ids)]
df_features_selected = features_df.loc[features_df['txId'].isin(selected_ids)]

# Merge Class and features
df_class_feature_selected = pd.merge(df_classes_selected, df_features_selected )
df_class_feature_selected.head()
# Out:
#    txId  class  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  2534      2          6        -0.170834        -0.131425         1.018602
# 1  3181      2         34         1.305212        -0.210553        -1.756361
# 2  6418      2         48        -0.125229         7.538599         2.128587
# 3  7952      2         48         0.967162        -0.210553        -1.756361
# 4  9351      2         48        -0.172970        -0.114281         1.018602
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  ...  \
# 0         0.028105         0.055376         0.054722        -0.061584  ...
# 1        -0.121970        97.300650        -0.113002        -0.061584  ...
# 2         7.381781         0.095076         7.602324         0.547008  ...
# 3        -0.121970        92.556494        -0.113002        -0.061584  ...
# 4        -0.121970        -0.043875        -0.113002        -0.061584  ...
#
#    Aggregate_feature_63  Aggregate_feature_64  Aggregate_feature_65  \
# 0              1.228858              0.379357              0.955101
# 1              1.348450              1.590664              0.059948
# 2              0.433960              0.168508             -0.197237
# 3              0.823581              0.850443              0.321431
# 4             -0.569626              0.641566              1.461330
#
#    Aggregate_feature_66  Aggregate_feature_67  Aggregate_feature_68  \
# 0              0.459257             -0.098889             -0.087490
# 1              0.113967             -0.098889              1.969527
# 2              0.303447             -0.098889              0.931406
# 3              0.268810             -0.098889              1.162100
# 4              1.461369             -0.098889              0.662264
#
#    Aggregate_feature_69  Aggregate_feature_70  Aggregate_feature_71  \
# 0             -0.099080             -0.122137             -0.379970
# 1              0.037532             -0.131010              0.006994
# 2              1.041565              0.371499              0.790060
# 3              0.485146              0.303509             -0.553520
# 4              1.728088              1.539269              1.519700
#
#    Aggregate_feature_72
# 0             -0.379288
# 1              0.017772
# 2              0.779125
# 3             -0.578865
# 4              1.521399
#
# [5 rows x 168 columns]

# %%
X = df_class_feature_selected.drop(columns=['txId', 'class', 'Time step']) # drop class, text id and time step
y = df_class_feature_selected[['class']]
print(np.unique(y))

# in this case, class 2 corresponds to licit transactions, we chang this to 0 as our interest is the ilicit transactions
y = y['class'].apply(lambda x: 0 if x == 2 else 1 )
print(np.unique(y))
# Out:
# [1 2]
# [0 1]

# %%
print("Feature Shape: ", X.shape)
print("Label Shape: ", y.shape)
# Out:
# Feature Shape:  (46564, 165)
# Label Shape:  (46564,)

# %% [markdown]
# # Utils

# %%
class utils:
    def __init__(self, confusion_matrix, y_true, y_pred):
        """
            - confusion_matrix: 2x2 numpy array
            - y_true: array of label
            - y_pred: array of output value calculated by model
            - fold_count: number of folds
        """
        
        # Initilize all indicator
        self.TP = confusion_matrix[0][0] # true positive
        self.FN = confusion_matrix[1][0] # false negative
        self.FP = confusion_matrix[1][0] # false positive
        self.TN = confusion_matrix[1][1] # true negative
        self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
        self.recall = self.TP / (self.TP + self.FN)
        self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
        self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
        self.specificity = self.TN / (self.TN + self.FP) # False Positive Rate
        self.negative_predictive_value = self.TN / (self.TN + self.FN) # Negative Predictive Value
        self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
        self.false_positive_rate = self.FP / (self.FP + self.TN) # False Positive Rate
        self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
        self.false_omission_rate = self.FN / (self.FN + self.TN) # False Ommision Rate
        self.positive_likelihood_ratio = self.sensitivity / self.false_positive_rate # Positive Likelihood Ratio
        self.negative_likelihood_ratio = self.false_negative_rate / self.specificity # Negative Likelihood Ratio
        self.prevalence_threshold = math.sqrt(self.false_positive_rate) / (math.sqrt(self.sensitivity) + 
                                                                      math.sqrt(self.false_positive_rate)) # Prevalance Threshold
        self.threat_score = self.TP / (self.TN + self.FN + self.FP) # Threat Score
        self.prevalence = (self.TP + self.FN)/(self.TP + self.FN + self.TN + self.FP) # Prevalance 
        #  Matthews correlation coefficient
        self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
                                                                                       *(self.TP + self.FN)
                                                                                       *(self.TN + self.FP)
                                                                                       *(self.TN + self.FN))
        self.fowlkes_mallows_index = math.sqrt(self.sensitivity + self.precision) # Fowlkes–Mallows index
        self.informedness = self.sensitivity + self.specificity - 1 # informedness
        self.markedness = self.precision + self.negative_predictive_value - 1 # markedness
        self.diagnostic_odds_ratio = self.positive_likelihood_ratio / self.negative_likelihood_ratio # Diagnostic odds ratio
        self.accuracy = (self.TP + self.TN) / (self.TP + self.TN + self.FP + self.FN)
        self.balanced_accuracy = (self.sensitivity + self.specificity) / 2
        self.roc_auc_macro = roc_auc_score(y_true, y_pred)
        self.roc_auc_micro = roc_auc_score(y_true, y_pred, average = 'micro')
        self.roc_auc_weighted = roc_auc_score(y_true, y_pred, average = 'weighted')
        self.cls_report = classification_report(y_true, y_pred)
        
        # Initilize the structure of output_dicts
        self.confusion_matrix = {
            "TP" : self.TP,
            "TN" : self.TN,
            "FN" : self.FN,
            "FP" : self.FP,
            "precision" : self.precision,
            "recall" : self.recall,
            "f1_score" : self.f1_score,
            "sensitivity" : self.sensitivity,
            "specificity" : self.specificity,
            "negative_predictive_value" : self.negative_predictive_value,
            "false_negative_rate" : self.false_negative_rate,
            "false_positive_rate" : self.false_positive_rate,
            "false_discovery_rate" : self.false_discovery_rate,
            "false_omission_rate" : self.false_omission_rate,
            "Positive_likelihood_ratio" : self.positive_likelihood_ratio,
            "Negative_likelihood_ratio" : self.negative_likelihood_ratio,
            "prevalence_threshold" : self.prevalence_threshold,
            "threat_score" : self.threat_score,
            "Prevalence" : self.prevalence,
            "Matthews_correlation_coefficient" : self.matthews_correlation_coefficient,
            "Fowlkes_Mallows_index" : self.fowlkes_mallows_index,
            "informedness" : self.informedness,
            "markedness" : self.markedness,
            "Diagnostic_odds_ratio" : self.diagnostic_odds_ratio,
            "accuracy" : self.accuracy,
            "balanced_accuracy" : self.balanced_accuracy
        }
        
        self.roc_auc_score = {
            "Macro": self.roc_auc_macro, 
            "Micro": self.roc_auc_micro,
            "Weight": self.roc_auc_weighted
        }
        
        self.sub_dict = {
            "Confusion Matrix" : self.confusion_matrix,
            "ROC_AUC_SCORE" : self.roc_auc_score,
            "Classification Report" : classification_report(y_true.tolist(), y_pred.tolist(), 
                                                            labels = [0, 1], # 0 : Licit, 1 : Illicit
                                                            output_dict = True)
        }
    def get_value(self):
        return self.sub_dict
        
# Test 
y_true = np.array([randint(0,1) for x in range(200)])
y_pred = np.array([randint(0,1) for x in range(200)])
confusion_matrix_test = confusion_matrix(y_true, y_pred)
base_utils = utils(confusion_matrix_test, y_true, y_pred)
base_utils.get_value()
# Out:
# {'Confusion Matrix': {'TP': 56,
#   'TN': 57,
#   'FN': 44,
#   'FP': 44,
#   'precision': 0.56,
#   'recall': 0.56,
#   'f1_score': 0.56,
#   'sensitivity': 0.56,
#   'specificity': 0.5643564356435643,
#   'negative_predictive_value': 0.5643564356435643,
#   'false_negative_rate': 0.44,
#   'false_positive_rate': 0.43564356435643564,
#   'false_discovery_rate': 0.44,
#   'false_omission_rate': 0.43564356435643564,
#   'Positive_likelihood_ratio': 1.2854545454545456,
#   'Negative_likelihood_ratio': 0.7796491228070176,
#   'prevalence_threshold': 0.4686521223219714,
#   'threat_score': 0.38620689655172413,
#   'Prevalence': 0.4975124378109453,
#   'Matthews_correlation_coefficient': 1.2312518380550926e-05,
#   'Fowlkes_Mallows_index': 1.0583005244258363,
#   'informedness': 0.12435643564356447,
#   'markedness': 0.12435643564356447,
#   'Diagnostic_odds_ratio': 1.6487603305785126,
#   'accuracy': 0.5621890547263682,
#   'balanced_accuracy': 0.5621782178217822},
#  'ROC_AUC_SCORE': {'Macro': 0.5650065006500651,
#   'Micro': 0.5650065006500651,
#   'Weight': 0.5650065006500651},
#  'Classification Report': {'0': {'precision': 0.56,
#    'recall': 0.5656565656565656,
#    'f1-score': 0.5628140703517588,
#    'support': 99},
#   '1': {'precision': 0.57,
#    'recall': 0.5643564356435643,
#    'f1-score': 0.5671641791044776,
#    'support': 101},
#   'accuracy': 0.565,
#   'macro avg': {'precision': 0.565,
#    'recall': 0.565006500650065,
#    'f1-score': 0.5649891247281182,
#    'support': 200},
#   'weighted avg': {'precision': 0.5650499999999999,
#    'recall': 0.565,
#    'f1-score': 0.5650108752718818,
#    'support': 200}}}

# %% [markdown]
# # Training

# %%
class Training:
    def __init__(self, fold_count, X, y):
        self.fold_count = fold_count
        self.param_grid = {
            "penalty" : ["l2"],
            "fit_intercept" : [True, False],
            "class_weight" : ["balanced", None],
            "solver" : ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
        }
        self.kf = KFold(n_splits=fold_count)
        self.history = {}
        self.X = X
        self.y = y
    
    def get_fold_value(self):
        return self.kf        
        
    def training(self, penalty, fit_intercept, class_weight, solver, njob, train_case):
    
        # output_dict initilize
        output_dict = {}
    
        # poiter track the index of fold
        fold_index = 0
    
        for train_index, test_index in self.kf.split(self.X):
            print("\tFold: {}".format(fold_index))
            print("\tTRAIN:", train_index, "\n\tTEST:", test_index)
        
            # folding data
            X_train, X_test = self.X.values[train_index], self.X.values[test_index]
            y_train, y_test = self.y.values[train_index], self.y.values[test_index]
    
            # Training
            print("\t\tTraining : {}".format(fold_index), end = " -- ")
            print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end=" --- ")
            model_LR = LogisticRegression(penalty = penalty,
                                         fit_intercept = fit_intercept,
                                         class_weight = class_weight,
                                          n_jobs = njob)
            model_LR.fit(X_train,y_train)
            print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Testing
            print("\t\tValidation: {}".format(fold_index), end = " -- ")
            print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end="---")
            y_pred = model_LR.predict(X_test)
            print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Evaluation
            cm = confusion_matrix(y_test, y_pred)
            current_utils = utils(cm, y_test, y_pred)
            output_dict["fold_{}".format(fold_index)] = current_utils.get_value()
            
            fold_index += 1
        print("\n")
        return output_dict 
    
    def train(self, path):
        count = 0
        for x in self.param_grid["penalty"]:
            for i in self.param_grid["fit_intercept"]:
                for j in self.param_grid["class_weight"]:
                    for k in self.param_grid["solver"]:
                        print("Traning Case: {}".format(count))
                        self.history["train_{}".format(count)] = {
                            "param" : {
                                "penalty" : x,
                                "fit_intercept" : i,
                                "class_weight" : j,
                                "solver" : k,
                            },
                            "train_fold" : self.training(x, i, j, k, 5, count)
                        }
                        count += 1
        with open(path, 'wb') as f:
            pickle.dump(train.history, f)
        
        return self.history

# %%
path = 'LR_AF.pkl'
train = Training(5, X, y)
history = train.train(path)
# Out:
# Traning Case: 0
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:24:54 --- End: 08/06/2022, 18:25:03
# 		Validation: 0 -- Start: 08/06/2022, 18:25:03---End: 08/06/2022, 18:25:03
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:25:03 --- End: 08/06/2022, 18:25:13
# 		Validation: 1 -- Start: 08/06/2022, 18:25:13---End: 08/06/2022, 18:25:13
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:25:13 --- End: 08/06/2022, 18:25:24
# 		Validation: 2 -- Start: 08/06/2022, 18:25:24---End: 08/06/2022, 18:25:24
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:25:24 --- End: 08/06/2022, 18:25:31
# 		Validation: 3 -- Start: 08/06/2022, 18:25:31---End: 08/06/2022, 18:25:31
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:25:32 --- End: 08/06/2022, 18:25:39
# 		Validation: 4 -- Start: 08/06/2022, 18:25:39---End: 08/06/2022, 18:25:39
#
#
# Traning Case: 1
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:25:39 --- End: 08/06/2022, 18:25:48
# 		Validation: 0 -- Start: 08/06/2022, 18:25:48---End: 08/06/2022, 18:25:48
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:25:48 --- End: 08/06/2022, 18:25:57
# 		Validation: 1 -- Start: 08/06/2022, 18:25:57---End: 08/06/2022, 18:25:57
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:25:57 --- End: 08/06/2022, 18:26:05
# 		Validation: 2 -- Start: 08/06/2022, 18:26:05---End: 08/06/2022, 18:26:05
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:26:05 --- End: 08/06/2022, 18:26:14
# 		Validation: 3 -- Start: 08/06/2022, 18:26:14---End: 08/06/2022, 18:26:14
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:26:14 --- End: 08/06/2022, 18:26:23
# 		Validation: 4 -- Start: 08/06/2022, 18:26:23---End: 08/06/2022, 18:26:23
#
#
# Traning Case: 2
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:26:23 --- End: 08/06/2022, 18:26:32
# 		Validation: 0 -- Start: 08/06/2022, 18:26:32---End: 08/06/2022, 18:26:32
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:26:32 --- End: 08/06/2022, 18:26:40
# 		Validation: 1 -- Start: 08/06/2022, 18:26:40---End: 08/06/2022, 18:26:40
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:26:40 --- End: 08/06/2022, 18:26:47
# 		Validation: 2 -- Start: 08/06/2022, 18:26:47---End: 08/06/2022, 18:26:47
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:26:47 --- End: 08/06/2022, 18:26:56
# 		Validation: 3 -- Start: 08/06/2022, 18:26:56---End: 08/06/2022, 18:26:56
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:26:56 --- End: 08/06/2022, 18:27:06
# 		Validation: 4 -- Start: 08/06/2022, 18:27:06---End: 08/06/2022, 18:27:06
#
#
# Traning Case: 3
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:27:06 --- End: 08/06/2022, 18:27:14
# 		Validation: 0 -- Start: 08/06/2022, 18:27:14---End: 08/06/2022, 18:27:14
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:27:14 --- End: 08/06/2022, 18:27:21
# 		Validation: 1 -- Start: 08/06/2022, 18:27:21---End: 08/06/2022, 18:27:21
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:27:21 --- End: 08/06/2022, 18:27:30
# 		Validation: 2 -- Start: 08/06/2022, 18:27:30---End: 08/06/2022, 18:27:30
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:27:30 --- End: 08/06/2022, 18:27:39
# 		Validation: 3 -- Start: 08/06/2022, 18:27:39---End: 08/06/2022, 18:27:39
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:27:39 --- End: 08/06/2022, 18:27:48
# 		Validation: 4 -- Start: 08/06/2022, 18:27:48---End: 08/06/2022, 18:27:48
#
#
# Traning Case: 4
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:27:48 --- End: 08/06/2022, 18:27:55
# 		Validation: 0 -- Start: 08/06/2022, 18:27:55---End: 08/06/2022, 18:27:55
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:27:55 --- End: 08/06/2022, 18:28:04
# 		Validation: 1 -- Start: 08/06/2022, 18:28:04---End: 08/06/2022, 18:28:04
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:28:04 --- End: 08/06/2022, 18:28:13
# 		Validation: 2 -- Start: 08/06/2022, 18:28:13---End: 08/06/2022, 18:28:13
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:28:13 --- End: 08/06/2022, 18:28:22
# 		Validation: 3 -- Start: 08/06/2022, 18:28:22---End: 08/06/2022, 18:28:22
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:28:22 --- End: 08/06/2022, 18:28:31
# 		Validation: 4 -- Start: 08/06/2022, 18:28:31---End: 08/06/2022, 18:28:31
#
#
# Traning Case: 5
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:28:31 --- End: 08/06/2022, 18:28:38
# 		Validation: 0 -- Start: 08/06/2022, 18:28:38---End: 08/06/2022, 18:28:38
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:28:38 --- End: 08/06/2022, 18:28:47
# 		Validation: 1 -- Start: 08/06/2022, 18:28:47---End: 08/06/2022, 18:28:47
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:28:47 --- End: 08/06/2022, 18:28:56
# 		Validation: 2 -- Start: 08/06/2022, 18:28:56---End: 08/06/2022, 18:28:56
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:28:56 --- End: 08/06/2022, 18:29:04
# 		Validation: 3 -- Start: 08/06/2022, 18:29:04---End: 08/06/2022, 18:29:04
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:29:05 --- End: 08/06/2022, 18:29:12
# 		Validation: 4 -- Start: 08/06/2022, 18:29:12---End: 08/06/2022, 18:29:12
#
#
# Traning Case: 6
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:29:12 --- End: 08/06/2022, 18:29:21
# 		Validation: 0 -- Start: 08/06/2022, 18:29:21---End: 08/06/2022, 18:29:21
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:29:21 --- End: 08/06/2022, 18:29:29
# 		Validation: 1 -- Start: 08/06/2022, 18:29:29---End: 08/06/2022, 18:29:29
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:29:29 --- End: 08/06/2022, 18:29:38
# 		Validation: 2 -- Start: 08/06/2022, 18:29:38---End: 08/06/2022, 18:29:38
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:29:38 --- End: 08/06/2022, 18:29:47
# 		Validation: 3 -- Start: 08/06/2022, 18:29:47---End: 08/06/2022, 18:29:47
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:29:47 --- End: 08/06/2022, 18:29:54
# 		Validation: 4 -- Start: 08/06/2022, 18:29:54---End: 08/06/2022, 18:29:54
#
#
# Traning Case: 7
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:29:54 --- End: 08/06/2022, 18:30:03
# 		Validation: 0 -- Start: 08/06/2022, 18:30:03---End: 08/06/2022, 18:30:03
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:30:03 --- End: 08/06/2022, 18:30:11
# 		Validation: 1 -- Start: 08/06/2022, 18:30:11---End: 08/06/2022, 18:30:11
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:30:11 --- End: 08/06/2022, 18:30:18
# 		Validation: 2 -- Start: 08/06/2022, 18:30:18---End: 08/06/2022, 18:30:18
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:30:18 --- End: 08/06/2022, 18:30:27
# 		Validation: 3 -- Start: 08/06/2022, 18:30:27---End: 08/06/2022, 18:30:27
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:30:27 --- End: 08/06/2022, 18:30:35
# 		Validation: 4 -- Start: 08/06/2022, 18:30:35---End: 08/06/2022, 18:30:35
#
#
# Traning Case: 8
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:30:36 --- End: 08/06/2022, 18:30:44
# 		Validation: 0 -- Start: 08/06/2022, 18:30:44---End: 08/06/2022, 18:30:44
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:30:44 --- End: 08/06/2022, 18:30:52
# 		Validation: 1 -- Start: 08/06/2022, 18:30:52---End: 08/06/2022, 18:30:52
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:30:52 --- End: 08/06/2022, 18:31:01
# 		Validation: 2 -- Start: 08/06/2022, 18:31:01---End: 08/06/2022, 18:31:01
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:31:01 --- End: 08/06/2022, 18:31:09
# 		Validation: 3 -- Start: 08/06/2022, 18:31:09---End: 08/06/2022, 18:31:09
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:31:09 --- End: 08/06/2022, 18:31:18
# 		Validation: 4 -- Start: 08/06/2022, 18:31:18---End: 08/06/2022, 18:31:18
#
#
# Traning Case: 9
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:31:18 --- End: 08/06/2022, 18:31:26
# 		Validation: 0 -- Start: 08/06/2022, 18:31:26---End: 08/06/2022, 18:31:26
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:31:27 --- End: 08/06/2022, 18:31:36
# 		Validation: 1 -- Start: 08/06/2022, 18:31:36---End: 08/06/2022, 18:31:36
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:31:36 --- End: 08/06/2022, 18:31:43
# 		Validation: 2 -- Start: 08/06/2022, 18:31:43---End: 08/06/2022, 18:31:43
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:31:43 --- End: 08/06/2022, 18:31:52
# 		Validation: 3 -- Start: 08/06/2022, 18:31:52---End: 08/06/2022, 18:31:52
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:31:52 --- End: 08/06/2022, 18:32:01
# 		Validation: 4 -- Start: 08/06/2022, 18:32:01---End: 08/06/2022, 18:32:01
#
#
# Traning Case: 10
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:32:01 --- End: 08/06/2022, 18:32:09
# 		Validation: 0 -- Start: 08/06/2022, 18:32:09---End: 08/06/2022, 18:32:09
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:32:09 --- End: 08/06/2022, 18:32:18
# 		Validation: 1 -- Start: 08/06/2022, 18:32:18---End: 08/06/2022, 18:32:18
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:32:18 --- End: 08/06/2022, 18:32:26
# 		Validation: 2 -- Start: 08/06/2022, 18:32:26---End: 08/06/2022, 18:32:26
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:32:26 --- End: 08/06/2022, 18:32:35
# 		Validation: 3 -- Start: 08/06/2022, 18:32:35---End: 08/06/2022, 18:32:35
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:32:35 --- End: 08/06/2022, 18:32:42
# 		Validation: 4 -- Start: 08/06/2022, 18:32:42---End: 08/06/2022, 18:32:42
#
#
# Traning Case: 11
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:32:42 --- End: 08/06/2022, 18:32:49
# 		Validation: 0 -- Start: 08/06/2022, 18:32:49---End: 08/06/2022, 18:32:49
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:32:49 --- End: 08/06/2022, 18:32:58
# 		Validation: 1 -- Start: 08/06/2022, 18:32:58---End: 08/06/2022, 18:32:58
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:32:58 --- End: 08/06/2022, 18:33:06
# 		Validation: 2 -- Start: 08/06/2022, 18:33:06---End: 08/06/2022, 18:33:06
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:33:06 --- End: 08/06/2022, 18:33:14
# 		Validation: 3 -- Start: 08/06/2022, 18:33:14---End: 08/06/2022, 18:33:14
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:33:14 --- End: 08/06/2022, 18:33:22
# 		Validation: 4 -- Start: 08/06/2022, 18:33:22---End: 08/06/2022, 18:33:22
#
#
# Traning Case: 12
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:33:22 --- End: 08/06/2022, 18:33:30
# 		Validation: 0 -- Start: 08/06/2022, 18:33:30---End: 08/06/2022, 18:33:30
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:33:31 --- End: 08/06/2022, 18:33:39
# 		Validation: 1 -- Start: 08/06/2022, 18:33:39---End: 08/06/2022, 18:33:39
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:33:39 --- End: 08/06/2022, 18:33:47
# 		Validation: 2 -- Start: 08/06/2022, 18:33:47---End: 08/06/2022, 18:33:47
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:33:47 --- End: 08/06/2022, 18:33:55
# 		Validation: 3 -- Start: 08/06/2022, 18:33:55---End: 08/06/2022, 18:33:55
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:33:55 --- End: 08/06/2022, 18:34:04
# 		Validation: 4 -- Start: 08/06/2022, 18:34:04---End: 08/06/2022, 18:34:04
#
#
# Traning Case: 13
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:34:04 --- End: 08/06/2022, 18:34:12
# 		Validation: 0 -- Start: 08/06/2022, 18:34:12---End: 08/06/2022, 18:34:12
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:34:12 --- End: 08/06/2022, 18:34:21
# 		Validation: 1 -- Start: 08/06/2022, 18:34:21---End: 08/06/2022, 18:34:21
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:34:21 --- End: 08/06/2022, 18:34:29
# 		Validation: 2 -- Start: 08/06/2022, 18:34:29---End: 08/06/2022, 18:34:29
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:34:29 --- End: 08/06/2022, 18:34:38
# 		Validation: 3 -- Start: 08/06/2022, 18:34:38---End: 08/06/2022, 18:34:38
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:34:38 --- End: 08/06/2022, 18:34:46
# 		Validation: 4 -- Start: 08/06/2022, 18:34:46---End: 08/06/2022, 18:34:46
#
#
# Traning Case: 14
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:34:46 --- End: 08/06/2022, 18:34:55
# 		Validation: 0 -- Start: 08/06/2022, 18:34:55---End: 08/06/2022, 18:34:55
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:34:55 --- End: 08/06/2022, 18:35:04
# 		Validation: 1 -- Start: 08/06/2022, 18:35:04---End: 08/06/2022, 18:35:04
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:35:04 --- End: 08/06/2022, 18:35:12
# 		Validation: 2 -- Start: 08/06/2022, 18:35:12---End: 08/06/2022, 18:35:12
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:35:12 --- End: 08/06/2022, 18:35:20
# 		Validation: 3 -- Start: 08/06/2022, 18:35:20---End: 08/06/2022, 18:35:20
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:35:20 --- End: 08/06/2022, 18:35:30
# 		Validation: 4 -- Start: 08/06/2022, 18:35:30---End: 08/06/2022, 18:35:30
#
#
# Traning Case: 15
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:35:30 --- End: 08/06/2022, 18:35:39
# 		Validation: 0 -- Start: 08/06/2022, 18:35:39---End: 08/06/2022, 18:35:39
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:35:39 --- End: 08/06/2022, 18:35:47
# 		Validation: 1 -- Start: 08/06/2022, 18:35:47---End: 08/06/2022, 18:35:47
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:35:47 --- End: 08/06/2022, 18:35:56
# 		Validation: 2 -- Start: 08/06/2022, 18:35:56---End: 08/06/2022, 18:35:56
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:35:56 --- End: 08/06/2022, 18:36:05
# 		Validation: 3 -- Start: 08/06/2022, 18:36:05---End: 08/06/2022, 18:36:05
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:36:05 --- End: 08/06/2022, 18:36:14
# 		Validation: 4 -- Start: 08/06/2022, 18:36:14---End: 08/06/2022, 18:36:14
#
#
# Traning Case: 16
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:36:14 --- End: 08/06/2022, 18:36:22
# 		Validation: 0 -- Start: 08/06/2022, 18:36:22---End: 08/06/2022, 18:36:22
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:36:22 --- End: 08/06/2022, 18:36:30
# 		Validation: 1 -- Start: 08/06/2022, 18:36:30---End: 08/06/2022, 18:36:30
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:36:30 --- End: 08/06/2022, 18:36:39
# 		Validation: 2 -- Start: 08/06/2022, 18:36:39---End: 08/06/2022, 18:36:39
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:36:39 --- End: 08/06/2022, 18:36:47
# 		Validation: 3 -- Start: 08/06/2022, 18:36:47---End: 08/06/2022, 18:36:47
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:36:47 --- End: 08/06/2022, 18:36:55
# 		Validation: 4 -- Start: 08/06/2022, 18:36:55---End: 08/06/2022, 18:36:55
#
#
# Traning Case: 17
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:36:55 --- End: 08/06/2022, 18:37:04
# 		Validation: 0 -- Start: 08/06/2022, 18:37:04---End: 08/06/2022, 18:37:04
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:37:04 --- End: 08/06/2022, 18:37:11
# 		Validation: 1 -- Start: 08/06/2022, 18:37:11---End: 08/06/2022, 18:37:11
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:37:11 --- End: 08/06/2022, 18:37:20
# 		Validation: 2 -- Start: 08/06/2022, 18:37:20---End: 08/06/2022, 18:37:20
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:37:20 --- End: 08/06/2022, 18:37:28
# 		Validation: 3 -- Start: 08/06/2022, 18:37:28---End: 08/06/2022, 18:37:28
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:37:28 --- End: 08/06/2022, 18:37:37
# 		Validation: 4 -- Start: 08/06/2022, 18:37:37---End: 08/06/2022, 18:37:37
#
#
# Traning Case: 18
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:37:37 --- End: 08/06/2022, 18:37:44
# 		Validation: 0 -- Start: 08/06/2022, 18:37:44---End: 08/06/2022, 18:37:44
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:37:44 --- End: 08/06/2022, 18:37:52
# 		Validation: 1 -- Start: 08/06/2022, 18:37:52---End: 08/06/2022, 18:37:52
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:37:52 --- End: 08/06/2022, 18:38:01
# 		Validation: 2 -- Start: 08/06/2022, 18:38:01---End: 08/06/2022, 18:38:01
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:38:01 --- End: 08/06/2022, 18:38:07
# 		Validation: 3 -- Start: 08/06/2022, 18:38:07---End: 08/06/2022, 18:38:07
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:38:07 --- End: 08/06/2022, 18:38:16
# 		Validation: 4 -- Start: 08/06/2022, 18:38:16---End: 08/06/2022, 18:38:16
#
#
# Traning Case: 19
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 18:38:16 --- End: 08/06/2022, 18:38:24
# 		Validation: 0 -- Start: 08/06/2022, 18:38:24---End: 08/06/2022, 18:38:24
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 18:38:24 --- End: 08/06/2022, 18:38:32
# 		Validation: 1 -- Start: 08/06/2022, 18:38:32---End: 08/06/2022, 18:38:32
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 18:38:32 --- End: 08/06/2022, 18:38:40
# 		Validation: 2 -- Start: 08/06/2022, 18:38:40---End: 08/06/2022, 18:38:40
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 18:38:40 --- End: 08/06/2022, 18:38:49
# 		Validation: 3 -- Start: 08/06/2022, 18:38:49---End: 08/06/2022, 18:38:49
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 18:38:49 --- End: 08/06/2022, 18:38:58
# 		Validation: 4 -- Start: 08/06/2022, 18:38:58---End: 08/06/2022, 18:38:58

# %%
with open(path, 'rb') as f:
    loaded_dict = pickle.load(f)
loaded_dict
# Out:
# {'train_0': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'newton-cg'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.9931749573434834,
#      'recall': 0.9931749573434834,
#      'f1_score': 0.9931749573434834,
#      'sensitivity': 0.9931749573434834,
#      'specificity': 0.9319371727748691,
#      'negative_predictive_value': 0.9319371727748691,
#      'false_negative_rate': 0.006825042656516603,
#      'false_positive_rate': 0.06806282722513089,
#      'false_discovery_rate': 0.006825042656516603,
#      'false_omission_rate': 0.06806282722513089,
#      'Positive_likelihood_ratio': 14.592032065585025,
#      'Negative_likelihood_ratio': 0.007323500828059951,
#      'prevalence_threshold': 0.20747095262390475,
#      'threat_score': 9.27328431372549,
#      'Prevalence': 0.908863175474174,
#      'Matthews_correlation_coefficient': 1.5892896068562962e-07,
#      'Fowlkes_Mallows_index': 1.409379265736149,
#      'informedness': 0.9251121301183525,
#      'markedness': 0.9251121301183525,
#      'Diagnostic_odds_ratio': 1992.4940828402366,
#      'accuracy': 0.9875939401169033,
#      'balanced_accuracy': 0.9625560650591762},
#     'ROC_AUC_SCORE': {'Macro': 0.9085349684204209,
#      'Micro': 0.9085349684204209,
#      'Weight': 0.9085349684204209},
#     'Classification Report': {'0': {'precision': 0.9931749573434834,
#       'recall': 0.8851327640659726,
#       'f1-score': 0.9360465116279069,
#       'support': 8549},
#      '1': {'precision': 0.4203069657615112,
#       'recall': 0.9319371727748691,
#       'f1-score': 0.5793327908868998,
#       'support': 764},
#      'accuracy': 0.8889724041662193,
#      'macro avg': {'precision': 0.7067409615524973,
#       'recall': 0.9085349684204209,
#       'f1-score': 0.7576896512574034,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9461792367841978,
#       'recall': 0.8889724041662193,
#       'f1-score': 0.9067831934011134,
#       'support': 9313}}},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.9868281000532197,
#      'recall': 0.9868281000532197,
#      'f1_score': 0.9868281000532197,
#      'sensitivity': 0.9868281000532197,
#      'specificity': 0.8433544303797469,
#      'negative_predictive_value': 0.8433544303797469,
#      'false_negative_rate': 0.013171899946780202,
#      'false_positive_rate': 0.15664556962025317,
#      'false_discovery_rate': 0.013171899946780202,
#      'false_omission_rate': 0.15664556962025317,
#      'Positive_likelihood_ratio': 6.299751103370049,
#      'Negative_likelihood_ratio': 0.015618462976294722,
#      'prevalence_threshold': 0.28490592638527523,
#      'threat_score': 10.146374829001369,
#      'Prevalence': 0.9224349533627885,
#      'Matthews_correlation_coefficient': 1.7477114864511965e-07,
#      'Fowlkes_Mallows_index': 1.4048687483556745,
#      'informedness': 0.8301825304329666,
#      'markedness': 0.8301825304329666,
#      'Diagnostic_odds_ratio': 403.3528211407,
#      'accuracy': 0.975699558173785,
#      'balanced_accuracy': 0.9150912652164833},
#     'ROC_AUC_SCORE': {'Macro': 0.8488745426867056,
#      'Micro': 0.8488745426867056,
#      'Weight': 0.8488745426867056},
#     'Classification Report': {'0': {'precision': 0.9868281000532197,
#       'recall': 0.8543946549936643,
#       'f1-score': 0.9158486139408533,
#       'support': 8681},
#      '1': {'precision': 0.29660545353366724,
#       'recall': 0.8433544303797469,
#       'f1-score': 0.4388637299300123,
#       'support': 632},
#      'accuracy': 0.8536454418554709,
#      'macro avg': {'precision': 0.6417167767934435,
#       'recall': 0.8488745426867056,
#       'f1-score': 0.6773561719354328,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9399881223231267,
#       'recall': 0.8536454418554709,
#       'f1-score': 0.8834794045888881,
#       'support': 9313}}},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.9913413963716328,
#      'recall': 0.9913413963716328,
#      'f1_score': 0.9913413963716328,
#      'sensitivity': 0.9913413963716328,
#      'specificity': 0.9306167400881057,
#      'negative_predictive_value': 0.9306167400881057,
#      'false_negative_rate': 0.008658603628367234,
#      'false_positive_rate': 0.06938325991189427,
#      'false_discovery_rate': 0.008658603628367234,
#      'false_omission_rate': 0.06938325991189427,
#      'Positive_likelihood_ratio': 14.28790456992766,
#      'Negative_likelihood_ratio': 0.009304156324920057,
#      'prevalence_threshold': 0.20920788915394095,
#      'threat_score': 7.42842430484037,
#      'Prevalence': 0.8890518084066471,
#      'Matthews_correlation_coefficient': 1.3955090667703283e-07,
#      'Fowlkes_Mallows_index': 1.4080776941430702,
#      'informedness': 0.9219581364597385,
#      'markedness': 0.9219581364597385,
#      'Diagnostic_odds_ratio': 1535.647518266566,
#      'accuracy': 0.9846041055718475,
#      'balanced_accuracy': 0.9609790682298692},
#     'ROC_AUC_SCORE': {'Macro': 0.8943981975276935,
#      'Micro': 0.8943981975276935,
#      'Weight': 0.8943981975276935},
#     'Classification Report': {'0': {'precision': 0.9913413963716328,
#       'recall': 0.8581796549672814,
#       'f1-score': 0.9199668388495632,
#       'support': 8405},
#      '1': {'precision': 0.41482572410407464,
#       'recall': 0.9306167400881057,
#       'f1-score': 0.5738539898132429,
#       'support': 908},
#      'accuracy': 0.8652421346504886,
#      'macro avg': {'precision': 0.7030835602378537,
#       'recall': 0.8943981975276936,
#       'f1-score': 0.746910414331403,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9351322016525365,
#       'recall': 0.8652421346504887,
#       'f1-score': 0.8862214864470099,
#       'support': 9313}}},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.9934111187371311,
#      'recall': 0.9934111187371311,
#      'f1_score': 0.9934111187371311,
#      'sensitivity': 0.9934111187371311,
#      'specificity': 0.9475982532751092,
#      'negative_predictive_value': 0.9475982532751092,
#      'false_negative_rate': 0.0065888812628689085,
#      'false_positive_rate': 0.05240174672489083,
#      'false_discovery_rate': 0.0065888812628689085,
#      'false_omission_rate': 0.05240174672489083,
#      'Positive_likelihood_ratio': 18.957595515900252,
#      'Negative_likelihood_ratio': 0.0069532433603547465,
#      'prevalence_threshold': 0.18677512229631277,
#      'threat_score': 7.507261410788382,
#      'Prevalence': 0.8883063041092549,
#      'Matthews_correlation_coefficient': 1.410161712935655e-07,
#      'Fowlkes_Mallows_index': 1.4095468198943453,
#      'informedness': 0.9410093720122403,
#      'markedness': 0.9410093720122403,
#      'Diagnostic_odds_ratio': 2726.4392361111113,
#      'accuracy': 0.9882941104743324,
#      'balanced_accuracy': 0.9705046860061202},
#     'ROC_AUC_SCORE': {'Macro': 0.9047268389157491,
#      'Micro': 0.9047268389157491,
#      'Weight': 0.9047268389157491},
#     'Classification Report': {'0': {'precision': 0.9934111187371311,
#       'recall': 0.8618554245563892,
#       'f1-score': 0.9229690090549675,
#       'support': 8397},
#      '1': {'precision': 0.4280078895463511,
#       'recall': 0.9475982532751092,
#       'f1-score': 0.5896739130434783,
#       'support': 916},
#      'accuracy': 0.8702888435520241,
#      'macro avg': {'precision': 0.710709504141741,
#       'recall': 0.9047268389157492,
#       'f1-score': 0.7563214610492228,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9377996768882366,
#       'recall': 0.8702888435520241,
#       'f1-score': 0.8901870582392772,
#       'support': 9313}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 0.9951219512195122,
#      'recall': 0.9951219512195122,
#      'f1_score': 0.9951219512195122,
#      'sensitivity': 0.9951219512195122,
#      'specificity': 0.9743396226415094,
#      'negative_predictive_value': 0.9743396226415094,
#      'false_negative_rate': 0.004878048780487805,
#      'false_positive_rate': 0.025660377358490565,
#      'false_discovery_rate': 0.004878048780487805,
#      'false_omission_rate': 0.025660377358490565,
#      'Positive_likelihood_ratio': 38.78048780487805,
#      'Negative_likelihood_ratio': 0.005006517919555648,
#      'prevalence_threshold': 0.1383623785887295,
#      'threat_score': 5.103752759381899,
#      'Prevalence': 0.8402652200120555,
#      'Matthews_correlation_coefficient': 1.049740476826314e-07,
#      'Fowlkes_Mallows_index': 1.4107600442453083,
#      'informedness': 0.9694615738610217,
#      'markedness': 0.9694615738610217,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.9918022905364677,
#      'balanced_accuracy': 0.9847307869305109},
#     'ROC_AUC_SCORE': {'Macro': 0.9213753953948752,
#      'Micro': 0.9213753953948752,
#      'Weight': 0.9213753953948752},
#     'Classification Report': {'0': {'precision': 0.9951219512195122,
#       'recall': 0.8684111681482409,
#       'f1-score': 0.9274587149829512,
#       'support': 7987},
#      '1': {'precision': 0.5512382578992314,
#       'recall': 0.9743396226415094,
#       'f1-score': 0.704117807472048,
#       'support': 1325},
#      'accuracy': 0.883483676975945,
#      'macro avg': {'precision': 0.7731801045593718,
#       'recall': 0.9213753953948751,
#       'f1-score': 0.8157882612274996,
#       'support': 9312},
#      'weighted avg': {'precision': 0.9319619540492619,
#       'recall': 0.883483676975945,
#       'f1-score': 0.8956796447024588,
#       'support': 9312}}}}},
#  'train_1': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'lbfgs'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.9931749573434834,
#      'recall': 0.9931749573434834,
#      'f1_score': 0.9931749573434834,
#      'sensitivity': 0.9931749573434834,
#      'specificity': 0.9319371727748691,
#      'negative_predictive_value': 0.9319371727748691,
#      'false_negative_rate': 0.006825042656516603,
#      'false_positive_rate': 0.06806282722513089,
#      'false_discovery_rate': 0.006825042656516603,
#      'false_omission_rate': 0.06806282722513089,
#      'Positive_likelihood_ratio': 14.592032065585025,
#      'Negative_likelihood_ratio': 0.007323500828059951,
#      'prevalence_threshold': 0.20747095262390475,
#      'threat_score': 9.27328431372549,
#      'Prevalence': 0.908863175474174,
#      'Matthews_correlation_coefficient': 1.5892896068562962e-07,
#      'Fowlkes_Mallows_index': 1.409379265736149,
#      'informedness': 0.9251121301183525,
#      'markedness': 0.9251121301183525,
#      'Diagnostic_odds_ratio': 1992.4940828402366,
#      'accuracy': 0.9875939401169033,
#      'balanced_accuracy': 0.9625560650591762},
#     'ROC_AUC_SCORE': {'Macro': 0.9085349684204209,
#      'Micro': 0.9085349684204209,
#      'Weight': 0.9085349684204209},
#     'Classification Report': {'0': {'precision': 0.9931749573434834,
#       'recall': 0.8851327640659726,
#       'f1-score': 0.9360465116279069,
#       'support': 8549},
#      '1': {'precision': 0.4203069657615112,
#       'recall': 0.9319371727748691,
#       'f1-score': 0.5793327908868998,
#       'support': 764},
#      'accuracy': 0.8889724041662193,
#      'macro avg': {'precision': 0.7067409615524973,
#       'recall': 0.9085349684204209,
#       'f1-score': 0.7576896512574034,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9461792367841978,
#       'recall': 0.8889724041662193,
#       'f1-score': 0.9067831934011134,
#       'support': 9313}}},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.9868281000532197,
#      'recall': 0.9868281000532197,
#      'f1_score': 0.9868281000532197,
#      'sensitivity': 0.9868281000532197,
#      'specificity': 0.8433544303797469,
#      'negative_predictive_value': 0.8433544303797469,
#      'false_negative_rate': 0.013171899946780202,
#      'false_positive_rate': 0.15664556962025317,
#      'false_discovery_rate': 0.013171899946780202,
#      'false_omission_rate': 0.15664556962025317,
#      'Positive_likelihood_ratio': 6.299751103370049,
#      'Negative_likelihood_ratio': 0.015618462976294722,
#      'prevalence_threshold': 0.28490592638527523,
#      'threat_score': 10.146374829001369,
#      'Prevalence': 0.9224349533627885,
#      'Matthews_correlation_coefficient': 1.7477114864511965e-07,
#      'Fowlkes_Mallows_index': 1.4048687483556745,
#      'informedness': 0.8301825304329666,
#      'markedness': 0.8301825304329666,
#      'Diagnostic_odds_ratio': 403.3528211407,
#      'accuracy': 0.975699558173785,
#      'balanced_accuracy': 0.9150912652164833},
#     'ROC_AUC_SCORE': {'Macro': 0.8488745426867056,
#      'Micro': 0.8488745426867056,
#      'Weight': 0.8488745426867056},
#     'Classification Report': {'0': {'precision': 0.9868281000532197,
#       'recall': 0.8543946549936643,
#       'f1-score': 0.9158486139408533,
#       'support': 8681},
#      '1': {'precision': 0.29660545353366724,
#       'recall': 0.8433544303797469,
#       'f1-score': 0.4388637299300123,
#       'support': 632},
#      'accuracy': 0.8536454418554709,
#      'macro avg': {'precision': 0.6417167767934435,
#       'recall': 0.8488745426867056,
#       'f1-score': 0.6773561719354328,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9399881223231267,
#       'recall': 0.8536454418554709,
#       'f1-score': 0.8834794045888881,
#       'support': 9313}}},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.9913413963716328,
#      'recall': 0.9913413963716328,
#      'f1_score': 0.9913413963716328,
#      'sensitivity': 0.9913413963716328,
#      'specificity': 0.9306167400881057,
#      'negative_predictive_value': 0.9306167400881057,
#      'false_negative_rate': 0.008658603628367234,
#      'false_positive_rate': 0.06938325991189427,
#      'false_discovery_rate': 0.008658603628367234,
#      'false_omission_rate': 0.06938325991189427,
#      'Positive_likelihood_ratio': 14.28790456992766,
#      'Negative_likelihood_ratio': 0.009304156324920057,
#      'prevalence_threshold': 0.20920788915394095,
#      'threat_score': 7.42842430484037,
#      'Prevalence': 0.8890518084066471,
#      'Matthews_correlation_coefficient': 1.3955090667703283e-07,
#      'Fowlkes_Mallows_index': 1.4080776941430702,
#      'informedness': 0.9219581364597385,
#      'markedness': 0.9219581364597385,
#      'Diagnostic_odds_ratio': 1535.647518266566,
#      'accuracy': 0.9846041055718475,
#      'balanced_accuracy': 0.9609790682298692},
#     'ROC_AUC_SCORE': {'Macro': 0.8943981975276935,
#      'Micro': 0.8943981975276935,
#      'Weight': 0.8943981975276935},
#     'Classification Report': {'0': {'precision': 0.9913413963716328,
#       'recall': 0.8581796549672814,
#       'f1-score': 0.9199668388495632,
#       'support': 8405},
#      '1': {'precision': 0.41482572410407464,
#       'recall': 0.9306167400881057,
#       'f1-score': 0.5738539898132429,
#       'support': 908},
#      'accuracy': 0.8652421346504886,
#      'macro avg': {'precision': 0.7030835602378537,
#       'recall': 0.8943981975276936,
#       'f1-score': 0.746910414331403,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9351322016525365,
#       'recall': 0.8652421346504887,
#       'f1-score': 0.8862214864470099,
#       'support': 9313}}},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.9934111187371311,
#      'recall': 0.9934111187371311,
#      'f1_score': 0.9934111187371311,
#      'sensitivity': 0.9934111187371311,
#      'specificity': 0.9475982532751092,
#      'negative_predictive_value': 0.9475982532751092,
#      'false_negative_rate': 0.0065888812628689085,
#      'false_positive_rate': 0.05240174672489083,
#      'false_discovery_rate': 0.0065888812628689085,
#      'false_omission_rate': 0.05240174672489083,
#      'Positive_likelihood_ratio': 18.957595515900252,
#      'Negative_likelihood_ratio': 0.0069532433603547465,
#      'prevalence_threshold': 0.18677512229631277,
#      'threat_score': 7.507261410788382,
#      'Prevalence': 0.8883063041092549,
#      'Matthews_correlation_coefficient': 1.410161712935655e-07,
#      'Fowlkes_Mallows_index': 1.4095468198943453,
#      'informedness': 0.9410093720122403,
#      'markedness': 0.9410093720122403,
#      'Diagnostic_odds_ratio': 2726.4392361111113,
#      'accuracy': 0.9882941104743324,
#      'balanced_accuracy': 0.9705046860061202},
#     'ROC_AUC_SCORE': {'Macro': 0.9047268389157491,
#      'Micro': 0.9047268389157491,
#      'Weight': 0.9047268389157491},
#     'Classification Report': {'0': {'precision': 0.9934111187371311,
#       'recall': 0.8618554245563892,
#       'f1-score': 0.9229690090549675,
#       'support': 8397},
#      '1': {'precision': 0.4280078895463511,
#       'recall': 0.9475982532751092,
#       'f1-score': 0.5896739130434783,
#       'support': 916},
#      'accuracy': 0.8702888435520241,
#      'macro avg': {'precision': 0.710709504141741,
#       'recall': 0.9047268389157492,
#       'f1-score': 0.7563214610492228,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9377996768882366,
#       'recall': 0.8702888435520241,
#       'f1-score': 0.8901870582392772,
#       'support': 9313}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 0.9951219512195122,
#      'recall': 0.9951219512195122,
#      'f1_score': 0.9951219512195122,
#      'sensitivity': 0.9951219512195122,
#      'specificity': 0.9743396226415094,
#      'negative_predictive_value': 0.9743396226415094,
#      'false_negative_rate': 0.004878048780487805,
#      'false_positive_rate': 0.025660377358490565,
#      'false_discovery_rate': 0.004878048780487805,
#      'false_omission_rate': 0.025660377358490565,
#      'Positive_likelihood_ratio': 38.78048780487805,
#      'Negative_likelihood_ratio': 0.005006517919555648,
#      'prevalence_threshold': 0.1383623785887295,
#      'threat_score': 5.103752759381899,
#      'Prevalence': 0.8402652200120555,
#      'Matthews_correlation_coefficient': 1.049740476826314e-07,
#      'Fowlkes_Mallows_index': 1.4107600442453083,
#      'informedness': 0.9694615738610217,
#      'markedness': 0.9694615738610217,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.9918022905364677,
#      'balanced_accuracy': 0.9847307869305109},
#     'ROC_AUC_SCORE': {'Macro': 0.9213753953948752,
#      'Micro': 0.9213753953948752,
#      'Weight': 0.9213753953948752},
#     'Classification Report': {'0': {'precision': 0.9951219512195122,
#       'recall': 0.8684111681482409,
#       'f1-score': 0.9274587149829512,
#       'support': 7987},
#      '1': {'precision': 0.5512382578992314,
#       'recall': 0.9743396226415094,
#       'f1-score': 0.704117807472048,
#       'support': 1325},
#      'accuracy': 0.883483676975945,
#      'macro avg': {'precision': 0.7731801045593718,
#       'recall': 0.9213753953948751,
#       'f1-score': 0.8157882612274996,
#       'support': 9312},
#      'weighted avg': {'precision': 0.9319619540492619,
#       'recall': 0.883483676975945,
#       'f1-score': 0.8956796447024588,
#       'support': 9312}}}}},
#  'train_2': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'liblinear'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.9931749573434834,
#      'recall': 0.9931749573434834,
#      'f1_score': 0.9931749573434834,
#      'sensitivity': 0.9931749573434834,
#      'specificity': 0.9319371727748691,
#      'negative_predictive_value': 0.9319371727748691,
#      'false_negative_rate': 0.006825042656516603,
#      'false_positive_rate': 0.06806282722513089,
#      'false_discovery_rate': 0.006825042656516603,
#      'false_omission_rate': 0.06806282722513089,
#      'Positive_likelihood_ratio': 14.592032065585025,
#      'Negative_likelihood_ratio': 0.007323500828059951,
#      'prevalence_threshold': 0.20747095262390475,
#      'threat_score': 9.27328431372549,
#      'Prevalence': 0.908863175474174,
#      'Matthews_correlation_coefficient': 1.5892896068562962e-07,
#      'Fowlkes_Mallows_index': 1.409379265736149,
#      'informedness': 0.9251121301183525,
#      'markedness': 0.9251121301183525,
#      'Diagnostic_odds_ratio': 1992.4940828402366,
#      'accuracy': 0.9875939401169033,
#      'balanced_accuracy': 0.9625560650591762},
#     'ROC_AUC_SCORE': {'Macro': 0.9085349684204209,
#      'Micro': 0.9085349684204209,
#      'Weight': 0.9085349684204209},
#     'Classification Report': {'0': {'precision': 0.9931749573434834,
#       'recall': 0.8851327640659726,
#       'f1-score': 0.9360465116279069,
#       'support': 8549},
#      '1': {'precision': 0.4203069657615112,
#       'recall': 0.9319371727748691,
#       'f1-score': 0.5793327908868998,
#       'support': 764},
#      'accuracy': 0.8889724041662193,
#      'macro avg': {'precision': 0.7067409615524973,
#       'recall': 0.9085349684204209,
#       'f1-score': 0.7576896512574034,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9461792367841978,
#       'recall': 0.8889724041662193,
#       'f1-score': 0.9067831934011134,
#       'support': 9313}}},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.9868281000532197,
#      'recall': 0.9868281000532197,
#      'f1_score': 0.9868281000532197,
#      'sensitivity': 0.9868281000532197,
#      'specificity': 0.8433544303797469,
#      'negative_predictive_value': 0.8433544303797469,
#      'false_negative_rate': 0.013171899946780202,
#      'false_positive_rate': 0.15664556962025317,
#      'false_discovery_rate': 0.013171899946780202,
#      'false_omission_rate': 0.15664556962025317,
#      'Positive_likelihood_ratio': 6.299751103370049,
#      'Negative_likelihood_ratio': 0.015618462976294722,
#      'prevalence_threshold': 0.28490592638527523,
#      'threat_score': 10.146374829001369,
#      'Prevalence': 0.9224349533627885,
#      'Matthews_correlation_coefficient': 1.7477114864511965e-07,
#      'Fowlkes_Mallows_index': 1.4048687483556745,
#      'informedness': 0.8301825304329666,
#      'markedness': 0.8301825304329666,
#      'Diagnostic_odds_ratio': 403.3528211407,
#      'accuracy': 0.975699558173785,
#      'balanced_accuracy': 0.9150912652164833},
#     'ROC_AUC_SCORE': {'Macro': 0.8488745426867056,
#      'Micro': 0.8488745426867056,
#      'Weight': 0.8488745426867056},
#     'Classification Report': {'0': {'precision': 0.9868281000532197,
#       'recall': 0.8543946549936643,
#       'f1-score': 0.9158486139408533,
#       'support': 8681},
#      '1': {'precision': 0.29660545353366724,
#       'recall': 0.8433544303797469,
#       'f1-score': 0.4388637299300123,
#       'support': 632},
#      'accuracy': 0.8536454418554709,
#      'macro avg': {'precision': 0.6417167767934435,
#       'recall': 0.8488745426867056,
#       'f1-score': 0.6773561719354328,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9399881223231267,
#       'recall': 0.8536454418554709,
#       'f1-score': 0.8834794045888881,
#       'support': 9313}}},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.9913413963716328,
#      'recall': 0.9913413963716328,
#      'f1_score': 0.9913413963716328,
#      'sensitivity': 0.9913413963716328,
#      'specificity': 0.9306167400881057,
#      'negative_predictive_value': 0.9306167400881057,
#      'false_negative_rate': 0.008658603628367234,
#      'false_positive_rate': 0.06938325991189427,
#      'false_discovery_rate': 0.008658603628367234,
#      'false_omission_rate': 0.06938325991189427,
#      'Positive_likelihood_ratio': 14.28790456992766,
#      'Negative_likelihood_ratio': 0.009304156324920057,
#      'prevalence_threshold': 0.20920788915394095,
#      'threat_score': 7.42842430484037,
#      'Prevalence': 0.8890518084066471,
#      'Matthews_correlation_coefficient': 1.3955090667703283e-07,
#      'Fowlkes_Mallows_index': 1.4080776941430702,
#      'informedness': 0.9219581364597385,
#      'markedness': 0.9219581364597385,
#      'Diagnostic_odds_ratio': 1535.647518266566,
#      'accuracy': 0.9846041055718475,
#      'balanced_accuracy': 0.9609790682298692},
#     'ROC_AUC_SCORE': {'Macro': 0.8943981975276935,
#      'Micro': 0.8943981975276935,
#      'Weight': 0.8943981975276935},
#     'Classification Report': {'0': {'precision': 0.9913413963716328,
#       'recall': 0.8581796549672814,
#       'f1-score': 0.9199668388495632,
#       'support': 8405},
#      '1': {'precision': 0.41482572410407464,
#       'recall': 0.9306167400881057,
#       'f1-score': 0.5738539898132429,
#       'support': 908},
#      'accuracy': 0.8652421346504886,
#      'macro avg': {'precision': 0.7030835602378537,
#       'recall': 0.8943981975276936,
#       'f1-score': 0.746910414331403,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9351322016525365,
#       'recall': 0.8652421346504887,
#       'f1-score': 0.8862214864470099,
#       'support': 9313}}},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.9934111187371311,
#      'recall': 0.9934111187371311,
#      'f1_score': 0.9934111187371311,
#      'sensitivity': 0.9934111187371311,
#      'specificity': 0.9475982532751092,
#      'negative_predictive_value': 0.9475982532751092,
#      'false_negative_rate': 0.0065888812628689085,
#      'false_positive_rate': 0.05240174672489083,
#      'false_discovery_rate': 0.0065888812628689085,
#      'false_omission_rate': 0.05240174672489083,
#      'Positive_likelihood_ratio': 18.957595515900252,
#      'Negative_likelihood_ratio': 0.0069532433603547465,
#      'prevalence_threshold': 0.18677512229631277,
#      'threat_score': 7.507261410788382,
#      'Prevalence': 0.8883063041092549,
#      'Matthews_correlation_coefficient': 1.410161712935655e-07,
#      'Fowlkes_Mallows_index': 1.4095468198943453,
#      'informedness': 0.9410093720122403,
#      'markedness': 0.9410093720122403,
#      'Diagnostic_odds_ratio': 2726.4392361111113,
#      'accuracy': 0.9882941104743324,
#      'balanced_accuracy': 0.9705046860061202},
#     'ROC_AUC_SCORE': {'Macro': 0.9047268389157491,
#      'Micro': 0.9047268389157491,
#      'Weight': 0.9047268389157491},
#     'Classification Report': {'0': {'precision': 0.9934111187371311,
#       'recall': 0.8618554245563892,
#       'f1-score': 0.9229690090549675,
#       'support': 8397},
#      '1': {'precision': 0.4280078895463511,
#       'recall': 0.9475982532751092,
#       'f1-score': 0.5896739130434783,
#       'support': 916},
#      'accuracy': 0.8702888435520241,
#      'macro avg': {'precision': 0.710709504141741,
#       'recall': 0.9047268389157492,
#       'f1-score': 0.7563214610492228,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9377996768882366,
#       'recall': 0.8702888435520241,
#       'f1-score': 0.8901870582392772,
#       'support': 9313}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 0.9951219512195122,
#      'recall': 0.9951219512195122,
#      'f1_score': 0.9951219512195122,
#      'sensitivity': 0.9951219512195122,
#      'specificity': 0.9743396226415094,
#      'negative_predictive_value': 0.9743396226415094,
#      'false_negative_rate': 0.004878048780487805,
#      'false_positive_rate': 0.025660377358490565,
#      'false_discovery_rate': 0.004878048780487805,
#      'false_omission_rate': 0.025660377358490565,
#      'Positive_likelihood_ratio': 38.78048780487805,
#      'Negative_likelihood_ratio': 0.005006517919555648,
#      'prevalence_threshold': 0.1383623785887295,
#      'threat_score': 5.103752759381899,
#      'Prevalence': 0.8402652200120555,
#      'Matthews_correlation_coefficient': 1.049740476826314e-07,
#      'Fowlkes_Mallows_index': 1.4107600442453083,
#      'informedness': 0.9694615738610217,
#      'markedness': 0.9694615738610217,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.9918022905364677,
#      'balanced_accuracy': 0.9847307869305109},
#     'ROC_AUC_SCORE': {'Macro': 0.9213753953948752,
#      'Micro': 0.9213753953948752,
#      'Weight': 0.9213753953948752},
#     'Classification Report': {'0': {'precision': 0.9951219512195122,
#       'recall': 0.8684111681482409,
#       'f1-score': 0.9274587149829512,
#       'support': 7987},
#      '1': {'precision': 0.5512382578992314,
#       'recall': 0.9743396226415094,
#       'f1-score': 0.704117807472048,
#       'support': 1325},
#      'accuracy': 0.883483676975945,
#      'macro avg': {'precision': 0.7731801045593718,
#       'recall': 0.9213753953948751,
#       'f1-score': 0.8157882612274996,
#       'support': 9312},
#      'weighted avg': {'precision': 0.9319619540492619,
#       'recall': 0.883483676975945,
#       'f1-score': 0.8956796447024588,
#       'support': 9312}}}}},
#  'train_3': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'sag'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.9931749573434834,
#      'recall': 0.9931749573434834,
#      'f1_score': 0.9931749573434834,
#      'sensitivity': 0.9931749573434834,
#      'specificity': 0.9319371727748691,
#      'negative_predictive_value': 0.9319371727748691,
#      'false_negative_rate': 0.006825042656516603,
#      'false_positive_rate': 0.06806282722513089,
#      'false_discovery_rate': 0.006825042656516603,
#      'false_omission_rate': 0.06806282722513089,
#      'Positive_likelihood_ratio': 14.592032065585025,
#      'Negative_likelihood_ratio': 0.007323500828059951,
#      'prevalence_threshold': 0.20747095262390475,
#      'threat_score': 9.27328431372549,
#      'Prevalence': 0.908863175474174,
#      'Matthews_correlation_coefficient': 1.5892896068562962e-07,
#      'Fowlkes_Mallows_index': 1.409379265736149,
#      'informedness': 0.9251121301183525,
#      'markedness': 0.9251121301183525,
#      'Diagnostic_odds_ratio': 1992.4940828402366,
#      'accuracy': 0.9875939401169033,
#      'balanced_accuracy': 0.9625560650591762},
#     'ROC_AUC_SCORE': {'Macro': 0.9085349684204209,
#      'Micro': 0.9085349684204209,
#      'Weight': 0.9085349684204209},
#     'Classification Report': {'0': {'precision': 0.9931749573434834,
#       'recall': 0.8851327640659726,
#       'f1-score': 0.9360465116279069,
#       'support': 8549},
#      '1': {'precision': 0.4203069657615112,
#       'recall': 0.9319371727748691,
#       'f1-score': 0.5793327908868998,
#       'support': 764},
#      'accuracy': 0.8889724041662193,
#      'macro avg': {'precision': 0.7067409615524973,
#       'recall': 0.9085349684204209,
#       'f1-score': 0.7576896512574034,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9461792367841978,
#       'recall': 0.8889724041662193,
#       'f1-score': 0.9067831934011134,
#       'support': 9313}}},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.9868281000532197,
#      'recall': 0.9868281000532197,
#      'f1_score': 0.9868281000532197,
#      'sensitivity': 0.9868281000532197,
#      'specificity': 0.8433544303797469,
#      'negative_predictive_value': 0.8433544303797469,
#      'false_negative_rate': 0.013171899946780202,
#      'false_positive_rate': 0.15664556962025317,
#      'false_discovery_rate': 0.013171899946780202,
#      'false_omission_rate': 0.15664556962025317,
#      'Positive_likelihood_ratio': 6.299751103370049,
#      'Negative_likelihood_ratio': 0.015618462976294722,
#      'prevalence_threshold': 0.28490592638527523,
#      'threat_score': 10.146374829001369,
#      'Prevalence': 0.9224349533627885,
#      'Matthews_correlation_coefficient': 1.7477114864511965e-07,
#      'Fowlkes_Mallows_index': 1.4048687483556745,
#      'informedness': 0.8301825304329666,
#      'markedness': 0.8301825304329666,
#      'Diagnostic_odds_ratio': 403.3528211407,
#      'accuracy': 0.975699558173785,
#      'balanced_accuracy': 0.9150912652164833},
#     'ROC_AUC_SCORE': {'Macro': 0.8488745426867056,
#      'Micro': 0.8488745426867056,
#      'Weight': 0.8488745426867056},
#     'Classification Report': {'0': {'precision': 0.9868281000532197,
#       'recall': 0.8543946549936643,
#       'f1-score': 0.9158486139408533,
#       'support': 8681},
#      '1': {'precision': 0.29660545353366724,
#       'recall': 0.8433544303797469,
#       'f1-score': 0.4388637299300123,
#       'support': 632},
#      'accuracy': 0.8536454418554709,
#      'macro avg': {'precision': 0.6417167767934435,
#       'recall': 0.8488745426867056,
#       'f1-score': 0.6773561719354328,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9399881223231267,
#       'recall': 0.8536454418554709,
#       'f1-score': 0.8834794045888881,
#       'support': 9313}}},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.9913413963716328,
#      'recall': 0.9913413963716328,
#      'f1_score': 0.9913413963716328,
#      'sensitivity': 0.9913413963716328,
#      'specificity': 0.9306167400881057,
#      'negative_predictive_value': 0.9306167400881057,
#      'false_negative_rate': 0.008658603628367234,
#      'false_positive_rate': 0.06938325991189427,
#      'false_discovery_rate': 0.008658603628367234,
#      'false_omission_rate': 0.06938325991189427,
#      'Positive_likelihood_ratio': 14.28790456992766,
#      'Negative_likelihood_ratio': 0.009304156324920057,
#      'prevalence_threshold': 0.20920788915394095,
#      'threat_score': 7.42842430484037,
#      'Prevalence': 0.8890518084066471,
#      'Matthews_correlation_coefficient': 1.3955090667703283e-07,
#      'Fowlkes_Mallows_index': 1.4080776941430702,
#      'informedness': 0.9219581364597385,
#      'markedness': 0.9219581364597385,
#      'Diagnostic_odds_ratio': 1535.647518266566,
#      'accuracy': 0.9846041055718475,
#      'balanced_accuracy': 0.9609790682298692},
#     'ROC_AUC_SCORE': {'Macro': 0.8943981975276935,
#      'Micro': 0.8943981975276935,
#      'Weight': 0.8943981975276935},
#     'Classification Report': {'0': {'precision': 0.9913413963716328,
#       'recall': 0.8581796549672814,
#       'f1-score': 0.9199668388495632,
#       'support': 8405},
#      '1': {'precision': 0.41482572410407464,
#       'recall': 0.9306167400881057,
#       'f1-score': 0.5738539898132429,
#       'support': 908},
#      'accuracy': 0.8652421346504886,
#      'macro avg': {'precision': 0.7030835602378537,
#       'recall': 0.8943981975276936,
#       'f1-score': 0.746910414331403,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9351322016525365,
#       'recall': 0.8652421346504887,
#       'f1-score': 0.8862214864470099,
#       'support': 9313}}},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.9934111187371311,
#      'recall': 0.9934111187371311,
#      'f1_score': 0.9934111187371311,
#      'sensitivity': 0.9934111187371311,
#      'specificity': 0.9475982532751092,
#      'negative_predictive_value': 0.9475982532751092,
#      'false_negative_rate': 0.0065888812628689085,
#      'false_positive_rate': 0.05240174672489083,
#      'false_discovery_rate': 0.0065888812628689085,
#      'false_omission_rate': 0.05240174672489083,
#      'Positive_likelihood_ratio': 18.957595515900252,
#      'Negative_likelihood_ratio': 0.0069532433603547465,
#      'prevalence_threshold': 0.18677512229631277,
#      'threat_score': 7.507261410788382,
#      'Prevalence': 0.8883063041092549,
#      'Matthews_correlation_coefficient': 1.410161712935655e-07,
#      'Fowlkes_Mallows_index': 1.4095468198943453,
#      'informedness': 0.9410093720122403,
#      'markedness': 0.9410093720122403,
#      'Diagnostic_odds_ratio': 2726.4392361111113,
#      'accuracy': 0.9882941104743324,
#      'balanced_accuracy': 0.9705046860061202},
#     'ROC_AUC_SCORE': {'Macro': 0.9047268389157491,
#      'Micro': 0.9047268389157491,
#      'Weight': 0.9047268389157491},
#     'Classification Report': {'0': {'precision': 0.9934111187371311,
#       'recall': 0.8618554245563892,
#       'f1-score': 0.9229690090549675,
#       'support': 8397},
#      '1': {'precision': 0.4280078895463511,
#       'recall': 0.9475982532751092,
#       'f1-score': 0.5896739130434783,
#       'support': 916},
#      'accuracy': 0.8702888435520241,
#      'macro avg': {'precision': 0.710709504141741,
#       'recall': 0.9047268389157492,
#       'f1-score': 0.7563214610492228,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9377996768882366,
#       'recall': 0.8702888435520241,
#       'f1-score': 0.8901870582392772,
#       'support': 9313}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 0.9951219512195122,
#      'recall': 0.9951219512195122,
#      'f1_score': 0.9951219512195122,
#      'sensitivity': 0.9951219512195122,
#      'specificity': 0.9743396226415094,
#      'negative_predictive_value': 0.9743396226415094,
#      'false_negative_rate': 0.004878048780487805,
#      'false_positive_rate': 0.025660377358490565,
#      'false_discovery_rate': 0.004878048780487805,
#      'false_omission_rate': 0.025660377358490565,
#      'Positive_likelihood_ratio': 38.78048780487805,
#      'Negative_likelihood_ratio': 0.005006517919555648,
#      'prevalence_threshold': 0.1383623785887295,
#      'threat_score': 5.103752759381899,
#      'Prevalence': 0.8402652200120555,
#      'Matthews_correlation_coefficient': 1.049740476826314e-07,
#      'Fowlkes_Mallows_index': 1.4107600442453083,
#      'informedness': 0.9694615738610217,
#      'markedness': 0.9694615738610217,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.9918022905364677,
#      'balanced_accuracy': 0.9847307869305109},
#     'ROC_AUC_SCORE': {'Macro': 0.9213753953948752,
#      'Micro': 0.9213753953948752,
#      'Weight': 0.9213753953948752},
#     'Classification Report': {'0': {'precision': 0.9951219512195122,
#       'recall': 0.8684111681482409,
#       'f1-score': 0.9274587149829512,
#       'support': 7987},
#      '1': {'precision': 0.5512382578992314,
#       'recall': 0.9743396226415094,
#       'f1-score': 0.704117807472048,
#       'support': 1325},
#      'accuracy': 0.883483676975945,
#      'macro avg': {'precision': 0.7731801045593718,
#       'recall': 0.9213753953948751,
#       'f1-score': 0.8157882612274996,
#       'support': 9312},
#      'weighted avg': {'precision': 0.9319619540492619,
#       'recall': 0.883483676975945,
#       'f1-score': 0.8956796447024588,
#       'support': 9312}}}}},
#  'train_4': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'saga'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.9931749573434834,
#      'recall': 0.9931749573434834,
#      'f1_score': 0.9931749573434834,
#      'sensitivity': 0.9931749573434834,
#      'specificity': 0.9319371727748691,
#      'negative_predictive_value': 0.9319371727748691,
#      'false_negative_rate': 0.006825042656516603,
#      'false_positive_rate': 0.06806282722513089,
#      'false_discovery_rate': 0.006825042656516603,
#      'false_omission_rate': 0.06806282722513089,
#      'Positive_likelihood_ratio': 14.592032065585025,
#      'Negative_likelihood_ratio': 0.007323500828059951,
#      'prevalence_threshold': 0.20747095262390475,
#      'threat_score': 9.27328431372549,
#      'Prevalence': 0.908863175474174,
#      'Matthews_correlation_coefficient': 1.5892896068562962e-07,
#      'Fowlkes_Mallows_index': 1.409379265736149,
#      'informedness': 0.9251121301183525,
#      'markedness': 0.9251121301183525,
#      'Diagnostic_odds_ratio': 1992.4940828402366,
#      'accuracy': 0.9875939401169033,
#      'balanced_accuracy': 0.9625560650591762},
#     'ROC_AUC_SCORE': {'Macro': 0.9085349684204209,
#      'Micro': 0.9085349684204209,
#      'Weight': 0.9085349684204209},
#     'Classification Report': {'0': {'precision': 0.9931749573434834,
#       'recall': 0.8851327640659726,
#       'f1-score': 0.9360465116279069,
#       'support': 8549},
#      '1': {'precision': 0.4203069657615112,
#       'recall': 0.9319371727748691,
#       'f1-score': 0.5793327908868998,
#       'support': 764},
#      'accuracy': 0.8889724041662193,
#      'macro avg': {'precision': 0.7067409615524973,
#       'recall': 0.9085349684204209,
#       'f1-score': 0.7576896512574034,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9461792367841978,
#       'recall': 0.8889724041662193,
#       'f1-score': 0.9067831934011134,
#       'support': 9313}}},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.9868281000532197,
#      'recall': 0.9868281000532197,
#      'f1_score': 0.9868281000532197,
#      'sensitivity': 0.9868281000532197,
#      'specificity': 0.8433544303797469,
#      'negative_predictive_value': 0.8433544303797469,
#      'false_negative_rate': 0.013171899946780202,
#      'false_positive_rate': 0.15664556962025317,
#      'false_discovery_rate': 0.013171899946780202,
#      'false_omission_rate': 0.15664556962025317,
#      'Positive_likelihood_ratio': 6.299751103370049,
#      'Negative_likelihood_ratio': 0.015618462976294722,
#      'prevalence_threshold': 0.28490592638527523,
#      'threat_score': 10.146374829001369,
#      'Prevalence': 0.9224349533627885,
#      'Matthews_correlation_coefficient': 1.7477114864511965e-07,
#      'Fowlkes_Mallows_index': 1.4048687483556745,
#      'informedness': 0.8301825304329666,
#      'markedness': 0.8301825304329666,
#      'Diagnostic_odds_ratio': 403.3528211407,
#      'accuracy': 0.975699558173785,
#      'balanced_accuracy': 0.9150912652164833},
#     'ROC_AUC_SCORE': {'Macro': 0.8488745426867056,
#      'Micro': 0.8488745426867056,
#      'Weight': 0.8488745426867056},
#     'Classification Report': {'0': {'precision': 0.9868281000532197,
#       'recall': 0.8543946549936643,
#       'f1-score': 0.9158486139408533,
#       'support': 8681},
#      '1': {'precision': 0.29660545353366724,
#       'recall': 0.8433544303797469,
#       'f1-score': 0.4388637299300123,
#       'support': 632},
#      'accuracy': 0.8536454418554709,
#      'macro avg': {'precision': 0.6417167767934435,
#       'recall': 0.8488745426867056,
#       'f1-score': 0.6773561719354328,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9399881223231267,
#       'recall': 0.8536454418554709,
#       'f1-score': 0.8834794045888881,
#       'support': 9313}}},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.9913413963716328,
#      'recall': 0.9913413963716328,
#      'f1_score': 0.9913413963716328,
#      'sensitivity': 0.9913413963716328,
#      'specificity': 0.9306167400881057,
#      'negative_predictive_value': 0.9306167400881057,
#      'false_negative_rate': 0.008658603628367234,
#      'false_positive_rate': 0.06938325991189427,
#      'false_discovery_rate': 0.008658603628367234,
#      'false_omission_rate': 0.06938325991189427,
#      'Positive_likelihood_ratio': 14.28790456992766,
#      'Negative_likelihood_ratio': 0.009304156324920057,
#      'prevalence_threshold': 0.20920788915394095,
#      'threat_score': 7.42842430484037,
#      'Prevalence': 0.8890518084066471,
#      'Matthews_correlation_coefficient': 1.3955090667703283e-07,
#      'Fowlkes_Mallows_index': 1.4080776941430702,
#      'informedness': 0.9219581364597385,
#      'markedness': 0.9219581364597385,
#      'Diagnostic_odds_ratio': 1535.647518266566,
#      'accuracy': 0.9846041055718475,
#      'balanced_accuracy': 0.9609790682298692},
#     'ROC_AUC_SCORE': {'Macro': 0.8943981975276935,
#      'Micro': 0.8943981975276935,
#      'Weight': 0.8943981975276935},
#     'Classification Report': {'0': {'precision': 0.9913413963716328,
#       'recall': 0.8581796549672814,
#       'f1-score': 0.9199668388495632,
#       'support': 8405},
#      '1': {'precision': 0.41482572410407464,
#       'recall': 0.9306167400881057,
#       'f1-score': 0.5738539898132429,
#       'support': 908},
#      'accuracy': 0.8652421346504886,
#      'macro avg': {'precision': 0.7030835602378537,
#       'recall': 0.8943981975276936,
#       'f1-score': 0.746910414331403,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9351322016525365,
#       'recall': 0.8652421346504887,
#       'f1-score': 0.8862214864470099,
#       'support': 9313}}},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.9934111187371311,
#      'recall': 0.9934111187371311,
#      'f1_score': 0.9934111187371311,
#      'sensitivity': 0.9934111187371311,
#      'specificity': 0.9475982532751092,
#      'negative_predictive_value': 0.9475982532751092,
#      'false_negative_rate': 0.0065888812628689085,
#      'false_positive_rate': 0.05240174672489083,
#      'false_discovery_rate': 0.0065888812628689085,
#      'false_omission_rate': 0.05240174672489083,
#      'Positive_likelihood_ratio': 18.957595515900252,
#      'Negative_likelihood_ratio': 0.0069532433603547465,
#      'prevalence_threshold': 0.18677512229631277,
#      'threat_score': 7.507261410788382,
#      'Prevalence': 0.8883063041092549,
#      'Matthews_correlation_coefficient': 1.410161712935655e-07,
#      'Fowlkes_Mallows_index': 1.4095468198943453,
#      'informedness': 0.9410093720122403,
#      'markedness': 0.9410093720122403,
#      'Diagnostic_odds_ratio': 2726.4392361111113,
#      'accuracy': 0.9882941104743324,
#      'balanced_accuracy': 0.9705046860061202},
#     'ROC_AUC_SCORE': {'Macro': 0.9047268389157491,
#      'Micro': 0.9047268389157491,
#      'Weight': 0.9047268389157491},
#     'Classification Report': {'0': {'precision': 0.9934111187371311,
#       'recall': 0.8618554245563892,
#       'f1-score': 0.9229690090549675,
#       'support': 8397},
#      '1': {'precision': 0.4280078895463511,
#       'recall': 0.9475982532751092,
#       'f1-score': 0.5896739130434783,
#       'support': 916},
#      'accuracy': 0.8702888435520241,
#      'macro avg': {'precision': 0.710709504141741,
#       'recall': 0.9047268389157492,
#       'f1-score': 0.7563214610492228,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9377996768882366,
#       'recall': 0.8702888435520241,
#       'f1-score': 0.8901870582392772,
#       'support': 9313}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 0.9951219512195122,
#      'recall': 0.9951219512195122,
#      'f1_score': 0.9951219512195122,
#      'sensitivity': 0.9951219512195122,
#      'specificity': 0.9743396226415094,
#      'negative_predictive_value': 0.9743396226415094,
#      'false_negative_rate': 0.004878048780487805,
#      'false_positive_rate': 0.025660377358490565,
#      'false_discovery_rate': 0.004878048780487805,
#      'false_omission_rate': 0.025660377358490565,
#      'Positive_likelihood_ratio': 38.78048780487805,
#      'Negative_likelihood_ratio': 0.005006517919555648,
#      'prevalence_threshold': 0.1383623785887295,
#      'threat_score': 5.103752759381899,
#      'Prevalence': 0.8402652200120555,
#      'Matthews_correlation_coefficient': 1.049740476826314e-07,
#      'Fowlkes_Mallows_index': 1.4107600442453083,
#      'informedness': 0.9694615738610217,
#      'markedness': 0.9694615738610217,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.9918022905364677,
#      'balanced_accuracy': 0.9847307869305109},
#     'ROC_AUC_SCORE': {'Macro': 0.9213753953948752,
#      'Micro': 0.9213753953948752,
#      'Weight': 0.9213753953948752},
#     'Classification Report': {'0': {'precision': 0.9951219512195122,
#       'recall': 0.8684111681482409,
#       'f1-score': 0.9274587149829512,
#       'support': 7987},
#      '1': {'precision': 0.5512382578992314,
#       'recall': 0.9743396226415094,
#       'f1-score': 0.704117807472048,
#       'support': 1325},
#      'accuracy': 0.883483676975945,
#      'macro avg': {'precision': 0.7731801045593718,
#       'recall': 0.9213753953948751,
#       'f1-score': 0.8157882612274996,
#       'support': 9312},
#      'weighted avg': {'precision': 0.9319619540492619,
#       'recall': 0.883483676975945,
#       'f1-score': 0.8956796447024588,
#       'support': 9312}}}}},
#  'train_5': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': None,
#    'solver': 'newton-cg'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 8394,
#      'TN': 534,
#      'FN': 230,
#      'FP': 230,
#      'precision': 0.9733302411873841,
#      'recall': 0.9733302411873841,
#      'f1_score': 0.9733302411873841,
#      'sensitivity': 0.9733302411873841,
#      'specificity': 0.6989528795811518,
#      'negative_predictive_value': 0.6989528795811518,
#      'false_negative_rate': 0.026669758812615955,
# ...
#      'Diagnostic_odds_ratio': 61.973354809912856,
#      'accuracy': 0.9480786825251601,
#      'balanced_accuracy': 0.8064197750480613},
#     'ROC_AUC_SCORE': {'Macro': 0.7745641397843975,
#      'Micro': 0.7745641397843975,
#      'Weight': 0.7745641397843975},
#     'Classification Report': {'0': {'precision': 0.972016765285996,
#       'recall': 0.9083054947586684,
#       'f1-score': 0.93908176025725,
#       'support': 8681},
#      '1': {'precision': 0.33721898417985013,
#       'recall': 0.6408227848101266,
#       'f1-score': 0.44189852700490995,
#       'support': 632},
#      'accuracy': 0.8901535488027489,
#      'macro avg': {'precision': 0.6546178747329231,
#       'recall': 0.7745641397843974,
#       'f1-score': 0.69049014363108,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9289380368784921,
#       'recall': 0.8901535488027489,
#       'f1-score': 0.9053418479394706,
#       'support': 9313}}},
#    'fold_2': {'Confusion Matrix': {'TP': 7890,
#      'TN': 549,
#      'FN': 359,
#      'FP': 359,
#      'precision': 0.9564795732816099,
#      'recall': 0.9564795732816099,
#      'f1_score': 0.9564795732816099,
#      'sensitivity': 0.9564795732816099,
#      'specificity': 0.6046255506607929,
#      'negative_predictive_value': 0.6046255506607929,
#      'false_negative_rate': 0.043520426718390105,
#      'false_positive_rate': 0.39537444933920707,
#      'false_discovery_rate': 0.043520426718390105,
#      'false_omission_rate': 0.39537444933920707,
#      'Positive_likelihood_ratio': 2.4191739625061333,
#      'Negative_likelihood_ratio': 0.07197913927194576,
#      'prevalence_threshold': 0.39133285426370973,
#      'threat_score': 6.22730860299921,
#      'Prevalence': 0.9008408867533035,
#      'Matthews_correlation_coefficient': 7.491298156850448e-08,
#      'Fowlkes_Mallows_index': 1.3830976634219363,
#      'informedness': 0.561105123942403,
#      'markedness': 0.561105123942403,
#      'Diagnostic_odds_ratio': 33.60937609112282,
#      'accuracy': 0.9215900404062466,
#      'balanced_accuracy': 0.7805525619712015},
#     'ROC_AUC_SCORE': {'Macro': 0.7716762494529426,
#      'Micro': 0.7716762494529426,
#      'Weight': 0.7716762494529426},
#     'Classification Report': {'0': {'precision': 0.9564795732816099,
#       'recall': 0.9387269482450922,
#       'f1-score': 0.9475201152876185,
#       'support': 8405},
#      '1': {'precision': 0.5159774436090225,
#       'recall': 0.6046255506607929,
#       'f1-score': 0.5567951318458418,
#       'support': 908},
#      'accuracy': 0.9061526897884677,
#      'macro avg': {'precision': 0.7362285084453162,
#       'recall': 0.7716762494529426,
#       'f1-score': 0.7521576235667302,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9135314433833269,
#       'recall': 0.9061526897884677,
#       'f1-score': 0.9094251636109157,
#       'support': 9313}}},
#    'fold_3': {'Confusion Matrix': {'TP': 7598,
#      'TN': 738,
#      'FN': 178,
#      'FP': 178,
#      'precision': 0.9771090534979424,
#      'recall': 0.9771090534979424,
#      'f1_score': 0.9771090534979424,
#      'sensitivity': 0.9771090534979424,
#      'specificity': 0.8056768558951966,
#      'negative_predictive_value': 0.8056768558951966,
#      'false_negative_rate': 0.022890946502057613,
#      'false_positive_rate': 0.1943231441048035,
#      'false_discovery_rate': 0.022890946502057613,
#      'false_omission_rate': 0.1943231441048035,
#      'Positive_likelihood_ratio': 5.028269061820872,
#      'Negative_likelihood_ratio': 0.02841206910011487,
#      'prevalence_threshold': 0.3084154020835661,
#      'threat_score': 6.9451553930530165,
#      'Prevalence': 0.8946157386102163,
#      'Matthews_correlation_coefficient': 1.098983757818732e-07,
#      'Fowlkes_Mallows_index': 1.3979335130813213,
#      'informedness': 0.7827859093931391,
#      'markedness': 0.7827859093931391,
#      'Diagnostic_odds_ratio': 176.97651811639943,
#      'accuracy': 0.9590427979751496,
#      'balanced_accuracy': 0.8913929546965695},
#     'ROC_AUC_SCORE': {'Macro': 0.8552619125254237,
#      'Micro': 0.8552619125254237,
#      'Weight': 0.8552619125254237},
#     'Classification Report': {'0': {'precision': 0.9771090534979424,
#       'recall': 0.9048469691556509,
#       'f1-score': 0.9395906758177209,
#       'support': 8397},
#      '1': {'precision': 0.4801561483409239,
#       'recall': 0.8056768558951966,
#       'f1-score': 0.6017121891561353,
#       'support': 916},
#      'accuracy': 0.8950928809191453,
#      'macro avg': {'precision': 0.7286326009194332,
#       'recall': 0.8552619125254237,
#       'f1-score': 0.7706514324869281,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9282301894236562,
#       'recall': 0.8950928809191453,
#       'f1-score': 0.9063579158282425,
#       'support': 9313}}},
#    'fold_4': {'Confusion Matrix': {'TP': 7356,
#      'TN': 960,
#      'FN': 365,
#      'FP': 365,
#      'precision': 0.9527263307861676,
#      'recall': 0.9527263307861676,
#      'f1_score': 0.9527263307861676,
#      'sensitivity': 0.9527263307861676,
#      'specificity': 0.7245283018867924,
#      'negative_predictive_value': 0.7245283018867924,
#      'false_negative_rate': 0.04727366921383241,
#      'false_positive_rate': 0.27547169811320754,
#      'false_discovery_rate': 0.04727366921383241,
#      'false_omission_rate': 0.27547169811320754,
#      'Positive_likelihood_ratio': 3.4585270912100605,
#      'Negative_likelihood_ratio': 0.06524751219617494,
#      'prevalence_threshold': 0.3496856163869738,
#      'threat_score': 4.352662721893491,
#      'Prevalence': 0.8535264205173557,
#      'Matthews_correlation_coefficient': 6.620069574260447e-08,
#      'Fowlkes_Mallows_index': 1.3803813464301578,
#      'informedness': 0.67725463267296,
#      'markedness': 0.67725463267296,
#      'Diagnostic_odds_ratio': 53.00626759241883,
#      'accuracy': 0.9193013486623922,
#      'balanced_accuracy': 0.83862731633648},
#     'ROC_AUC_SCORE': {'Macro': 0.8227624606967454,
#      'Micro': 0.8227624606967454,
#      'Weight': 0.8227624606967454},
#     'Classification Report': {'0': {'precision': 0.9527263307861676,
#       'recall': 0.9209966195066984,
#       'f1-score': 0.9365928189457601,
#       'support': 7987},
#      '1': {'precision': 0.6033940917661847,
#       'recall': 0.7245283018867924,
#       'f1-score': 0.6584362139917694,
#       'support': 1325},
#      'accuracy': 0.8930412371134021,
#      'macro avg': {'precision': 0.7780602112761762,
#       'recall': 0.8227624606967454,
#       'f1-score': 0.7975145164687647,
#       'support': 9312},
#      'weighted avg': {'precision': 0.9030200145596344,
#       'recall': 0.8930412371134021,
#       'f1-score': 0.8970140494479039,
#       'support': 9312}}}}},
#  'train_19': {'param': {'penalty': 'l2',
#    'fit_intercept': False,
#    'class_weight': None,
#    'solver': 'saga'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7775,
#      'TN': 340,
#      'FN': 424,
#      'FP': 424,
#      'precision': 0.9482863763873643,
#      'recall': 0.9482863763873643,
#      'f1_score': 0.9482863763873643,
#      'sensitivity': 0.9482863763873643,
#      'specificity': 0.44502617801047123,
#      'negative_predictive_value': 0.44502617801047123,
#      'false_negative_rate': 0.051713623612635685,
#      'false_positive_rate': 0.5549738219895288,
#      'false_discovery_rate': 0.051713623612635685,
#      'false_omission_rate': 0.5549738219895288,
#      'Positive_likelihood_ratio': 1.708704697075345,
#      'Negative_likelihood_ratio': 0.11620355423545195,
#      'prevalence_threshold': 0.433430622164809,
#      'threat_score': 6.544612794612795,
#      'Prevalence': 0.9147606828070959,
#      'Matthews_correlation_coefficient': 6.278899967973292e-08,
#      'Fowlkes_Mallows_index': 1.3771611208477854,
#      'informedness': 0.3933125543978355,
#      'markedness': 0.3933125543978355,
#      'Diagnostic_odds_ratio': 14.70440993236027,
#      'accuracy': 0.9053888207073525,
#      'balanced_accuracy': 0.6966562771989178},
#     'ROC_AUC_SCORE': {'Macro': 0.6772446365546565,
#      'Micro': 0.6772446365546565,
#      'Weight': 0.6772446365546565},
#     'Classification Report': {'0': {'precision': 0.9482863763873643,
#       'recall': 0.9094630950988419,
#       'f1-score': 0.9284690709338429,
#       'support': 8549},
#      '1': {'precision': 0.3052064631956912,
#       'recall': 0.44502617801047123,
#       'f1-score': 0.36208732694355705,
#       'support': 764},
#      'accuracy': 0.8713626114034145,
#      'macro avg': {'precision': 0.6267464197915278,
#       'recall': 0.6772446365546566,
#       'f1-score': 0.6452781989387,
#       'support': 9313},
#      'weighted avg': {'precision': 0.8955307601865228,
#       'recall': 0.8713626114034145,
#       'f1-score': 0.8820054552988619,
#       'support': 9313}}},
#    'fold_1': {'Confusion Matrix': {'TP': 7885,
#      'TN': 405,
#      'FN': 227,
#      'FP': 227,
#      'precision': 0.972016765285996,
#      'recall': 0.972016765285996,
#      'f1_score': 0.972016765285996,
#      'sensitivity': 0.972016765285996,
#      'specificity': 0.6408227848101266,
#      'negative_predictive_value': 0.6408227848101266,
#      'false_negative_rate': 0.027983234714003945,
#      'false_positive_rate': 0.35917721518987344,
#      'false_discovery_rate': 0.027983234714003945,
#      'false_omission_rate': 0.35917721518987344,
#      'Positive_likelihood_ratio': 2.706231698946033,
#      'Negative_likelihood_ratio': 0.043667665035186404,
#      'prevalence_threshold': 0.37806285372973236,
#      'threat_score': 9.179278230500582,
#      'Prevalence': 0.9277218664226898,
#      'Matthews_correlation_coefficient': 1.1953683831737842e-07,
#      'Fowlkes_Mallows_index': 1.3942860289667942,
#      'informedness': 0.6128395500961226,
#      'markedness': 0.6128395500961226,
#      'Diagnostic_odds_ratio': 61.973354809912856,
#      'accuracy': 0.9480786825251601,
#      'balanced_accuracy': 0.8064197750480613},
#     'ROC_AUC_SCORE': {'Macro': 0.7745641397843975,
#      'Micro': 0.7745641397843975,
#      'Weight': 0.7745641397843975},
#     'Classification Report': {'0': {'precision': 0.972016765285996,
#       'recall': 0.9083054947586684,
#       'f1-score': 0.93908176025725,
#       'support': 8681},
#      '1': {'precision': 0.33721898417985013,
#       'recall': 0.6408227848101266,
#       'f1-score': 0.44189852700490995,
#       'support': 632},
#      'accuracy': 0.8901535488027489,
#      'macro avg': {'precision': 0.6546178747329231,
#       'recall': 0.7745641397843974,
#       'f1-score': 0.69049014363108,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9289380368784921,
#       'recall': 0.8901535488027489,
#       'f1-score': 0.9053418479394706,
#       'support': 9313}}},
#    'fold_2': {'Confusion Matrix': {'TP': 7890,
#      'TN': 549,
#      'FN': 359,
#      'FP': 359,
#      'precision': 0.9564795732816099,
#      'recall': 0.9564795732816099,
#      'f1_score': 0.9564795732816099,
#      'sensitivity': 0.9564795732816099,
#      'specificity': 0.6046255506607929,
#      'negative_predictive_value': 0.6046255506607929,
#      'false_negative_rate': 0.043520426718390105,
#      'false_positive_rate': 0.39537444933920707,
#      'false_discovery_rate': 0.043520426718390105,
#      'false_omission_rate': 0.39537444933920707,
#      'Positive_likelihood_ratio': 2.4191739625061333,
#      'Negative_likelihood_ratio': 0.07197913927194576,
#      'prevalence_threshold': 0.39133285426370973,
#      'threat_score': 6.22730860299921,
#      'Prevalence': 0.9008408867533035,
#      'Matthews_correlation_coefficient': 7.491298156850448e-08,
#      'Fowlkes_Mallows_index': 1.3830976634219363,
#      'informedness': 0.561105123942403,
#      'markedness': 0.561105123942403,
#      'Diagnostic_odds_ratio': 33.60937609112282,
#      'accuracy': 0.9215900404062466,
#      'balanced_accuracy': 0.7805525619712015},
#     'ROC_AUC_SCORE': {'Macro': 0.7716762494529426,
#      'Micro': 0.7716762494529426,
#      'Weight': 0.7716762494529426},
#     'Classification Report': {'0': {'precision': 0.9564795732816099,
#       'recall': 0.9387269482450922,
#       'f1-score': 0.9475201152876185,
#       'support': 8405},
#      '1': {'precision': 0.5159774436090225,
#       'recall': 0.6046255506607929,
#       'f1-score': 0.5567951318458418,
#       'support': 908},
#      'accuracy': 0.9061526897884677,
#      'macro avg': {'precision': 0.7362285084453162,
#       'recall': 0.7716762494529426,
#       'f1-score': 0.7521576235667302,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9135314433833269,
#       'recall': 0.9061526897884677,
#       'f1-score': 0.9094251636109157,
#       'support': 9313}}},
#    'fold_3': {'Confusion Matrix': {'TP': 7598,
#      'TN': 738,
#      'FN': 178,
#      'FP': 178,
#      'precision': 0.9771090534979424,
#      'recall': 0.9771090534979424,
#      'f1_score': 0.9771090534979424,
#      'sensitivity': 0.9771090534979424,
#      'specificity': 0.8056768558951966,
#      'negative_predictive_value': 0.8056768558951966,
#      'false_negative_rate': 0.022890946502057613,
#      'false_positive_rate': 0.1943231441048035,
#      'false_discovery_rate': 0.022890946502057613,
#      'false_omission_rate': 0.1943231441048035,
#      'Positive_likelihood_ratio': 5.028269061820872,
#      'Negative_likelihood_ratio': 0.02841206910011487,
#      'prevalence_threshold': 0.3084154020835661,
#      'threat_score': 6.9451553930530165,
#      'Prevalence': 0.8946157386102163,
#      'Matthews_correlation_coefficient': 1.098983757818732e-07,
#      'Fowlkes_Mallows_index': 1.3979335130813213,
#      'informedness': 0.7827859093931391,
#      'markedness': 0.7827859093931391,
#      'Diagnostic_odds_ratio': 176.97651811639943,
#      'accuracy': 0.9590427979751496,
#      'balanced_accuracy': 0.8913929546965695},
#     'ROC_AUC_SCORE': {'Macro': 0.8552619125254237,
#      'Micro': 0.8552619125254237,
#      'Weight': 0.8552619125254237},
#     'Classification Report': {'0': {'precision': 0.9771090534979424,
#       'recall': 0.9048469691556509,
#       'f1-score': 0.9395906758177209,
#       'support': 8397},
#      '1': {'precision': 0.4801561483409239,
#       'recall': 0.8056768558951966,
#       'f1-score': 0.6017121891561353,
#       'support': 916},
#      'accuracy': 0.8950928809191453,
#      'macro avg': {'precision': 0.7286326009194332,
#       'recall': 0.8552619125254237,
#       'f1-score': 0.7706514324869281,
#       'support': 9313},
#      'weighted avg': {'precision': 0.9282301894236562,
#       'recall': 0.8950928809191453,
#       'f1-score': 0.9063579158282425,
#       'support': 9313}}},
#    'fold_4': {'Confusion Matrix': {'TP': 7356,
#      'TN': 960,
#      'FN': 365,
#      'FP': 365,
#      'precision': 0.9527263307861676,
#      'recall': 0.9527263307861676,
#      'f1_score': 0.9527263307861676,
#      'sensitivity': 0.9527263307861676,
#      'specificity': 0.7245283018867924,
#      'negative_predictive_value': 0.7245283018867924,
#      'false_negative_rate': 0.04727366921383241,
#      'false_positive_rate': 0.27547169811320754,
#      'false_discovery_rate': 0.04727366921383241,
#      'false_omission_rate': 0.27547169811320754,
#      'Positive_likelihood_ratio': 3.4585270912100605,
#      'Negative_likelihood_ratio': 0.06524751219617494,
#      'prevalence_threshold': 0.3496856163869738,
#      'threat_score': 4.352662721893491,
#      'Prevalence': 0.8535264205173557,
#      'Matthews_correlation_coefficient': 6.620069574260447e-08,
#      'Fowlkes_Mallows_index': 1.3803813464301578,
#      'informedness': 0.67725463267296,
#      'markedness': 0.67725463267296,
#      'Diagnostic_odds_ratio': 53.00626759241883,
#      'accuracy': 0.9193013486623922,
#      'balanced_accuracy': 0.83862731633648},
#     'ROC_AUC_SCORE': {'Macro': 0.8227624606967454,
#      'Micro': 0.8227624606967454,
#      'Weight': 0.8227624606967454},
#     'Classification Report': {'0': {'precision': 0.9527263307861676,
#       'recall': 0.9209966195066984,
#       'f1-score': 0.9365928189457601,
#       'support': 7987},
#      '1': {'precision': 0.6033940917661847,
#       'recall': 0.7245283018867924,
#       'f1-score': 0.6584362139917694,
#       'support': 1325},
#      'accuracy': 0.8930412371134021,
#      'macro avg': {'precision': 0.7780602112761762,
#       'recall': 0.8227624606967454,
#       'f1-score': 0.7975145164687647,
#       'support': 9312},
#      'weighted avg': {'precision': 0.9030200145596344,
#       'recall': 0.8930412371134021,
#       'f1-score': 0.8970140494479039,
#       'support': 9312}}}}}}
