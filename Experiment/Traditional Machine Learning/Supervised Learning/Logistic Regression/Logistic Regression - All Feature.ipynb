# %%
# Data Manipulation and Representation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import networkx as nx
import json
import pickle

# Mathematics
from random import randint
import math 
import time
from datetime import datetime

# Training Implementation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
import joblib

# Validation Implementation
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Data Preparation

# %%
main_data_dir = "D:/GitCloneProject/Bitcoin-Transaction-Graph-Elliptic-Data-Set/Data/Elliptic Data Set/elliptic_bitcoin_dataset"
features_data_path = main_data_dir + "/elliptic_txs_features.csv"
class_data_path = main_data_dir + "/elliptic_txs_classes.csv"
egdelist_data_path = main_data_dir + "/elliptic_txs_edgelist.csv"

model_path = "Model"

# %%
features_df = pd.read_csv(features_data_path)
classes_df = pd.read_csv(class_data_path)
edges_df = pd.read_csv(egdelist_data_path)

# %%
features_df.head()
# Out:
#    txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  1076         48        -0.168500         0.270909        -0.091383
# 1  2534          6        -0.170834        -0.131425         1.018602
# 2  3181         34         1.305212        -0.210553        -1.756361
# 3  3321          1        -0.169615        -0.184668        -1.201369
# 4  3889         48        -0.086232        -0.101835        -0.646376
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.046932        -0.043875        -0.029140        -0.061584
# 1         0.028105         0.055376         0.054722        -0.061584
# 2        -0.121970        97.300650        -0.113002        -0.061584
# 3        -0.121970        -0.043875        -0.113002        -0.061584
# 4        -0.121970        17.046997        -0.113002        -0.061584
#
#    Local_feature_8  ...  Aggregate_feature_63  Aggregate_feature_64  \
# 0        -0.163591  ...              0.073047             -0.039637
# 1        -0.163572  ...              1.228858              0.379357
# 2         1.348765  ...              1.348450              1.590664
# 3        -0.160199  ...             -0.577099             -0.500080
# 4        -0.074885  ...              0.501062              0.362510
#
#    Aggregate_feature_65  Aggregate_feature_66  Aggregate_feature_67  \
# 0              1.461330              1.461369              0.018279
# 1              0.955101              0.459257             -0.098889
# 2              0.059948              0.113967             -0.098889
# 3              0.241128              0.241406             -0.098889
# 4              0.082065              0.114773             -0.098889
#
#    Aggregate_feature_68  Aggregate_feature_69  Aggregate_feature_70  \
# 0              0.470019              1.216796              1.151607
# 1             -0.087490             -0.099080             -0.122137
# 2              1.969527              0.037532             -0.131010
# 3             -0.087490             -0.084674             -0.140597
# 4              8.948005              1.024948             -0.009570
#
#    Aggregate_feature_71  Aggregate_feature_72
# 0              1.519700              1.521399
# 1             -0.379970             -0.379288
# 2              0.006994              0.017772
# 3              1.519700              1.521399
# 4             -0.080708             -0.123601
#
# [5 rows x 167 columns]

# %%
classes_df.head()
# Out:
#    txId  class
# 0  1076      3
# 1  2534      2
# 2  3181      2
# 3  3321      3
# 4  3889      3

# %%
edges_df.head()
# Out:
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %%
df_class_feature = pd.merge(classes_df, features_df)
df_class_feature.head()
# Out:
#    txId  class  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  1076      3         48        -0.168500         0.270909        -0.091383
# 1  2534      2          6        -0.170834        -0.131425         1.018602
# 2  3181      2         34         1.305212        -0.210553        -1.756361
# 3  3321      3          1        -0.169615        -0.184668        -1.201369
# 4  3889      3         48        -0.086232        -0.101835        -0.646376
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  ...  \
# 0        -0.046932        -0.043875        -0.029140        -0.061584  ...
# 1         0.028105         0.055376         0.054722        -0.061584  ...
# 2        -0.121970        97.300650        -0.113002        -0.061584  ...
# 3        -0.121970        -0.043875        -0.113002        -0.061584  ...
# 4        -0.121970        17.046997        -0.113002        -0.061584  ...
#
#    Aggregate_feature_63  Aggregate_feature_64  Aggregate_feature_65  \
# 0              0.073047             -0.039637              1.461330
# 1              1.228858              0.379357              0.955101
# 2              1.348450              1.590664              0.059948
# 3             -0.577099             -0.500080              0.241128
# 4              0.501062              0.362510              0.082065
#
#    Aggregate_feature_66  Aggregate_feature_67  Aggregate_feature_68  \
# 0              1.461369              0.018279              0.470019
# 1              0.459257             -0.098889             -0.087490
# 2              0.113967             -0.098889              1.969527
# 3              0.241406             -0.098889             -0.087490
# 4              0.114773             -0.098889              8.948005
#
#    Aggregate_feature_69  Aggregate_feature_70  Aggregate_feature_71  \
# 0              1.216796              1.151607              1.519700
# 1             -0.099080             -0.122137             -0.379970
# 2              0.037532             -0.131010              0.006994
# 3             -0.084674             -0.140597              1.519700
# 4              1.024948             -0.009570             -0.080708
#
#    Aggregate_feature_72
# 0              1.521399
# 1             -0.379288
# 2              0.017772
# 3              1.521399
# 4             -0.123601
#
# [5 rows x 168 columns]

# %%
selected_ids = df_class_feature.loc[(df_class_feature['class'] != 3), 'txId']
df_edges_selected = edges_df.loc[edges_df['txId1'].isin(selected_ids)]
df_classes_selected = classes_df.loc[classes_df['txId'].isin(selected_ids)]
df_features_selected = features_df.loc[features_df['txId'].isin(selected_ids)]

# Merge Class and features
df_class_feature_selected = pd.merge(df_classes_selected, df_features_selected )
df_class_feature_selected.head()
# Out:
#    txId  class  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  2534      2          6        -0.170834        -0.131425         1.018602
# 1  3181      2         34         1.305212        -0.210553        -1.756361
# 2  6418      2         48        -0.125229         7.538599         2.128587
# 3  7952      2         48         0.967162        -0.210553        -1.756361
# 4  9351      2         48        -0.172970        -0.114281         1.018602
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  ...  \
# 0         0.028105         0.055376         0.054722        -0.061584  ...
# 1        -0.121970        97.300650        -0.113002        -0.061584  ...
# 2         7.381781         0.095076         7.602324         0.547008  ...
# 3        -0.121970        92.556494        -0.113002        -0.061584  ...
# 4        -0.121970        -0.043875        -0.113002        -0.061584  ...
#
#    Aggregate_feature_63  Aggregate_feature_64  Aggregate_feature_65  \
# 0              1.228858              0.379357              0.955101
# 1              1.348450              1.590664              0.059948
# 2              0.433960              0.168508             -0.197237
# 3              0.823581              0.850443              0.321431
# 4             -0.569626              0.641566              1.461330
#
#    Aggregate_feature_66  Aggregate_feature_67  Aggregate_feature_68  \
# 0              0.459257             -0.098889             -0.087490
# 1              0.113967             -0.098889              1.969527
# 2              0.303447             -0.098889              0.931406
# 3              0.268810             -0.098889              1.162100
# 4              1.461369             -0.098889              0.662264
#
#    Aggregate_feature_69  Aggregate_feature_70  Aggregate_feature_71  \
# 0             -0.099080             -0.122137             -0.379970
# 1              0.037532             -0.131010              0.006994
# 2              1.041565              0.371499              0.790060
# 3              0.485146              0.303509             -0.553520
# 4              1.728088              1.539269              1.519700
#
#    Aggregate_feature_72
# 0             -0.379288
# 1              0.017772
# 2              0.779125
# 3             -0.578865
# 4              1.521399
#
# [5 rows x 168 columns]

# %%
X = df_class_feature_selected.drop(columns=['txId', 'class', 'Time step']) # drop class, text id and time step
y = df_class_feature_selected[['class']]
print(np.unique(y))

# in this case, class 2 corresponds to licit transactions, we chang this to 0 as our interest is the ilicit transactions
y = y['class'].apply(lambda x: 0 if x == 2 else 1 )
print(np.unique(y))
# Out:
# [1 2]
# [0 1]

# %%
print("Feature Shape: ", X.shape)
print("Label Shape: ", y.shape)
# Out:
# Feature Shape:  (46564, 165)
# Label Shape:  (46564,)

# %% [markdown]
# # Utils

# %%
class utils:
    def __init__(self, confusion_matrix, y_true, y_pred):
        """
            - confusion_matrix: 2x2 numpy array
            - y_true: array of label
            - y_pred: array of output value calculated by model
            - fold_count: number of folds
        """
        
        # Initilize all indicator
        self.TP = confusion_matrix[0][0] # true positive
        self.FN = confusion_matrix[1][0] # false negative
        self.FP = confusion_matrix[1][0] # false positive
        self.TN = confusion_matrix[1][1] # true negative
        self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
        self.recall = self.TP / (self.TP + self.FN)
        self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
        self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
        self.specificity = self.TN / (self.TN + self.FP) # False Positive Rate
        self.negative_predictive_value = self.TN / (self.TN + self.FN) # Negative Predictive Value
        self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
        self.false_positive_rate = self.FP / (self.FP + self.TN) # False Positive Rate
        self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
        self.false_omission_rate = self.FN / (self.FN + self.TN) # False Ommision Rate
        self.positive_likelihood_ratio = self.sensitivity / self.false_positive_rate # Positive Likelihood Ratio
        self.negative_likelihood_ratio = self.false_negative_rate / self.specificity # Negative Likelihood Ratio
        self.prevalence_threshold = math.sqrt(self.false_positive_rate) / (math.sqrt(self.sensitivity) + 
                                                                      math.sqrt(self.false_positive_rate)) # Prevalance Threshold
        self.threat_score = self.TP / (self.TN + self.FN + self.FP) # Threat Score
        self.prevalence = (self.TP + self.FN)/(self.TP + self.FN + self.TN + self.FP) # Prevalance 
        #  Matthews correlation coefficient
        self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
                                                                                       *(self.TP + self.FN)
                                                                                       *(self.TN + self.FP)
                                                                                       *(self.TN + self.FN))
        self.fowlkes_mallows_index = math.sqrt(self.sensitivity + self.precision) # Fowlkes–Mallows index
        self.informedness = self.sensitivity + self.specificity - 1 # informedness
        self.markedness = self.precision + self.negative_predictive_value - 1 # markedness
        self.diagnostic_odds_ratio = self.positive_likelihood_ratio / self.negative_likelihood_ratio # Diagnostic odds ratio
        self.accuracy = (self.TP + self.TN) / (self.TP + self.TN + self.FP + self.FN)
        self.balanced_accuracy = (self.sensitivity + self.specificity) / 2
        self.roc_auc_macro = roc_auc_score(y_true, y_pred)
        self.roc_auc_micro = roc_auc_score(y_true, y_pred, average = 'micro')
        self.roc_auc_weighted = roc_auc_score(y_true, y_pred, average = 'weighted')
        self.cls_report = classification_report(y_true, y_pred)
        
        # Initilize the structure of output_dicts
        self.confusion_matrix = {
            "TP" : self.TP,
            "TN" : self.TN,
            "FN" : self.FN,
            "FP" : self.FP,
            "precision" : round(self.precision, 2),
            "recall" : round(self.recall, 2),
            "f1_score" : round(self.f1_score, 2),
            "sensitivity" : round(self.sensitivity, 2),
            "specificity" : round(self.specificity, 2),
            "negative_predictive_value" : round(self.negative_predictive_value, 2),
            "false_negative_rate" : round(self.false_negative_rate, 2),
            "false_positive_rate" : round(self.false_positive_rate, 2),
            "false_discovery_rate" : round(self.false_discovery_rate, 2),
            "false_omission_rate" : round(self.false_omission_rate, 2),
            "Positive_likelihood_ratio" : round(self.positive_likelihood_ratio, 2),
            "Negative_likelihood_ratio" : round(self.negative_likelihood_ratio, 2),
            "prevalence_threshold" : round(self.prevalence_threshold, 2),
            "threat_score" : round(self.threat_score, 2),
            "Prevalence" : round(self.prevalence, 2),
            "Matthews_correlation_coefficient" : round(self.matthews_correlation_coefficient, 2),
            "Fowlkes_Mallows_index" : round(self.fowlkes_mallows_index, 2),
            "informedness" : round(self.informedness, 2),
            "markedness" : round(self.markedness, 2),
            "Diagnostic_odds_ratio" : round(self.diagnostic_odds_ratio, 2),
            "accuracy" : round(self.accuracy, 2),
            "balanced_accuracy" : round(self.balanced_accuracy, 2)
        }
        
        self.roc_auc_score = {
            "Macro": round(self.roc_auc_macro, 2), 
            "Micro": round(self.roc_auc_micro, 2),
            "Weight": round(self.roc_auc_weighted, 2)
        }
        
        self.sub_dict = {
            "Confusion Matrix" : self.confusion_matrix,
            "ROC_AUC_SCORE" : self.roc_auc_score,
            "Classification Report" : classification_report(y_true.tolist(), y_pred.tolist(), 
                                                            labels = [0, 1], # 0 : Licit, 1 : Illicit
                                                            output_dict = True)
        }
    def get_value(self):
        return self.sub_dict
        
# Test 
y_true = np.array([randint(0,1) for x in range(200)])
y_pred = np.array([randint(0,1) for x in range(200)])
confusion_matrix_test = confusion_matrix(y_true, y_pred)
base_utils = utils(confusion_matrix_test, y_true, y_pred)
base_utils.get_value()
# Out:
# {'Confusion Matrix': {'TP': 47,
#   'TN': 45,
#   'FN': 51,
#   'FP': 51,
#   'precision': 0.48,
#   'recall': 0.48,
#   'f1_score': 0.48,
#   'sensitivity': 0.48,
#   'specificity': 0.47,
#   'negative_predictive_value': 0.47,
#   'false_negative_rate': 0.52,
#   'false_positive_rate': 0.53,
#   'false_discovery_rate': 0.52,
#   'false_omission_rate': 0.53,
#   'Positive_likelihood_ratio': 0.9,
#   'Negative_likelihood_ratio': 1.11,
#   'prevalence_threshold': 0.51,
#   'threat_score': 0.32,
#   'Prevalence': 0.51,
#   'Matthews_correlation_coefficient': -0.0,
#   'Fowlkes_Mallows_index': 0.98,
#   'informedness': -0.05,
#   'markedness': -0.05,
#   'Diagnostic_odds_ratio': 0.81,
#   'accuracy': 0.47,
#   'balanced_accuracy': 0.47},
#  'ROC_AUC_SCORE': {'Macro': 0.46, 'Micro': 0.46, 'Weight': 0.46},
#  'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.48      0.45      0.47       104\n           1       0.44      0.47      0.45        96\n\n    accuracy                           0.46       200\n   macro avg       0.46      0.46      0.46       200\nweighted avg       0.46      0.46      0.46       200\n'}

# %% [markdown]
# # Training

# %%
class Training:
    def __init__(self, fold_count, X, y):
        self.fold_count = fold_count
        self.param_grid = {
            "penalty" : ["l2"],
            "fit_intercept" : [True, False],
            "class_weight" : ["balanced", None],
            "solver" : ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
        }
        self.kf = KFold(n_splits=fold_count)
        self.history = {}
        self.X = X
        self.y = y
    
    def get_fold_value(self):
        return self.kf        
        
    def training(self, penalty, fit_intercept, class_weight, solver, njob, train_case):
    
        # output_dict initilize
        output_dict = {}
    
        # poiter track the index of fold
        fold_index = 0
    
        for train_index, test_index in self.kf.split(self.X):
            print("\tFold: {}".format(fold_index))
            print("\tTRAIN:", train_index, "\n\tTEST:", test_index)
        
            # folding data
            X_train, X_test = self.X.values[train_index], self.X.values[test_index]
            y_train, y_test = self.y.values[train_index], self.y.values[test_index]
    
            # Training
            print("\t\tTraining : {}".format(fold_index), end = " -- ")
            print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end=" --- ")
            model_LR = LogisticRegression(penalty = penalty,
                                         fit_intercept = fit_intercept,
                                         class_weight = class_weight,
                                          n_jobs = njob)
            model_LR.fit(X_train,y_train)
            joblib.dump(model_LR, model_path + "/{0}_{1}.joblib".format(train_case, fold_index))
            print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Testing
            print("\t\tValidation: {}".format(fold_index), end = " -- ")
            print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end="---")
            y_pred = model_LR.predict(X_test)
            print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Evaluation
            cm = confusion_matrix(y_test, y_pred)
            current_utils = utils(cm, y_test, y_pred)
            output_dict["fold_{}".format(fold_index)] = current_utils.get_value()
            
            fold_index += 1
        print("\n")
        return output_dict 
    
    def train(self, path):
        count = 0
        for x in self.param_grid["penalty"]:
            for i in self.param_grid["fit_intercept"]:
                for j in self.param_grid["class_weight"]:
                    for k in self.param_grid["solver"]:
                        print("Traning Case: {}".format(count))
                        self.history["train_{}".format(count)] = {
                            "param" : {
                                "penalty" : x,
                                "fit_intercept" : i,
                                "class_weight" : j,
                                "solver" : k,
                            },
                            "train_fold" : self.training(x, i, j, k, 5, count)
                        }
                        count += 1
        with open(path, 'wb') as f:
            pickle.dump(train.history, f)
        
        return self.history

# %%
path = 'LR_AF.pkl'
train = Training(5, X, y)
history = train.train(path)
# Out:
# Traning Case: 0
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:43:52 --- End: 08/06/2022, 14:44:02
# 		Validation: 0 -- Start: 08/06/2022, 14:44:02---End: 08/06/2022, 14:44:02
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:44:02 --- End: 08/06/2022, 14:44:11
# 		Validation: 1 -- Start: 08/06/2022, 14:44:11---End: 08/06/2022, 14:44:11
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:44:11 --- End: 08/06/2022, 14:44:20
# 		Validation: 2 -- Start: 08/06/2022, 14:44:20---End: 08/06/2022, 14:44:20
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:44:20 --- End: 08/06/2022, 14:44:29
# 		Validation: 3 -- Start: 08/06/2022, 14:44:29---End: 08/06/2022, 14:44:29
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:44:29 --- End: 08/06/2022, 14:44:38
# 		Validation: 4 -- Start: 08/06/2022, 14:44:38---End: 08/06/2022, 14:44:38
#
#
# Traning Case: 1
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:44:38 --- End: 08/06/2022, 14:44:47
# 		Validation: 0 -- Start: 08/06/2022, 14:44:47---End: 08/06/2022, 14:44:47
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:44:47 --- End: 08/06/2022, 14:44:54
# 		Validation: 1 -- Start: 08/06/2022, 14:44:54---End: 08/06/2022, 14:44:54
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:44:54 --- End: 08/06/2022, 14:45:03
# 		Validation: 2 -- Start: 08/06/2022, 14:45:03---End: 08/06/2022, 14:45:03
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:45:03 --- End: 08/06/2022, 14:45:12
# 		Validation: 3 -- Start: 08/06/2022, 14:45:12---End: 08/06/2022, 14:45:12
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:45:12 --- End: 08/06/2022, 14:45:20
# 		Validation: 4 -- Start: 08/06/2022, 14:45:20---End: 08/06/2022, 14:45:20
#
#
# Traning Case: 2
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:45:20 --- End: 08/06/2022, 14:45:29
# 		Validation: 0 -- Start: 08/06/2022, 14:45:29---End: 08/06/2022, 14:45:29
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:45:29 --- End: 08/06/2022, 14:45:38
# 		Validation: 1 -- Start: 08/06/2022, 14:45:38---End: 08/06/2022, 14:45:38
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:45:38 --- End: 08/06/2022, 14:45:48
# 		Validation: 2 -- Start: 08/06/2022, 14:45:48---End: 08/06/2022, 14:45:48
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:45:48 --- End: 08/06/2022, 14:45:57
# 		Validation: 3 -- Start: 08/06/2022, 14:45:57---End: 08/06/2022, 14:45:57
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:45:57 --- End: 08/06/2022, 14:46:06
# 		Validation: 4 -- Start: 08/06/2022, 14:46:06---End: 08/06/2022, 14:46:06
#
#
# Traning Case: 3
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:46:06 --- End: 08/06/2022, 14:46:15
# 		Validation: 0 -- Start: 08/06/2022, 14:46:15---End: 08/06/2022, 14:46:15
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:46:15 --- End: 08/06/2022, 14:46:23
# 		Validation: 1 -- Start: 08/06/2022, 14:46:23---End: 08/06/2022, 14:46:23
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:46:23 --- End: 08/06/2022, 14:46:32
# 		Validation: 2 -- Start: 08/06/2022, 14:46:32---End: 08/06/2022, 14:46:32
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:46:32 --- End: 08/06/2022, 14:46:41
# 		Validation: 3 -- Start: 08/06/2022, 14:46:41---End: 08/06/2022, 14:46:41
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:46:41 --- End: 08/06/2022, 14:46:50
# 		Validation: 4 -- Start: 08/06/2022, 14:46:50---End: 08/06/2022, 14:46:50
#
#
# Traning Case: 4
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:46:50 --- End: 08/06/2022, 14:46:59
# 		Validation: 0 -- Start: 08/06/2022, 14:46:59---End: 08/06/2022, 14:46:59
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:46:59 --- End: 08/06/2022, 14:47:08
# 		Validation: 1 -- Start: 08/06/2022, 14:47:08---End: 08/06/2022, 14:47:08
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:47:08 --- End: 08/06/2022, 14:47:16
# 		Validation: 2 -- Start: 08/06/2022, 14:47:16---End: 08/06/2022, 14:47:16
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:47:16 --- End: 08/06/2022, 14:47:25
# 		Validation: 3 -- Start: 08/06/2022, 14:47:25---End: 08/06/2022, 14:47:25
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:47:25 --- End: 08/06/2022, 14:47:36
# 		Validation: 4 -- Start: 08/06/2022, 14:47:36---End: 08/06/2022, 14:47:36
#
#
# Traning Case: 5
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:47:36 --- End: 08/06/2022, 14:47:43
# 		Validation: 0 -- Start: 08/06/2022, 14:47:43---End: 08/06/2022, 14:47:43
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:47:43 --- End: 08/06/2022, 14:47:52
# 		Validation: 1 -- Start: 08/06/2022, 14:47:52---End: 08/06/2022, 14:47:52
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:47:52 --- End: 08/06/2022, 14:48:00
# 		Validation: 2 -- Start: 08/06/2022, 14:48:00---End: 08/06/2022, 14:48:00
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:48:00 --- End: 08/06/2022, 14:48:09
# 		Validation: 3 -- Start: 08/06/2022, 14:48:09---End: 08/06/2022, 14:48:09
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:48:09 --- End: 08/06/2022, 14:48:17
# 		Validation: 4 -- Start: 08/06/2022, 14:48:17---End: 08/06/2022, 14:48:17
#
#
# Traning Case: 6
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:48:17 --- End: 08/06/2022, 14:48:27
# 		Validation: 0 -- Start: 08/06/2022, 14:48:27---End: 08/06/2022, 14:48:27
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:48:27 --- End: 08/06/2022, 14:48:35
# 		Validation: 1 -- Start: 08/06/2022, 14:48:35---End: 08/06/2022, 14:48:35
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:48:35 --- End: 08/06/2022, 14:48:44
# 		Validation: 2 -- Start: 08/06/2022, 14:48:44---End: 08/06/2022, 14:48:44
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:48:44 --- End: 08/06/2022, 14:48:53
# 		Validation: 3 -- Start: 08/06/2022, 14:48:53---End: 08/06/2022, 14:48:53
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:48:53 --- End: 08/06/2022, 14:49:01
# 		Validation: 4 -- Start: 08/06/2022, 14:49:01---End: 08/06/2022, 14:49:01
#
#
# Traning Case: 7
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:49:01 --- End: 08/06/2022, 14:49:10
# 		Validation: 0 -- Start: 08/06/2022, 14:49:10---End: 08/06/2022, 14:49:10
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:49:10 --- End: 08/06/2022, 14:49:18
# 		Validation: 1 -- Start: 08/06/2022, 14:49:18---End: 08/06/2022, 14:49:18
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:49:18 --- End: 08/06/2022, 14:49:27
# 		Validation: 2 -- Start: 08/06/2022, 14:49:27---End: 08/06/2022, 14:49:27
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:49:27 --- End: 08/06/2022, 14:49:36
# 		Validation: 3 -- Start: 08/06/2022, 14:49:36---End: 08/06/2022, 14:49:36
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:49:36 --- End: 08/06/2022, 14:49:44
# 		Validation: 4 -- Start: 08/06/2022, 14:49:44---End: 08/06/2022, 14:49:44
#
#
# Traning Case: 8
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:49:44 --- End: 08/06/2022, 14:49:53
# 		Validation: 0 -- Start: 08/06/2022, 14:49:53---End: 08/06/2022, 14:49:53
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:49:53 --- End: 08/06/2022, 14:50:01
# 		Validation: 1 -- Start: 08/06/2022, 14:50:01---End: 08/06/2022, 14:50:01
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:50:01 --- End: 08/06/2022, 14:50:10
# 		Validation: 2 -- Start: 08/06/2022, 14:50:10---End: 08/06/2022, 14:50:10
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:50:10 --- End: 08/06/2022, 14:50:20
# 		Validation: 3 -- Start: 08/06/2022, 14:50:20---End: 08/06/2022, 14:50:20
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:50:20 --- End: 08/06/2022, 14:50:29
# 		Validation: 4 -- Start: 08/06/2022, 14:50:29---End: 08/06/2022, 14:50:29
#
#
# Traning Case: 9
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:50:29 --- End: 08/06/2022, 14:50:35
# 		Validation: 0 -- Start: 08/06/2022, 14:50:35---End: 08/06/2022, 14:50:35
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:50:36 --- End: 08/06/2022, 14:50:44
# 		Validation: 1 -- Start: 08/06/2022, 14:50:44---End: 08/06/2022, 14:50:44
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:50:44 --- End: 08/06/2022, 14:50:53
# 		Validation: 2 -- Start: 08/06/2022, 14:50:53---End: 08/06/2022, 14:50:53
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:50:53 --- End: 08/06/2022, 14:51:02
# 		Validation: 3 -- Start: 08/06/2022, 14:51:02---End: 08/06/2022, 14:51:02
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:51:02 --- End: 08/06/2022, 14:51:10
# 		Validation: 4 -- Start: 08/06/2022, 14:51:10---End: 08/06/2022, 14:51:10
#
#
# Traning Case: 10
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:51:10 --- End: 08/06/2022, 14:51:19
# 		Validation: 0 -- Start: 08/06/2022, 14:51:19---End: 08/06/2022, 14:51:19
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:51:19 --- End: 08/06/2022, 14:51:28
# 		Validation: 1 -- Start: 08/06/2022, 14:51:28---End: 08/06/2022, 14:51:28
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:51:28 --- End: 08/06/2022, 14:51:38
# 		Validation: 2 -- Start: 08/06/2022, 14:51:38---End: 08/06/2022, 14:51:38
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:51:38 --- End: 08/06/2022, 14:51:47
# 		Validation: 3 -- Start: 08/06/2022, 14:51:47---End: 08/06/2022, 14:51:47
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:51:47 --- End: 08/06/2022, 14:51:54
# 		Validation: 4 -- Start: 08/06/2022, 14:51:54---End: 08/06/2022, 14:51:54
#
#
# Traning Case: 11
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:51:54 --- End: 08/06/2022, 14:52:03
# 		Validation: 0 -- Start: 08/06/2022, 14:52:03---End: 08/06/2022, 14:52:03
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:52:03 --- End: 08/06/2022, 14:52:12
# 		Validation: 1 -- Start: 08/06/2022, 14:52:12---End: 08/06/2022, 14:52:12
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:52:12 --- End: 08/06/2022, 14:52:22
# 		Validation: 2 -- Start: 08/06/2022, 14:52:22---End: 08/06/2022, 14:52:22
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:52:22 --- End: 08/06/2022, 14:52:29
# 		Validation: 3 -- Start: 08/06/2022, 14:52:29---End: 08/06/2022, 14:52:29
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:52:29 --- End: 08/06/2022, 14:52:36
# 		Validation: 4 -- Start: 08/06/2022, 14:52:36---End: 08/06/2022, 14:52:36
#
#
# Traning Case: 12
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:52:36 --- End: 08/06/2022, 14:52:45
# 		Validation: 0 -- Start: 08/06/2022, 14:52:45---End: 08/06/2022, 14:52:45
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:52:45 --- End: 08/06/2022, 14:52:53
# 		Validation: 1 -- Start: 08/06/2022, 14:52:53---End: 08/06/2022, 14:52:53
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:52:53 --- End: 08/06/2022, 14:53:01
# 		Validation: 2 -- Start: 08/06/2022, 14:53:01---End: 08/06/2022, 14:53:01
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:53:01 --- End: 08/06/2022, 14:53:09
# 		Validation: 3 -- Start: 08/06/2022, 14:53:09---End: 08/06/2022, 14:53:09
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:53:09 --- End: 08/06/2022, 14:53:17
# 		Validation: 4 -- Start: 08/06/2022, 14:53:17---End: 08/06/2022, 14:53:17
#
#
# Traning Case: 13
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:53:17 --- End: 08/06/2022, 14:53:26
# 		Validation: 0 -- Start: 08/06/2022, 14:53:26---End: 08/06/2022, 14:53:26
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:53:26 --- End: 08/06/2022, 14:53:33
# 		Validation: 1 -- Start: 08/06/2022, 14:53:33---End: 08/06/2022, 14:53:33
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:53:33 --- End: 08/06/2022, 14:53:41
# 		Validation: 2 -- Start: 08/06/2022, 14:53:41---End: 08/06/2022, 14:53:41
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:53:42 --- End: 08/06/2022, 14:53:50
# 		Validation: 3 -- Start: 08/06/2022, 14:53:50---End: 08/06/2022, 14:53:50
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:53:51 --- End: 08/06/2022, 14:53:58
# 		Validation: 4 -- Start: 08/06/2022, 14:53:58---End: 08/06/2022, 14:53:58
#
#
# Traning Case: 14
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:53:58 --- End: 08/06/2022, 14:54:06
# 		Validation: 0 -- Start: 08/06/2022, 14:54:06---End: 08/06/2022, 14:54:06
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:54:06 --- End: 08/06/2022, 14:54:15
# 		Validation: 1 -- Start: 08/06/2022, 14:54:15---End: 08/06/2022, 14:54:15
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:54:15 --- End: 08/06/2022, 14:54:24
# 		Validation: 2 -- Start: 08/06/2022, 14:54:24---End: 08/06/2022, 14:54:24
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:54:24 --- End: 08/06/2022, 14:54:33
# 		Validation: 3 -- Start: 08/06/2022, 14:54:33---End: 08/06/2022, 14:54:33
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:54:33 --- End: 08/06/2022, 14:54:43
# 		Validation: 4 -- Start: 08/06/2022, 14:54:43---End: 08/06/2022, 14:54:43
#
#
# Traning Case: 15
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:54:43 --- End: 08/06/2022, 14:54:50
# 		Validation: 0 -- Start: 08/06/2022, 14:54:50---End: 08/06/2022, 14:54:50
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:54:50 --- End: 08/06/2022, 14:54:59
# 		Validation: 1 -- Start: 08/06/2022, 14:54:59---End: 08/06/2022, 14:54:59
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:54:59 --- End: 08/06/2022, 14:55:09
# 		Validation: 2 -- Start: 08/06/2022, 14:55:09---End: 08/06/2022, 14:55:09
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:55:09 --- End: 08/06/2022, 14:55:18
# 		Validation: 3 -- Start: 08/06/2022, 14:55:18---End: 08/06/2022, 14:55:18
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:55:18 --- End: 08/06/2022, 14:55:27
# 		Validation: 4 -- Start: 08/06/2022, 14:55:27---End: 08/06/2022, 14:55:27
#
#
# Traning Case: 16
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:55:27 --- End: 08/06/2022, 14:55:36
# 		Validation: 0 -- Start: 08/06/2022, 14:55:36---End: 08/06/2022, 14:55:36
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:55:36 --- End: 08/06/2022, 14:55:44
# 		Validation: 1 -- Start: 08/06/2022, 14:55:44---End: 08/06/2022, 14:55:44
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:55:44 --- End: 08/06/2022, 14:55:53
# 		Validation: 2 -- Start: 08/06/2022, 14:55:53---End: 08/06/2022, 14:55:53
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:55:53 --- End: 08/06/2022, 14:56:02
# 		Validation: 3 -- Start: 08/06/2022, 14:56:02---End: 08/06/2022, 14:56:02
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:56:02 --- End: 08/06/2022, 14:56:11
# 		Validation: 4 -- Start: 08/06/2022, 14:56:11---End: 08/06/2022, 14:56:11
#
#
# Traning Case: 17
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:56:11 --- End: 08/06/2022, 14:56:20
# 		Validation: 0 -- Start: 08/06/2022, 14:56:20---End: 08/06/2022, 14:56:20
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:56:20 --- End: 08/06/2022, 14:56:28
# 		Validation: 1 -- Start: 08/06/2022, 14:56:28---End: 08/06/2022, 14:56:28
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:56:28 --- End: 08/06/2022, 14:56:37
# 		Validation: 2 -- Start: 08/06/2022, 14:56:37---End: 08/06/2022, 14:56:37
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:56:37 --- End: 08/06/2022, 14:56:46
# 		Validation: 3 -- Start: 08/06/2022, 14:56:46---End: 08/06/2022, 14:56:46
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:56:46 --- End: 08/06/2022, 14:56:54
# 		Validation: 4 -- Start: 08/06/2022, 14:56:54---End: 08/06/2022, 14:56:54
#
#
# Traning Case: 18
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:56:55 --- End: 08/06/2022, 14:57:02
# 		Validation: 0 -- Start: 08/06/2022, 14:57:02---End: 08/06/2022, 14:57:02
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:57:02 --- End: 08/06/2022, 14:57:10
# 		Validation: 1 -- Start: 08/06/2022, 14:57:10---End: 08/06/2022, 14:57:10
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:57:10 --- End: 08/06/2022, 14:57:19
# 		Validation: 2 -- Start: 08/06/2022, 14:57:19---End: 08/06/2022, 14:57:19
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:57:19 --- End: 08/06/2022, 14:57:29
# 		Validation: 3 -- Start: 08/06/2022, 14:57:29---End: 08/06/2022, 14:57:29
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:57:29 --- End: 08/06/2022, 14:57:37
# 		Validation: 4 -- Start: 08/06/2022, 14:57:37---End: 08/06/2022, 14:57:37
#
#
# Traning Case: 19
# 	Fold: 0
# 	TRAIN: [ 9313  9314  9315 ... 46561 46562 46563]
# 	TEST: [   0    1    2 ... 9310 9311 9312]
# 		Training : 0 -- Start: 08/06/2022, 14:57:37 --- End: 08/06/2022, 14:57:46
# 		Validation: 0 -- Start: 08/06/2022, 14:57:46---End: 08/06/2022, 14:57:46
# 	Fold: 1
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# 		Training : 1 -- Start: 08/06/2022, 14:57:46 --- End: 08/06/2022, 14:57:54
# 		Validation: 1 -- Start: 08/06/2022, 14:57:54---End: 08/06/2022, 14:57:54
# 	Fold: 2
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [18626 18627 18628 ... 27936 27937 27938]
# 		Training : 2 -- Start: 08/06/2022, 14:57:54 --- End: 08/06/2022, 14:58:04
# 		Validation: 2 -- Start: 08/06/2022, 14:58:04---End: 08/06/2022, 14:58:04
# 	Fold: 3
# 	TRAIN: [    0     1     2 ... 46561 46562 46563]
# 	TEST: [27939 27940 27941 ... 37249 37250 37251]
# 		Training : 3 -- Start: 08/06/2022, 14:58:04 --- End: 08/06/2022, 14:58:14
# 		Validation: 3 -- Start: 08/06/2022, 14:58:14---End: 08/06/2022, 14:58:14
# 	Fold: 4
# 	TRAIN: [    0     1     2 ... 37249 37250 37251]
# 	TEST: [37252 37253 37254 ... 46561 46562 46563]
# 		Training : 4 -- Start: 08/06/2022, 14:58:15 --- End: 08/06/2022, 14:58:25
# 		Validation: 4 -- Start: 08/06/2022, 14:58:25---End: 08/06/2022, 14:58:25

# %%
with open(path, 'rb') as f:
    loaded_dict = pickle.load(f)
loaded_dict
# Out:
# {'train_0': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'newton-cg'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.59,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 9.27,
#      'Prevalence': 0.91,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.93,
#      'markedness': 0.93,
#      'Diagnostic_odds_ratio': 1992.49,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.91, 'Micro': 0.91, 'Weight': 0.91},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.89      0.94      8549\n           1       0.42      0.93      0.58       764\n\n    accuracy                           0.89      9313\n   macro avg       0.71      0.91      0.76      9313\nweighted avg       0.95      0.89      0.91      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.84,
#      'negative_predictive_value': 0.84,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.16,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.16,
#      'Positive_likelihood_ratio': 6.3,
#      'Negative_likelihood_ratio': 0.02,
#      'prevalence_threshold': 0.28,
#      'threat_score': 10.15,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.83,
#      'markedness': 0.83,
#      'Diagnostic_odds_ratio': 403.35,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.92},
#     'ROC_AUC_SCORE': {'Macro': 0.85, 'Micro': 0.85, 'Weight': 0.85},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.85      0.92      8681\n           1       0.30      0.84      0.44       632\n\n    accuracy                           0.85      9313\n   macro avg       0.64      0.85      0.68      9313\nweighted avg       0.94      0.85      0.88      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.29,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 7.43,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.92,
#      'markedness': 0.92,
#      'Diagnostic_odds_ratio': 1535.65,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.89, 'Micro': 0.89, 'Weight': 0.89},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8405\n           1       0.41      0.93      0.57       908\n\n    accuracy                           0.87      9313\n   macro avg       0.70      0.89      0.75      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.95,
#      'negative_predictive_value': 0.95,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.05,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.05,
#      'Positive_likelihood_ratio': 18.96,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.19,
#      'threat_score': 7.51,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.94,
#      'markedness': 0.94,
#      'Diagnostic_odds_ratio': 2726.44,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.97},
#     'ROC_AUC_SCORE': {'Macro': 0.9, 'Micro': 0.9, 'Weight': 0.9},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8397\n           1       0.43      0.95      0.59       916\n\n    accuracy                           0.87      9313\n   macro avg       0.71      0.90      0.76      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 1.0,
#      'recall': 1.0,
#      'f1_score': 1.0,
#      'sensitivity': 1.0,
#      'specificity': 0.97,
#      'negative_predictive_value': 0.97,
#      'false_negative_rate': 0.0,
#      'false_positive_rate': 0.03,
#      'false_discovery_rate': 0.0,
#      'false_omission_rate': 0.03,
#      'Positive_likelihood_ratio': 38.78,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.14,
#      'threat_score': 5.1,
#      'Prevalence': 0.84,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.97,
#      'markedness': 0.97,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.98},
#     'ROC_AUC_SCORE': {'Macro': 0.92, 'Micro': 0.92, 'Weight': 0.92},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       1.00      0.87      0.93      7987\n           1       0.55      0.97      0.70      1325\n\n    accuracy                           0.88      9312\n   macro avg       0.77      0.92      0.82      9312\nweighted avg       0.93      0.88      0.90      9312\n'}}},
#  'train_1': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'lbfgs'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.59,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 9.27,
#      'Prevalence': 0.91,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.93,
#      'markedness': 0.93,
#      'Diagnostic_odds_ratio': 1992.49,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.91, 'Micro': 0.91, 'Weight': 0.91},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.89      0.94      8549\n           1       0.42      0.93      0.58       764\n\n    accuracy                           0.89      9313\n   macro avg       0.71      0.91      0.76      9313\nweighted avg       0.95      0.89      0.91      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.84,
#      'negative_predictive_value': 0.84,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.16,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.16,
#      'Positive_likelihood_ratio': 6.3,
#      'Negative_likelihood_ratio': 0.02,
#      'prevalence_threshold': 0.28,
#      'threat_score': 10.15,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.83,
#      'markedness': 0.83,
#      'Diagnostic_odds_ratio': 403.35,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.92},
#     'ROC_AUC_SCORE': {'Macro': 0.85, 'Micro': 0.85, 'Weight': 0.85},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.85      0.92      8681\n           1       0.30      0.84      0.44       632\n\n    accuracy                           0.85      9313\n   macro avg       0.64      0.85      0.68      9313\nweighted avg       0.94      0.85      0.88      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.29,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 7.43,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.92,
#      'markedness': 0.92,
#      'Diagnostic_odds_ratio': 1535.65,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.89, 'Micro': 0.89, 'Weight': 0.89},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8405\n           1       0.41      0.93      0.57       908\n\n    accuracy                           0.87      9313\n   macro avg       0.70      0.89      0.75      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.95,
#      'negative_predictive_value': 0.95,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.05,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.05,
#      'Positive_likelihood_ratio': 18.96,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.19,
#      'threat_score': 7.51,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.94,
#      'markedness': 0.94,
#      'Diagnostic_odds_ratio': 2726.44,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.97},
#     'ROC_AUC_SCORE': {'Macro': 0.9, 'Micro': 0.9, 'Weight': 0.9},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8397\n           1       0.43      0.95      0.59       916\n\n    accuracy                           0.87      9313\n   macro avg       0.71      0.90      0.76      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 1.0,
#      'recall': 1.0,
#      'f1_score': 1.0,
#      'sensitivity': 1.0,
#      'specificity': 0.97,
#      'negative_predictive_value': 0.97,
#      'false_negative_rate': 0.0,
#      'false_positive_rate': 0.03,
#      'false_discovery_rate': 0.0,
#      'false_omission_rate': 0.03,
#      'Positive_likelihood_ratio': 38.78,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.14,
#      'threat_score': 5.1,
#      'Prevalence': 0.84,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.97,
#      'markedness': 0.97,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.98},
#     'ROC_AUC_SCORE': {'Macro': 0.92, 'Micro': 0.92, 'Weight': 0.92},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       1.00      0.87      0.93      7987\n           1       0.55      0.97      0.70      1325\n\n    accuracy                           0.88      9312\n   macro avg       0.77      0.92      0.82      9312\nweighted avg       0.93      0.88      0.90      9312\n'}}},
#  'train_2': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'liblinear'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.59,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 9.27,
#      'Prevalence': 0.91,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.93,
#      'markedness': 0.93,
#      'Diagnostic_odds_ratio': 1992.49,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.91, 'Micro': 0.91, 'Weight': 0.91},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.89      0.94      8549\n           1       0.42      0.93      0.58       764\n\n    accuracy                           0.89      9313\n   macro avg       0.71      0.91      0.76      9313\nweighted avg       0.95      0.89      0.91      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.84,
#      'negative_predictive_value': 0.84,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.16,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.16,
#      'Positive_likelihood_ratio': 6.3,
#      'Negative_likelihood_ratio': 0.02,
#      'prevalence_threshold': 0.28,
#      'threat_score': 10.15,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.83,
#      'markedness': 0.83,
#      'Diagnostic_odds_ratio': 403.35,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.92},
#     'ROC_AUC_SCORE': {'Macro': 0.85, 'Micro': 0.85, 'Weight': 0.85},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.85      0.92      8681\n           1       0.30      0.84      0.44       632\n\n    accuracy                           0.85      9313\n   macro avg       0.64      0.85      0.68      9313\nweighted avg       0.94      0.85      0.88      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.29,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 7.43,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.92,
#      'markedness': 0.92,
#      'Diagnostic_odds_ratio': 1535.65,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.89, 'Micro': 0.89, 'Weight': 0.89},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8405\n           1       0.41      0.93      0.57       908\n\n    accuracy                           0.87      9313\n   macro avg       0.70      0.89      0.75      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.95,
#      'negative_predictive_value': 0.95,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.05,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.05,
#      'Positive_likelihood_ratio': 18.96,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.19,
#      'threat_score': 7.51,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.94,
#      'markedness': 0.94,
#      'Diagnostic_odds_ratio': 2726.44,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.97},
#     'ROC_AUC_SCORE': {'Macro': 0.9, 'Micro': 0.9, 'Weight': 0.9},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8397\n           1       0.43      0.95      0.59       916\n\n    accuracy                           0.87      9313\n   macro avg       0.71      0.90      0.76      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 1.0,
#      'recall': 1.0,
#      'f1_score': 1.0,
#      'sensitivity': 1.0,
#      'specificity': 0.97,
#      'negative_predictive_value': 0.97,
#      'false_negative_rate': 0.0,
#      'false_positive_rate': 0.03,
#      'false_discovery_rate': 0.0,
#      'false_omission_rate': 0.03,
#      'Positive_likelihood_ratio': 38.78,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.14,
#      'threat_score': 5.1,
#      'Prevalence': 0.84,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.97,
#      'markedness': 0.97,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.98},
#     'ROC_AUC_SCORE': {'Macro': 0.92, 'Micro': 0.92, 'Weight': 0.92},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       1.00      0.87      0.93      7987\n           1       0.55      0.97      0.70      1325\n\n    accuracy                           0.88      9312\n   macro avg       0.77      0.92      0.82      9312\nweighted avg       0.93      0.88      0.90      9312\n'}}},
#  'train_3': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'sag'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.59,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 9.27,
#      'Prevalence': 0.91,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.93,
#      'markedness': 0.93,
#      'Diagnostic_odds_ratio': 1992.49,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.91, 'Micro': 0.91, 'Weight': 0.91},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.89      0.94      8549\n           1       0.42      0.93      0.58       764\n\n    accuracy                           0.89      9313\n   macro avg       0.71      0.91      0.76      9313\nweighted avg       0.95      0.89      0.91      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.84,
#      'negative_predictive_value': 0.84,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.16,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.16,
#      'Positive_likelihood_ratio': 6.3,
#      'Negative_likelihood_ratio': 0.02,
#      'prevalence_threshold': 0.28,
#      'threat_score': 10.15,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.83,
#      'markedness': 0.83,
#      'Diagnostic_odds_ratio': 403.35,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.92},
#     'ROC_AUC_SCORE': {'Macro': 0.85, 'Micro': 0.85, 'Weight': 0.85},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.85      0.92      8681\n           1       0.30      0.84      0.44       632\n\n    accuracy                           0.85      9313\n   macro avg       0.64      0.85      0.68      9313\nweighted avg       0.94      0.85      0.88      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.29,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 7.43,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.92,
#      'markedness': 0.92,
#      'Diagnostic_odds_ratio': 1535.65,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.89, 'Micro': 0.89, 'Weight': 0.89},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8405\n           1       0.41      0.93      0.57       908\n\n    accuracy                           0.87      9313\n   macro avg       0.70      0.89      0.75      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.95,
#      'negative_predictive_value': 0.95,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.05,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.05,
#      'Positive_likelihood_ratio': 18.96,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.19,
#      'threat_score': 7.51,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.94,
#      'markedness': 0.94,
#      'Diagnostic_odds_ratio': 2726.44,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.97},
#     'ROC_AUC_SCORE': {'Macro': 0.9, 'Micro': 0.9, 'Weight': 0.9},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8397\n           1       0.43      0.95      0.59       916\n\n    accuracy                           0.87      9313\n   macro avg       0.71      0.90      0.76      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 1.0,
#      'recall': 1.0,
#      'f1_score': 1.0,
#      'sensitivity': 1.0,
#      'specificity': 0.97,
#      'negative_predictive_value': 0.97,
#      'false_negative_rate': 0.0,
#      'false_positive_rate': 0.03,
#      'false_discovery_rate': 0.0,
#      'false_omission_rate': 0.03,
#      'Positive_likelihood_ratio': 38.78,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.14,
#      'threat_score': 5.1,
#      'Prevalence': 0.84,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.97,
#      'markedness': 0.97,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.98},
#     'ROC_AUC_SCORE': {'Macro': 0.92, 'Micro': 0.92, 'Weight': 0.92},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       1.00      0.87      0.93      7987\n           1       0.55      0.97      0.70      1325\n\n    accuracy                           0.88      9312\n   macro avg       0.77      0.92      0.82      9312\nweighted avg       0.93      0.88      0.90      9312\n'}}},
#  'train_4': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'saga'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7567,
#      'TN': 712,
#      'FN': 52,
#      'FP': 52,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.59,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 9.27,
#      'Prevalence': 0.91,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.93,
#      'markedness': 0.93,
#      'Diagnostic_odds_ratio': 1992.49,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.91, 'Micro': 0.91, 'Weight': 0.91},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.89      0.94      8549\n           1       0.42      0.93      0.58       764\n\n    accuracy                           0.89      9313\n   macro avg       0.71      0.91      0.76      9313\nweighted avg       0.95      0.89      0.91      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 7417,
#      'TN': 533,
#      'FN': 99,
#      'FP': 99,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.84,
#      'negative_predictive_value': 0.84,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.16,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.16,
#      'Positive_likelihood_ratio': 6.3,
#      'Negative_likelihood_ratio': 0.02,
#      'prevalence_threshold': 0.28,
#      'threat_score': 10.15,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.83,
#      'markedness': 0.83,
#      'Diagnostic_odds_ratio': 403.35,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.92},
#     'ROC_AUC_SCORE': {'Macro': 0.85, 'Micro': 0.85, 'Weight': 0.85},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.85      0.92      8681\n           1       0.30      0.84      0.44       632\n\n    accuracy                           0.85      9313\n   macro avg       0.64      0.85      0.68      9313\nweighted avg       0.94      0.85      0.88      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 7213,
#      'TN': 845,
#      'FN': 63,
#      'FP': 63,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.93,
#      'negative_predictive_value': 0.93,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.07,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.07,
#      'Positive_likelihood_ratio': 14.29,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.21,
#      'threat_score': 7.43,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.92,
#      'markedness': 0.92,
#      'Diagnostic_odds_ratio': 1535.65,
#      'accuracy': 0.98,
#      'balanced_accuracy': 0.96},
#     'ROC_AUC_SCORE': {'Macro': 0.89, 'Micro': 0.89, 'Weight': 0.89},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8405\n           1       0.41      0.93      0.57       908\n\n    accuracy                           0.87      9313\n   macro avg       0.70      0.89      0.75      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7237,
#      'TN': 868,
#      'FN': 48,
#      'FP': 48,
#      'precision': 0.99,
#      'recall': 0.99,
#      'f1_score': 0.99,
#      'sensitivity': 0.99,
#      'specificity': 0.95,
#      'negative_predictive_value': 0.95,
#      'false_negative_rate': 0.01,
#      'false_positive_rate': 0.05,
#      'false_discovery_rate': 0.01,
#      'false_omission_rate': 0.05,
#      'Positive_likelihood_ratio': 18.96,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.19,
#      'threat_score': 7.51,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.94,
#      'markedness': 0.94,
#      'Diagnostic_odds_ratio': 2726.44,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.97},
#     'ROC_AUC_SCORE': {'Macro': 0.9, 'Micro': 0.9, 'Weight': 0.9},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.99      0.86      0.92      8397\n           1       0.43      0.95      0.59       916\n\n    accuracy                           0.87      9313\n   macro avg       0.71      0.90      0.76      9313\nweighted avg       0.94      0.87      0.89      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 6936,
#      'TN': 1291,
#      'FN': 34,
#      'FP': 34,
#      'precision': 1.0,
#      'recall': 1.0,
#      'f1_score': 1.0,
#      'sensitivity': 1.0,
#      'specificity': 0.97,
#      'negative_predictive_value': 0.97,
#      'false_negative_rate': 0.0,
#      'false_positive_rate': 0.03,
#      'false_discovery_rate': 0.0,
#      'false_omission_rate': 0.03,
#      'Positive_likelihood_ratio': 38.78,
#      'Negative_likelihood_ratio': 0.01,
#      'prevalence_threshold': 0.14,
#      'threat_score': 5.1,
#      'Prevalence': 0.84,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.41,
#      'informedness': 0.97,
#      'markedness': 0.97,
#      'Diagnostic_odds_ratio': 7746.0,
#      'accuracy': 0.99,
#      'balanced_accuracy': 0.98},
#     'ROC_AUC_SCORE': {'Macro': 0.92, 'Micro': 0.92, 'Weight': 0.92},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       1.00      0.87      0.93      7987\n           1       0.55      0.97      0.70      1325\n\n    accuracy                           0.88      9312\n   macro avg       0.77      0.92      0.82      9312\nweighted avg       0.93      0.88      0.90      9312\n'}}},
#  'train_5': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': None,
#    'solver': 'newton-cg'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 8394,
#      'TN': 534,
#      'FN': 230,
#      'FP': 230,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.7,
#      'negative_predictive_value': 0.7,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.3,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.3,
#      'Positive_likelihood_ratio': 3.23,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.36,
#      'threat_score': 8.44,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.67,
#      'markedness': 0.67,
#      'Diagnostic_odds_ratio': 84.73,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.84},
#     'ROC_AUC_SCORE': {'Macro': 0.84, 'Micro': 0.84, 'Weight': 0.84},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.98      0.98      8549\n           1       0.78      0.70      0.74       764\n\n    accuracy                           0.96      9313\n   macro avg       0.87      0.84      0.86      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 8496,
#      'TN': 421,
#      'FN': 211,
#      'FP': 211,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.67,
#      'negative_predictive_value': 0.67,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.33,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.33,
#      'Positive_likelihood_ratio': 2.92,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.37,
#      'threat_score': 10.08,
#      'Prevalence': 0.93,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.64,
#      'markedness': 0.64,
#      'Diagnostic_odds_ratio': 80.34,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.82},
#     'ROC_AUC_SCORE': {'Macro': 0.82, 'Micro': 0.82, 'Weight': 0.82},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      8681\n           1       0.69      0.67      0.68       632\n\n    accuracy                           0.96      9313\n   macro avg       0.84      0.82      0.83      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 8248,
#      'TN': 632,
#      'FN': 276,
#      'FP': 276,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.7,
#      'negative_predictive_value': 0.7,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.3,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.3,
#      'Positive_likelihood_ratio': 3.18,
#      'Negative_likelihood_ratio': 0.05,
#      'prevalence_threshold': 0.36,
#      'threat_score': 6.97,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.39,
#      'informedness': 0.66,
#      'markedness': 0.66,
#      'Diagnostic_odds_ratio': 68.43,
#      'accuracy': 0.94,
#      'balanced_accuracy': 0.83},
#     'ROC_AUC_SCORE': {'Macro': 0.84, 'Micro': 0.84, 'Weight': 0.84},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.98      0.97      8405\n           1       0.80      0.70      0.74       908\n\n    accuracy                           0.95      9313\n   macro avg       0.88      0.84      0.86      9313\nweighted avg       0.95      0.95      0.95      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 8233,
#      'TN': 725,
#      'FN': 191,
#      'FP': 191,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.79,
#      'negative_predictive_value': 0.79,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.21,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.21,
#      'Positive_likelihood_ratio': 4.69,
#      'Negative_likelihood_ratio': 0.03,
#      'prevalence_threshold': 0.32,
#      'threat_score': 7.44,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.77,
#      'markedness': 0.77,
#      'Diagnostic_odds_ratio': 163.62,
#      'accuracy': 0.96,
#      'balanced_accuracy': 0.88},
#     'ROC_AUC_SCORE': {'Macro': 0.89, 'Micro': 0.89, 'Weight': 0.89},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      8397\n           1       0.82      0.79      0.80       916\n\n    accuracy                           0.96      9313\n   macro avg       0.90      0.89      0.89      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 7861,
#      'TN': 1005,
#      'FN': 320,
#      'FP': 320,
#      'precision': 0.96,
#      'recall': 0.96,
#      'f1_score': 0.96,
#      'sensitivity': 0.96,
#      'specificity': 0.76,
#      'negative_predictive_value': 0.76,
#      'false_negative_rate': 0.04,
#      'false_positive_rate': 0.24,
#      'false_discovery_rate': 0.04,
#      'false_omission_rate': 0.24,
#      'Positive_likelihood_ratio': 3.98,
#      'Negative_likelihood_ratio': 0.05,
#      'prevalence_threshold': 0.33,
#      'threat_score': 4.78,
#      'Prevalence': 0.86,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.39,
#      'informedness': 0.72,
#      'markedness': 0.72,
#      'Diagnostic_odds_ratio': 77.15,
#      'accuracy': 0.93,
#      'balanced_accuracy': 0.86},
#     'ROC_AUC_SCORE': {'Macro': 0.87, 'Micro': 0.87, 'Weight': 0.87},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.96      0.98      0.97      7987\n           1       0.89      0.76      0.82      1325\n\n    accuracy                           0.95      9312\n   macro avg       0.92      0.87      0.90      9312\nweighted avg       0.95      0.95      0.95      9312\n'}}},
#  'train_6': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': None,
#    'solver': 'lbfgs'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 8394,
#      'TN': 534,
#      'FN': 230,
#      'FP': 230,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.7,
#      'negative_predictive_value': 0.7,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.3,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.3,
#      'Positive_likelihood_ratio': 3.23,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.36,
#      'threat_score': 8.44,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.67,
#      'markedness': 0.67,
#      'Diagnostic_odds_ratio': 84.73,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.84},
#     'ROC_AUC_SCORE': {'Macro': 0.84, 'Micro': 0.84, 'Weight': 0.84},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.98      0.98      8549\n           1       0.78      0.70      0.74       764\n\n    accuracy                           0.96      9313\n   macro avg       0.87      0.84      0.86      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 8496,
#      'TN': 421,
#      'FN': 211,
#      'FP': 211,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.67,
#      'negative_predictive_value': 0.67,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.33,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.33,
#      'Positive_likelihood_ratio': 2.92,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.37,
#      'threat_score': 10.08,
#      'Prevalence': 0.93,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.64,
#      'markedness': 0.64,
#      'Diagnostic_odds_ratio': 80.34,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.82},
#     'ROC_AUC_SCORE': {'Macro': 0.82, 'Micro': 0.82, 'Weight': 0.82},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      8681\n           1       0.69      0.67      0.68       632\n\n    accuracy                           0.96      9313\n   macro avg       0.84      0.82      0.83      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 8248,
#      'TN': 632,
#      'FN': 276,
#      'FP': 276,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.7,
#      'negative_predictive_value': 0.7,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.3,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.3,
#      'Positive_likelihood_ratio': 3.18,
#      'Negative_likelihood_ratio': 0.05,
#      'prevalence_threshold': 0.36,
#      'threat_score': 6.97,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.39,
#      'informedness': 0.66,
#      'markedness': 0.66,
#      'Diagnostic_odds_ratio': 68.43,
#      'accuracy': 0.94,
#      'balanced_accuracy': 0.83},
#     'ROC_AUC_SCORE': {'Macro': 0.84, 'Micro': 0.84, 'Weight': 0.84},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.98      0.97      8405\n           1       0.80      0.70      0.74       908\n\n    accuracy                           0.95      9313\n   macro avg       0.88      0.84      0.86      9313\nweighted avg       0.95      0.95      0.95      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 8233,
#      'TN': 725,
#      'FN': 191,
#      'FP': 191,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.79,
#      'negative_predictive_value': 0.79,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.21,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.21,
#      'Positive_likelihood_ratio': 4.69,
#      'Negative_likelihood_ratio': 0.03,
#      'prevalence_threshold': 0.32,
#      'threat_score': 7.44,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.77,
#      'markedness': 0.77,
#      'Diagnostic_odds_ratio': 163.62,
#      'accuracy': 0.96,
#      'balanced_accuracy': 0.88},
#     'ROC_AUC_SCORE': {'Macro': 0.89, 'Micro': 0.89, 'Weight': 0.89},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      8397\n           1       0.82      0.79      0.80       916\n\n    accuracy                           0.96      9313\n   macro avg       0.90      0.89      0.89      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 7861,
#      'TN': 1005,
#      'FN': 320,
#      'FP': 320,
#      'precision': 0.96,
#      'recall': 0.96,
#      'f1_score': 0.96,
#      'sensitivity': 0.96,
#      'specificity': 0.76,
#      'negative_predictive_value': 0.76,
#      'false_negative_rate': 0.04,
#      'false_positive_rate': 0.24,
#      'false_discovery_rate': 0.04,
#      'false_omission_rate': 0.24,
#      'Positive_likelihood_ratio': 3.98,
#      'Negative_likelihood_ratio': 0.05,
#      'prevalence_threshold': 0.33,
#      'threat_score': 4.78,
#      'Prevalence': 0.86,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.39,
#      'informedness': 0.72,
#      'markedness': 0.72,
#      'Diagnostic_odds_ratio': 77.15,
#      'accuracy': 0.93,
#      'balanced_accuracy': 0.86},
#     'ROC_AUC_SCORE': {'Macro': 0.87, 'Micro': 0.87, 'Weight': 0.87},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.96      0.98      0.97      7987\n           1       0.89      0.76      0.82      1325\n\n    accuracy                           0.95      9312\n   macro avg       0.92      0.87      0.90      9312\nweighted avg       0.95      0.95      0.95      9312\n'}}},
#  'train_7': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': None,
#    'solver': 'liblinear'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 8394,
#      'TN': 534,
#      'FN': 230,
#      'FP': 230,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.7,
#      'negative_predictive_value': 0.7,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.3,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.3,
#      'Positive_likelihood_ratio': 3.23,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.36,
#      'threat_score': 8.44,
#      'Prevalence': 0.92,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.67,
#      'markedness': 0.67,
#      'Diagnostic_odds_ratio': 84.73,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.84},
#     'ROC_AUC_SCORE': {'Macro': 0.84, 'Micro': 0.84, 'Weight': 0.84},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.98      0.98      8549\n           1       0.78      0.70      0.74       764\n\n    accuracy                           0.96      9313\n   macro avg       0.87      0.84      0.86      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 8496,
#      'TN': 421,
#      'FN': 211,
#      'FP': 211,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.67,
#      'negative_predictive_value': 0.67,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.33,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.33,
#      'Positive_likelihood_ratio': 2.92,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.37,
#      'threat_score': 10.08,
#      'Prevalence': 0.93,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.64,
#      'markedness': 0.64,
#      'Diagnostic_odds_ratio': 80.34,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.82},
#     'ROC_AUC_SCORE': {'Macro': 0.82, 'Micro': 0.82, 'Weight': 0.82},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      8681\n           1       0.69      0.67      0.68       632\n\n    accuracy                           0.96      9313\n   macro avg       0.84      0.82      0.83      9313\nweighted avg       0.96      0.96      0.96      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 8248,
#      'TN': 632,
#      'FN': 276,
#      'FP': 276,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.7,
#      'negative_predictive_value': 0.7,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.3,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.3,
#      'Positive_likelihood_ratio': 3.18,
#      'Negative_likelihood_ratio': 0.05,
#      'prevalence_threshold': 0.36,
#      'threat_score': 6.97,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.39,
#      'informedness': 0.66,
#      'markedness': 0.66,
#      'Diagnostic_odds_ratio': 68.43,
#      'accuracy': 0.94,
#      'balanced_accuracy': 0.83},
#     'ROC_AUC_SCORE': {'Macro': 0.84, 'Micro': 0.84, 'Weight': 0.84},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.98      0.97      8405\n           1       0.80      0.70      0.74       908\n\n    accuracy                           0.95      9313\n   macro avg       0.88      0.84      0.86      9313\nweighted avg       0.95      0.95      0.95      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 8233,
#      'TN': 725,
#      'FN': 191,
#      'FP': 191,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.79,
#      'negative_predictive_value': 0.79,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.21,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.21,
#      'Positive_likelihood_ratio': 4.69,
#      'Negative_likelihood_ratio': 0.03,
#      'prevalence_threshold': 0.32,
# ...
#      'sensitivity': 0.96,
#      'specificity': 0.6,
#      'negative_predictive_value': 0.6,
#      'false_negative_rate': 0.04,
#      'false_positive_rate': 0.4,
#      'false_discovery_rate': 0.04,
#      'false_omission_rate': 0.4,
#      'Positive_likelihood_ratio': 2.42,
#      'Negative_likelihood_ratio': 0.07,
#      'prevalence_threshold': 0.39,
#      'threat_score': 6.23,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.56,
#      'markedness': 0.56,
#      'Diagnostic_odds_ratio': 33.61,
#      'accuracy': 0.92,
#      'balanced_accuracy': 0.78},
#     'ROC_AUC_SCORE': {'Macro': 0.77, 'Micro': 0.77, 'Weight': 0.77},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.96      0.94      0.95      8405\n           1       0.52      0.60      0.56       908\n\n    accuracy                           0.91      9313\n   macro avg       0.74      0.77      0.75      9313\nweighted avg       0.91      0.91      0.91      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7598,
#      'TN': 738,
#      'FN': 178,
#      'FP': 178,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.81,
#      'negative_predictive_value': 0.81,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.19,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.19,
#      'Positive_likelihood_ratio': 5.03,
#      'Negative_likelihood_ratio': 0.03,
#      'prevalence_threshold': 0.31,
#      'threat_score': 6.95,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.78,
#      'markedness': 0.78,
#      'Diagnostic_odds_ratio': 176.98,
#      'accuracy': 0.96,
#      'balanced_accuracy': 0.89},
#     'ROC_AUC_SCORE': {'Macro': 0.86, 'Micro': 0.86, 'Weight': 0.86},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.90      0.94      8397\n           1       0.48      0.81      0.60       916\n\n    accuracy                           0.90      9313\n   macro avg       0.73      0.86      0.77      9313\nweighted avg       0.93      0.90      0.91      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 7356,
#      'TN': 960,
#      'FN': 365,
#      'FP': 365,
#      'precision': 0.95,
#      'recall': 0.95,
#      'f1_score': 0.95,
#      'sensitivity': 0.95,
#      'specificity': 0.72,
#      'negative_predictive_value': 0.72,
#      'false_negative_rate': 0.05,
#      'false_positive_rate': 0.28,
#      'false_discovery_rate': 0.05,
#      'false_omission_rate': 0.28,
#      'Positive_likelihood_ratio': 3.46,
#      'Negative_likelihood_ratio': 0.07,
#      'prevalence_threshold': 0.35,
#      'threat_score': 4.35,
#      'Prevalence': 0.85,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.68,
#      'markedness': 0.68,
#      'Diagnostic_odds_ratio': 53.01,
#      'accuracy': 0.92,
#      'balanced_accuracy': 0.84},
#     'ROC_AUC_SCORE': {'Macro': 0.82, 'Micro': 0.82, 'Weight': 0.82},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.95      0.92      0.94      7987\n           1       0.60      0.72      0.66      1325\n\n    accuracy                           0.89      9312\n   macro avg       0.78      0.82      0.80      9312\nweighted avg       0.90      0.89      0.90      9312\n'}}},
#  'train_18': {'param': {'penalty': 'l2',
#    'fit_intercept': False,
#    'class_weight': None,
#    'solver': 'sag'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7775,
#      'TN': 340,
#      'FN': 424,
#      'FP': 424,
#      'precision': 0.95,
#      'recall': 0.95,
#      'f1_score': 0.95,
#      'sensitivity': 0.95,
#      'specificity': 0.45,
#      'negative_predictive_value': 0.45,
#      'false_negative_rate': 0.05,
#      'false_positive_rate': 0.55,
#      'false_discovery_rate': 0.05,
#      'false_omission_rate': 0.55,
#      'Positive_likelihood_ratio': 1.71,
#      'Negative_likelihood_ratio': 0.12,
#      'prevalence_threshold': 0.43,
#      'threat_score': 6.54,
#      'Prevalence': 0.91,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.39,
#      'markedness': 0.39,
#      'Diagnostic_odds_ratio': 14.7,
#      'accuracy': 0.91,
#      'balanced_accuracy': 0.7},
#     'ROC_AUC_SCORE': {'Macro': 0.68, 'Micro': 0.68, 'Weight': 0.68},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.95      0.91      0.93      8549\n           1       0.31      0.45      0.36       764\n\n    accuracy                           0.87      9313\n   macro avg       0.63      0.68      0.65      9313\nweighted avg       0.90      0.87      0.88      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 7885,
#      'TN': 405,
#      'FN': 227,
#      'FP': 227,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.64,
#      'negative_predictive_value': 0.64,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.36,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.36,
#      'Positive_likelihood_ratio': 2.71,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.38,
#      'threat_score': 9.18,
#      'Prevalence': 0.93,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.39,
#      'informedness': 0.61,
#      'markedness': 0.61,
#      'Diagnostic_odds_ratio': 61.97,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.81},
#     'ROC_AUC_SCORE': {'Macro': 0.77, 'Micro': 0.77, 'Weight': 0.77},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.91      0.94      8681\n           1       0.34      0.64      0.44       632\n\n    accuracy                           0.89      9313\n   macro avg       0.65      0.77      0.69      9313\nweighted avg       0.93      0.89      0.91      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 7890,
#      'TN': 549,
#      'FN': 359,
#      'FP': 359,
#      'precision': 0.96,
#      'recall': 0.96,
#      'f1_score': 0.96,
#      'sensitivity': 0.96,
#      'specificity': 0.6,
#      'negative_predictive_value': 0.6,
#      'false_negative_rate': 0.04,
#      'false_positive_rate': 0.4,
#      'false_discovery_rate': 0.04,
#      'false_omission_rate': 0.4,
#      'Positive_likelihood_ratio': 2.42,
#      'Negative_likelihood_ratio': 0.07,
#      'prevalence_threshold': 0.39,
#      'threat_score': 6.23,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.56,
#      'markedness': 0.56,
#      'Diagnostic_odds_ratio': 33.61,
#      'accuracy': 0.92,
#      'balanced_accuracy': 0.78},
#     'ROC_AUC_SCORE': {'Macro': 0.77, 'Micro': 0.77, 'Weight': 0.77},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.96      0.94      0.95      8405\n           1       0.52      0.60      0.56       908\n\n    accuracy                           0.91      9313\n   macro avg       0.74      0.77      0.75      9313\nweighted avg       0.91      0.91      0.91      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7598,
#      'TN': 738,
#      'FN': 178,
#      'FP': 178,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.81,
#      'negative_predictive_value': 0.81,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.19,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.19,
#      'Positive_likelihood_ratio': 5.03,
#      'Negative_likelihood_ratio': 0.03,
#      'prevalence_threshold': 0.31,
#      'threat_score': 6.95,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.78,
#      'markedness': 0.78,
#      'Diagnostic_odds_ratio': 176.98,
#      'accuracy': 0.96,
#      'balanced_accuracy': 0.89},
#     'ROC_AUC_SCORE': {'Macro': 0.86, 'Micro': 0.86, 'Weight': 0.86},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.90      0.94      8397\n           1       0.48      0.81      0.60       916\n\n    accuracy                           0.90      9313\n   macro avg       0.73      0.86      0.77      9313\nweighted avg       0.93      0.90      0.91      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 7356,
#      'TN': 960,
#      'FN': 365,
#      'FP': 365,
#      'precision': 0.95,
#      'recall': 0.95,
#      'f1_score': 0.95,
#      'sensitivity': 0.95,
#      'specificity': 0.72,
#      'negative_predictive_value': 0.72,
#      'false_negative_rate': 0.05,
#      'false_positive_rate': 0.28,
#      'false_discovery_rate': 0.05,
#      'false_omission_rate': 0.28,
#      'Positive_likelihood_ratio': 3.46,
#      'Negative_likelihood_ratio': 0.07,
#      'prevalence_threshold': 0.35,
#      'threat_score': 4.35,
#      'Prevalence': 0.85,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.68,
#      'markedness': 0.68,
#      'Diagnostic_odds_ratio': 53.01,
#      'accuracy': 0.92,
#      'balanced_accuracy': 0.84},
#     'ROC_AUC_SCORE': {'Macro': 0.82, 'Micro': 0.82, 'Weight': 0.82},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.95      0.92      0.94      7987\n           1       0.60      0.72      0.66      1325\n\n    accuracy                           0.89      9312\n   macro avg       0.78      0.82      0.80      9312\nweighted avg       0.90      0.89      0.90      9312\n'}}},
#  'train_19': {'param': {'penalty': 'l2',
#    'fit_intercept': False,
#    'class_weight': None,
#    'solver': 'saga'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 7775,
#      'TN': 340,
#      'FN': 424,
#      'FP': 424,
#      'precision': 0.95,
#      'recall': 0.95,
#      'f1_score': 0.95,
#      'sensitivity': 0.95,
#      'specificity': 0.45,
#      'negative_predictive_value': 0.45,
#      'false_negative_rate': 0.05,
#      'false_positive_rate': 0.55,
#      'false_discovery_rate': 0.05,
#      'false_omission_rate': 0.55,
#      'Positive_likelihood_ratio': 1.71,
#      'Negative_likelihood_ratio': 0.12,
#      'prevalence_threshold': 0.43,
#      'threat_score': 6.54,
#      'Prevalence': 0.91,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.39,
#      'markedness': 0.39,
#      'Diagnostic_odds_ratio': 14.7,
#      'accuracy': 0.91,
#      'balanced_accuracy': 0.7},
#     'ROC_AUC_SCORE': {'Macro': 0.68, 'Micro': 0.68, 'Weight': 0.68},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.95      0.91      0.93      8549\n           1       0.31      0.45      0.36       764\n\n    accuracy                           0.87      9313\n   macro avg       0.63      0.68      0.65      9313\nweighted avg       0.90      0.87      0.88      9313\n'},
#    'fold_1': {'Confusion Matrix': {'TP': 7885,
#      'TN': 405,
#      'FN': 227,
#      'FP': 227,
#      'precision': 0.97,
#      'recall': 0.97,
#      'f1_score': 0.97,
#      'sensitivity': 0.97,
#      'specificity': 0.64,
#      'negative_predictive_value': 0.64,
#      'false_negative_rate': 0.03,
#      'false_positive_rate': 0.36,
#      'false_discovery_rate': 0.03,
#      'false_omission_rate': 0.36,
#      'Positive_likelihood_ratio': 2.71,
#      'Negative_likelihood_ratio': 0.04,
#      'prevalence_threshold': 0.38,
#      'threat_score': 9.18,
#      'Prevalence': 0.93,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.39,
#      'informedness': 0.61,
#      'markedness': 0.61,
#      'Diagnostic_odds_ratio': 61.97,
#      'accuracy': 0.95,
#      'balanced_accuracy': 0.81},
#     'ROC_AUC_SCORE': {'Macro': 0.77, 'Micro': 0.77, 'Weight': 0.77},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.97      0.91      0.94      8681\n           1       0.34      0.64      0.44       632\n\n    accuracy                           0.89      9313\n   macro avg       0.65      0.77      0.69      9313\nweighted avg       0.93      0.89      0.91      9313\n'},
#    'fold_2': {'Confusion Matrix': {'TP': 7890,
#      'TN': 549,
#      'FN': 359,
#      'FP': 359,
#      'precision': 0.96,
#      'recall': 0.96,
#      'f1_score': 0.96,
#      'sensitivity': 0.96,
#      'specificity': 0.6,
#      'negative_predictive_value': 0.6,
#      'false_negative_rate': 0.04,
#      'false_positive_rate': 0.4,
#      'false_discovery_rate': 0.04,
#      'false_omission_rate': 0.4,
#      'Positive_likelihood_ratio': 2.42,
#      'Negative_likelihood_ratio': 0.07,
#      'prevalence_threshold': 0.39,
#      'threat_score': 6.23,
#      'Prevalence': 0.9,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.56,
#      'markedness': 0.56,
#      'Diagnostic_odds_ratio': 33.61,
#      'accuracy': 0.92,
#      'balanced_accuracy': 0.78},
#     'ROC_AUC_SCORE': {'Macro': 0.77, 'Micro': 0.77, 'Weight': 0.77},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.96      0.94      0.95      8405\n           1       0.52      0.60      0.56       908\n\n    accuracy                           0.91      9313\n   macro avg       0.74      0.77      0.75      9313\nweighted avg       0.91      0.91      0.91      9313\n'},
#    'fold_3': {'Confusion Matrix': {'TP': 7598,
#      'TN': 738,
#      'FN': 178,
#      'FP': 178,
#      'precision': 0.98,
#      'recall': 0.98,
#      'f1_score': 0.98,
#      'sensitivity': 0.98,
#      'specificity': 0.81,
#      'negative_predictive_value': 0.81,
#      'false_negative_rate': 0.02,
#      'false_positive_rate': 0.19,
#      'false_discovery_rate': 0.02,
#      'false_omission_rate': 0.19,
#      'Positive_likelihood_ratio': 5.03,
#      'Negative_likelihood_ratio': 0.03,
#      'prevalence_threshold': 0.31,
#      'threat_score': 6.95,
#      'Prevalence': 0.89,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.4,
#      'informedness': 0.78,
#      'markedness': 0.78,
#      'Diagnostic_odds_ratio': 176.98,
#      'accuracy': 0.96,
#      'balanced_accuracy': 0.89},
#     'ROC_AUC_SCORE': {'Macro': 0.86, 'Micro': 0.86, 'Weight': 0.86},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.98      0.90      0.94      8397\n           1       0.48      0.81      0.60       916\n\n    accuracy                           0.90      9313\n   macro avg       0.73      0.86      0.77      9313\nweighted avg       0.93      0.90      0.91      9313\n'},
#    'fold_4': {'Confusion Matrix': {'TP': 7356,
#      'TN': 960,
#      'FN': 365,
#      'FP': 365,
#      'precision': 0.95,
#      'recall': 0.95,
#      'f1_score': 0.95,
#      'sensitivity': 0.95,
#      'specificity': 0.72,
#      'negative_predictive_value': 0.72,
#      'false_negative_rate': 0.05,
#      'false_positive_rate': 0.28,
#      'false_discovery_rate': 0.05,
#      'false_omission_rate': 0.28,
#      'Positive_likelihood_ratio': 3.46,
#      'Negative_likelihood_ratio': 0.07,
#      'prevalence_threshold': 0.35,
#      'threat_score': 4.35,
#      'Prevalence': 0.85,
#      'Matthews_correlation_coefficient': 0.0,
#      'Fowlkes_Mallows_index': 1.38,
#      'informedness': 0.68,
#      'markedness': 0.68,
#      'Diagnostic_odds_ratio': 53.01,
#      'accuracy': 0.92,
#      'balanced_accuracy': 0.84},
#     'ROC_AUC_SCORE': {'Macro': 0.82, 'Micro': 0.82, 'Weight': 0.82},
#     'Classification Report': '              precision    recall  f1-score   support\n\n           0       0.95      0.92      0.94      7987\n           1       0.60      0.72      0.66      1325\n\n    accuracy                           0.89      9312\n   macro avg       0.78      0.82      0.80      9312\nweighted avg       0.90      0.89      0.90      9312\n'}}}}

# %% [markdown]
# # Evaluation Result Analyze

# %%
print("Number of train case: {}".format(len(loaded_dict.keys())))

# %%
print("Number of training: {}".format(len(loaded_dict.keys()) * 5))
