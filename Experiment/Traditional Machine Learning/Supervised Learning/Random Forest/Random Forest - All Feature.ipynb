# %%
# Data Manipulation and Representation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import networkx as nx
import json

# Mathematics
from random import randint
import math 
import time
from datetime import datetime

# Training Implementation
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold

# Validation Implementation
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Data Preparation

# %%
main_data_dir = "D:/Github/Bitcoin-Transaction-Graph-Elliptic-Data-Set/Data/Elliptic Data Set/elliptic_bitcoin_dataset"
features_data_path = main_data_dir + "/elliptic_txs_features.csv"
class_data_path = main_data_dir + "/elliptic_txs_classes.csv"
egdelist_data_path = main_data_dir + "/elliptic_txs_edgelist.csv"

# %%
features_df = pd.read_csv(features_data_path)
classes_df = pd.read_csv(class_data_path)
edges_df = pd.read_csv(egdelist_data_path)

# %%
features_df.head()
# Out:
#    txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  1076         48        -0.168500         0.270909        -0.091383
# 1  2534          6        -0.170834        -0.131425         1.018602
# 2  3181         34         1.305212        -0.210553        -1.756361
# 3  3321          1        -0.169615        -0.184668        -1.201369
# 4  3889         48        -0.086232        -0.101835        -0.646376
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.046932        -0.043875        -0.029140        -0.061584
# 1         0.028105         0.055376         0.054722        -0.061584
# 2        -0.121970        97.300650        -0.113002        -0.061584
# 3        -0.121970        -0.043875        -0.113002        -0.061584
# 4        -0.121970        17.046997        -0.113002        -0.061584
#
#    Local_feature_8  ...  Aggregate_feature_63  Aggregate_feature_64  \
# 0        -0.163591  ...              0.073047             -0.039637
# 1        -0.163572  ...              1.228858              0.379357
# 2         1.348765  ...              1.348450              1.590664
# 3        -0.160199  ...             -0.577099             -0.500080
# 4        -0.074885  ...              0.501062              0.362510
#
#    Aggregate_feature_65  Aggregate_feature_66  Aggregate_feature_67  \
# 0              1.461330              1.461369              0.018279
# 1              0.955101              0.459257             -0.098889
# 2              0.059948              0.113967             -0.098889
# 3              0.241128              0.241406             -0.098889
# 4              0.082065              0.114773             -0.098889
#
#    Aggregate_feature_68  Aggregate_feature_69  Aggregate_feature_70  \
# 0              0.470019              1.216796              1.151607
# 1             -0.087490             -0.099080             -0.122137
# 2              1.969527              0.037532             -0.131010
# 3             -0.087490             -0.084674             -0.140597
# 4              8.948005              1.024948             -0.009570
#
#    Aggregate_feature_71  Aggregate_feature_72
# 0              1.519700              1.521399
# 1             -0.379970             -0.379288
# 2              0.006994              0.017772
# 3              1.519700              1.521399
# 4             -0.080708             -0.123601
#
# [5 rows x 167 columns]

# %%
classes_df.head()
# Out:
#    txId  class
# 0  1076      3
# 1  2534      2
# 2  3181      2
# 3  3321      3
# 4  3889      3

# %%
edges_df.head()
# Out:
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %%
df_class_feature = pd.merge(classes_df, features_df)
df_class_feature.head()
# Out:
#    txId  class  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  1076      3         48        -0.168500         0.270909        -0.091383
# 1  2534      2          6        -0.170834        -0.131425         1.018602
# 2  3181      2         34         1.305212        -0.210553        -1.756361
# 3  3321      3          1        -0.169615        -0.184668        -1.201369
# 4  3889      3         48        -0.086232        -0.101835        -0.646376
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  ...  \
# 0        -0.046932        -0.043875        -0.029140        -0.061584  ...
# 1         0.028105         0.055376         0.054722        -0.061584  ...
# 2        -0.121970        97.300650        -0.113002        -0.061584  ...
# 3        -0.121970        -0.043875        -0.113002        -0.061584  ...
# 4        -0.121970        17.046997        -0.113002        -0.061584  ...
#
#    Aggregate_feature_63  Aggregate_feature_64  Aggregate_feature_65  \
# 0              0.073047             -0.039637              1.461330
# 1              1.228858              0.379357              0.955101
# 2              1.348450              1.590664              0.059948
# 3             -0.577099             -0.500080              0.241128
# 4              0.501062              0.362510              0.082065
#
#    Aggregate_feature_66  Aggregate_feature_67  Aggregate_feature_68  \
# 0              1.461369              0.018279              0.470019
# 1              0.459257             -0.098889             -0.087490
# 2              0.113967             -0.098889              1.969527
# 3              0.241406             -0.098889             -0.087490
# 4              0.114773             -0.098889              8.948005
#
#    Aggregate_feature_69  Aggregate_feature_70  Aggregate_feature_71  \
# 0              1.216796              1.151607              1.519700
# 1             -0.099080             -0.122137             -0.379970
# 2              0.037532             -0.131010              0.006994
# 3             -0.084674             -0.140597              1.519700
# 4              1.024948             -0.009570             -0.080708
#
#    Aggregate_feature_72
# 0              1.521399
# 1             -0.379288
# 2              0.017772
# 3              1.521399
# 4             -0.123601
#
# [5 rows x 168 columns]

# %%
selected_ids = df_class_feature.loc[(df_class_feature['class'] != 3), 'txId']
df_edges_selected = edges_df.loc[edges_df['txId1'].isin(selected_ids)]
df_classes_selected = classes_df.loc[classes_df['txId'].isin(selected_ids)]
df_features_selected = features_df.loc[features_df['txId'].isin(selected_ids)]

# Merge Class and features
df_class_feature_selected = pd.merge(df_classes_selected, df_features_selected )
df_class_feature_selected.head()
# Out:
#    txId  class  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0  2534      2          6        -0.170834        -0.131425         1.018602
# 1  3181      2         34         1.305212        -0.210553        -1.756361
# 2  6418      2         48        -0.125229         7.538599         2.128587
# 3  7952      2         48         0.967162        -0.210553        -1.756361
# 4  9351      2         48        -0.172970        -0.114281         1.018602
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  ...  \
# 0         0.028105         0.055376         0.054722        -0.061584  ...
# 1        -0.121970        97.300650        -0.113002        -0.061584  ...
# 2         7.381781         0.095076         7.602324         0.547008  ...
# 3        -0.121970        92.556494        -0.113002        -0.061584  ...
# 4        -0.121970        -0.043875        -0.113002        -0.061584  ...
#
#    Aggregate_feature_63  Aggregate_feature_64  Aggregate_feature_65  \
# 0              1.228858              0.379357              0.955101
# 1              1.348450              1.590664              0.059948
# 2              0.433960              0.168508             -0.197237
# 3              0.823581              0.850443              0.321431
# 4             -0.569626              0.641566              1.461330
#
#    Aggregate_feature_66  Aggregate_feature_67  Aggregate_feature_68  \
# 0              0.459257             -0.098889             -0.087490
# 1              0.113967             -0.098889              1.969527
# 2              0.303447             -0.098889              0.931406
# 3              0.268810             -0.098889              1.162100
# 4              1.461369             -0.098889              0.662264
#
#    Aggregate_feature_69  Aggregate_feature_70  Aggregate_feature_71  \
# 0             -0.099080             -0.122137             -0.379970
# 1              0.037532             -0.131010              0.006994
# 2              1.041565              0.371499              0.790060
# 3              0.485146              0.303509             -0.553520
# 4              1.728088              1.539269              1.519700
#
#    Aggregate_feature_72
# 0             -0.379288
# 1              0.017772
# 2              0.779125
# 3             -0.578865
# 4              1.521399
#
# [5 rows x 168 columns]

# %%
X = df_class_feature_selected.drop(columns=['txId', 'class', 'Time step']) # drop class, text id and time step
y = df_class_feature_selected[['class']]
print(np.unique(y))

# in this case, class 2 corresponds to licit transactions, we chang this to 0 as our interest is the ilicit transactions
y = y['class'].apply(lambda x: 0 if x == 2 else 1 )
print(np.unique(y))
# Out:
# [1 2]
# [0 1]

# %%
print("Feature Shape: ", X.shape)
print("Label Shape: ", y.shape)
# Out:
# Feature Shape:  (46564, 165)
# Label Shape:  (46564,)

# %% [markdown]
# # Utils

# %%
class utils:
    def __init__(self, confusion_matrix, y_true, y_pred):
        """
            - confusion_matrix: 2x2 numpy array
            - y_true: array of label
            - y_pred: array of output value calculated by model
            - fold_count: number of folds
        """
        
        # Initilize all indicator
        self.TP = confusion_matrix[0][0] # true positive
        self.FN = confusion_matrix[1][0] # false negative
        self.FP = confusion_matrix[1][0] # false positive
        self.TN = confusion_matrix[1][1] # true negative
        self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
        self.recall = self.TP / (self.TP + self.FN)
        self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
        self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
        self.specificity = self.TN / (self.TN + self.FP) # False Positive Rate
        self.negative_predictive_value = self.TN / (self.TN + self.FN) # Negative Predictive Value
        self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
        self.false_positive_rate = self.FP / (self.FP + self.TN) # False Positive Rate
        self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
        self.false_omission_rate = self.FN / (self.FN + self.TN) # False Ommision Rate
        self.positive_likelihood_ratio = self.sensitivity / self.false_positive_rate # Positive Likelihood Ratio
        self.negative_likelihood_ratio = self.false_negative_rate / self.specificity # Negative Likelihood Ratio
        self.prevalence_threshold = math.sqrt(self.false_positive_rate) / (math.sqrt(self.sensitivity) + 
                                                                      math.sqrt(self.false_positive_rate)) # Prevalance Threshold
        self.threat_score = self.TP / (self.TN + self.FN + self.FP) # Threat Score
        self.prevalence = (self.TP + self.FN)/(self.TP + self.FN + self.TN + self.FP) # Prevalance 
        #  Matthews correlation coefficient
        self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
                                                                                       *(self.TP + self.FN)
                                                                                       *(self.TN + self.FP)
                                                                                       *(self.TN + self.FN))
        self.fowlkes_mallows_index = math.sqrt(self.sensitivity + self.precision) # Fowlkes–Mallows index
        self.informedness = self.sensitivity + self.specificity - 1 # informedness
        self.markedness = self.precision + self.negative_predictive_value - 1 # markedness
        self.diagnostic_odds_ratio = self.positive_likelihood_ratio / self.negative_likelihood_ratio # Diagnostic odds ratio
        self.accuracy = (self.TP + self.TN) / (self.TP + self.TN + self.FP + self.FN)
        self.balanced_accuracy = (self.sensitivity + self.specificity) / 2
        self.roc_auc_macro = roc_auc_score(y_true, y_pred)
        self.roc_auc_micro = roc_auc_score(y_true, y_pred, average = 'micro')
        self.roc_auc_weighted = roc_auc_score(y_true, y_pred, average = 'weighted')
        self.cls_report = classification_report(y_true, y_pred)
        
        # Initilize the structure of output_dicts
        self.confusion_matrix = {
            "TP" : self.TP,
            "TN" : self.TN,
            "FN" : self.FN,
            "FP" : self.FP,
            "precision" : self.precision,
            "recall" : self.recall,
            "f1_score" : self.f1_score,
            "sensitivity" : self.sensitivity,
            "specificity" : self.specificity,
            "negative_predictive_value" : self.negative_predictive_value,
            "false_negative_rate" : self.false_negative_rate,
            "false_positive_rate" : self.false_positive_rate,
            "false_discovery_rate" : self.false_discovery_rate,
            "false_omission_rate" : self.false_omission_rate,
            "Positive_likelihood_ratio" : self.positive_likelihood_ratio,
            "Negative_likelihood_ratio" : self.negative_likelihood_ratio,
            "prevalence_threshold" : self.prevalence_threshold,
            "threat_score" : self.threat_score,
            "Prevalence" : self.prevalence,
            "Matthews_correlation_coefficient" : self.matthews_correlation_coefficient,
            "Fowlkes_Mallows_index" : self.fowlkes_mallows_index,
            "informedness" : self.informedness,
            "markedness" : self.markedness,
            "Diagnostic_odds_ratio" : self.diagnostic_odds_ratio,
            "accuracy" : self.accuracy,
            "balanced_accuracy" : self.balanced_accuracy
        }
        
        self.roc_auc_score = {
            "Macro": self.roc_auc_macro, 
            "Micro": self.roc_auc_micro,
            "Weight": self.roc_auc_weighted
        }
        
        self.sub_dict = {
            "Confusion Matrix" : self.confusion_matrix,
            "ROC_AUC_SCORE" : self.roc_auc_score,
            "Classification Report" : classification_report(y_true.tolist(), y_pred.tolist(), 
                                                            labels = [0, 1], # 0 : Licit, 1 : Illicit
                                                            output_dict = True)
        }
    def get_value(self):
        return self.sub_dict
        
# Test 
y_true = np.array([randint(0,1) for x in range(200)])
y_pred = np.array([randint(0,1) for x in range(200)])
confusion_matrix_test = confusion_matrix(y_true, y_pred)
base_utils = utils(confusion_matrix_test, y_true, y_pred)
base_utils.get_value()
# Out:
# {'Confusion Matrix': {'TP': 57,
#   'TN': 48,
#   'FN': 51,
#   'FP': 51,
#   'precision': 0.5277777777777778,
#   'recall': 0.5277777777777778,
#   'f1_score': 0.5277777777777778,
#   'sensitivity': 0.5277777777777778,
#   'specificity': 0.48484848484848486,
#   'negative_predictive_value': 0.48484848484848486,
#   'false_negative_rate': 0.4722222222222222,
#   'false_positive_rate': 0.5151515151515151,
#   'false_discovery_rate': 0.4722222222222222,
#   'false_omission_rate': 0.5151515151515151,
#   'Positive_likelihood_ratio': 1.0245098039215688,
#   'Negative_likelihood_ratio': 0.9739583333333333,
#   'prevalence_threshold': 0.4969732547071784,
#   'threat_score': 0.38,
#   'Prevalence': 0.5217391304347826,
#   'Matthews_correlation_coefficient': 1.1809074659804176e-06,
#   'Fowlkes_Mallows_index': 1.0274023338281628,
#   'informedness': 0.012626262626262541,
#   'markedness': 0.012626262626262541,
#   'Diagnostic_odds_ratio': 1.0519031141868513,
#   'accuracy': 0.5072463768115942,
#   'balanced_accuracy': 0.5063131313131313},
#  'ROC_AUC_SCORE': {'Macro': 0.5246024602460246,
#   'Micro': 0.5246024602460246,
#   'Weight': 0.5246024602460246},
#  'Classification Report': {'0': {'precision': 0.5277777777777778,
#    'recall': 0.5643564356435643,
#    'f1-score': 0.5454545454545454,
#    'support': 101},
#   '1': {'precision': 0.5217391304347826,
#    'recall': 0.48484848484848486,
#    'f1-score': 0.5026178010471203,
#    'support': 99},
#   'accuracy': 0.525,
#   'macro avg': {'precision': 0.5247584541062802,
#    'recall': 0.5246024602460246,
#    'f1-score': 0.5240361732508328,
#    'support': 200},
#   'weighted avg': {'precision': 0.5247886473429952,
#    'recall': 0.525,
#    'f1-score': 0.52425035697287,
#    'support': 200}}}

# %% [markdown]
# # Training

# %%
class Training:
    def __init__(self, fold_count, X, y):
        self.fold_count = fold_count
        self.param_grid = {
            "n_estimators" : [50, 100, 150, 200],
            "criterion" : ["gini", "entropy", "log_loss"],
            "max_features" : ["sqrt", "log2", None],
            "bootstrap" : [True, False],
            "class_weight" : ["balanced", "balanced_subsample", None]
        }
        self.kf = KFold(n_splits=fold_count)
        self.history = {}
        self.X = X
        self.y = y
    
    def get_fold_value(self):
        return self.kf        
        
    def training(self, n_estimators, criterion, max_features, bootstrap, class_weight, njob = 4):
    
        # output_dict initilize
        output_dict = {}
    
        # poiter track the index of fold
        fold_index = 0
    
        for train_index, test_index in self.kf.split(self.X):
            print("TRAIN:", train_index, "TEST:", test_index)
        
            # folding data
            X_train, X_test = self.X.values[train_index], self.X.values[test_index]
            y_train, y_test = self.y.values[train_index], self.y.values[test_index]
    
            # Training
            print("Training : {}".format(fold_index))
            print("Start time: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
            model_RF = RandomForestClassifier()
            model_RF.fit(X_train,y_train)
            print("End time: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Testing
            print("Validation: {}".format(fold_index))
            print("Start time: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
            y_pred = model_RF.predict(X_test)
            print("End time: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Evaluation
            cm = confusion_matrix(y_test, y_pred)
            current_utils = utils(cm, y_test, y_pred)
            output_dict["fold_{}".format(fold_index)] = current_utils.get_value()
            
            fold_index += 1
    
        return output_dict 
    
    def train(self, path):
        count = 0
        for x in self.param_grid["n_estimators"]:
            for i in self.param_grid["criterion"]:
                for j in self.param_grid["max_features"]:
                    for k in self.param_grid["bootstrap"]:
                        for l in self.param_grid["class_weight"]:
                            self.history["train_{}".format(count)] = {
                                "param" : {
                                    "n_estimators" : x,
                                    "criterion" : i,
                                    "max_features" : j,
                                    "bootstrap" : k,
                                    "class_weight" : l
                                },
                                "train_fold" : self.training(x, i, j, k, l, 5)
                            }
        with open(path, "w") as outfile:
            json.dump(self.history, outfile)

# %%
path = "Random_Forest_AF.json"
train = Training(5, X, y)
train.train(path)
# Out:
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:40:16
# End time: 08/05/2022, 18:40:29
# Validation: 0
# Start time: 08/05/2022, 18:40:29
# End time: 08/05/2022, 18:40:30
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:40:30
# End time: 08/05/2022, 18:40:43
# Validation: 1
# Start time: 08/05/2022, 18:40:43
# End time: 08/05/2022, 18:40:43
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:40:43
# End time: 08/05/2022, 18:40:56
# Validation: 2
# Start time: 08/05/2022, 18:40:56
# End time: 08/05/2022, 18:40:56
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:40:56
# End time: 08/05/2022, 18:41:10
# Validation: 3
# Start time: 08/05/2022, 18:41:10
# End time: 08/05/2022, 18:41:10
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:41:10
# End time: 08/05/2022, 18:41:24
# Validation: 4
# Start time: 08/05/2022, 18:41:24
# End time: 08/05/2022, 18:41:24
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:41:24
# End time: 08/05/2022, 18:41:37
# Validation: 0
# Start time: 08/05/2022, 18:41:37
# End time: 08/05/2022, 18:41:37
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:41:38
# End time: 08/05/2022, 18:41:51
# Validation: 1
# Start time: 08/05/2022, 18:41:51
# End time: 08/05/2022, 18:41:51
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:41:51
# End time: 08/05/2022, 18:42:04
# Validation: 2
# Start time: 08/05/2022, 18:42:04
# End time: 08/05/2022, 18:42:04
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:42:04
# End time: 08/05/2022, 18:42:18
# Validation: 3
# Start time: 08/05/2022, 18:42:18
# End time: 08/05/2022, 18:42:18
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:42:18
# End time: 08/05/2022, 18:42:32
# Validation: 4
# Start time: 08/05/2022, 18:42:32
# End time: 08/05/2022, 18:42:32
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:42:33
# End time: 08/05/2022, 18:42:46
# Validation: 0
# Start time: 08/05/2022, 18:42:46
# End time: 08/05/2022, 18:42:46
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:42:46
# End time: 08/05/2022, 18:43:00
# Validation: 1
# Start time: 08/05/2022, 18:43:00
# End time: 08/05/2022, 18:43:00
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:43:00
# End time: 08/05/2022, 18:43:13
# Validation: 2
# Start time: 08/05/2022, 18:43:13
# End time: 08/05/2022, 18:43:13
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:43:13
# End time: 08/05/2022, 18:43:27
# Validation: 3
# Start time: 08/05/2022, 18:43:27
# End time: 08/05/2022, 18:43:27
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:43:27
# End time: 08/05/2022, 18:43:41
# Validation: 4
# Start time: 08/05/2022, 18:43:41
# End time: 08/05/2022, 18:43:41
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:43:41
# End time: 08/05/2022, 18:43:54
# Validation: 0
# Start time: 08/05/2022, 18:43:54
# End time: 08/05/2022, 18:43:54
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:43:54
# End time: 08/05/2022, 18:44:08
# Validation: 1
# Start time: 08/05/2022, 18:44:08
# End time: 08/05/2022, 18:44:08
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:44:08
# End time: 08/05/2022, 18:44:21
# Validation: 2
# Start time: 08/05/2022, 18:44:21
# End time: 08/05/2022, 18:44:21
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:44:21
# End time: 08/05/2022, 18:44:35
# Validation: 3
# Start time: 08/05/2022, 18:44:35
# End time: 08/05/2022, 18:44:35
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:44:35
# End time: 08/05/2022, 18:44:49
# Validation: 4
# Start time: 08/05/2022, 18:44:49
# End time: 08/05/2022, 18:44:49
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:44:49
# End time: 08/05/2022, 18:45:03
# Validation: 0
# Start time: 08/05/2022, 18:45:03
# End time: 08/05/2022, 18:45:03
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:45:03
# End time: 08/05/2022, 18:45:16
# Validation: 1
# Start time: 08/05/2022, 18:45:16
# End time: 08/05/2022, 18:45:16
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:45:16
# End time: 08/05/2022, 18:45:29
# Validation: 2
# Start time: 08/05/2022, 18:45:29
# End time: 08/05/2022, 18:45:29
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:45:29
# End time: 08/05/2022, 18:45:43
# Validation: 3
# Start time: 08/05/2022, 18:45:43
# End time: 08/05/2022, 18:45:44
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:45:44
# End time: 08/05/2022, 18:45:57
# Validation: 4
# Start time: 08/05/2022, 18:45:57
# End time: 08/05/2022, 18:45:57
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:45:57
# End time: 08/05/2022, 18:46:11
# Validation: 0
# Start time: 08/05/2022, 18:46:11
# End time: 08/05/2022, 18:46:11
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:46:11
# End time: 08/05/2022, 18:46:24
# Validation: 1
# Start time: 08/05/2022, 18:46:24
# End time: 08/05/2022, 18:46:24
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:46:24
# End time: 08/05/2022, 18:46:38
# Validation: 2
# Start time: 08/05/2022, 18:46:38
# End time: 08/05/2022, 18:46:38
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:46:38
# End time: 08/05/2022, 18:46:51
# Validation: 3
# Start time: 08/05/2022, 18:46:51
# End time: 08/05/2022, 18:46:52
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:46:52
# End time: 08/05/2022, 18:47:05
# Validation: 4
# Start time: 08/05/2022, 18:47:05
# End time: 08/05/2022, 18:47:05
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:47:05
# End time: 08/05/2022, 18:47:19
# Validation: 0
# Start time: 08/05/2022, 18:47:19
# End time: 08/05/2022, 18:47:19
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:47:19
# End time: 08/05/2022, 18:47:32
# Validation: 1
# Start time: 08/05/2022, 18:47:32
# End time: 08/05/2022, 18:47:32
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:47:32
# End time: 08/05/2022, 18:47:46
# Validation: 2
# Start time: 08/05/2022, 18:47:46
# End time: 08/05/2022, 18:47:46
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:47:46
# End time: 08/05/2022, 18:48:00
# Validation: 3
# Start time: 08/05/2022, 18:48:00
# End time: 08/05/2022, 18:48:00
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:48:00
# End time: 08/05/2022, 18:48:13
# Validation: 4
# Start time: 08/05/2022, 18:48:13
# End time: 08/05/2022, 18:48:14
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:48:14
# End time: 08/05/2022, 18:48:27
# Validation: 0
# Start time: 08/05/2022, 18:48:27
# End time: 08/05/2022, 18:48:27
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:48:27
# End time: 08/05/2022, 18:48:41
# Validation: 1
# Start time: 08/05/2022, 18:48:41
# End time: 08/05/2022, 18:48:41
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:48:41
# End time: 08/05/2022, 18:48:54
# Validation: 2
# Start time: 08/05/2022, 18:48:54
# End time: 08/05/2022, 18:48:54
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:48:54
# End time: 08/05/2022, 18:49:08
# Validation: 3
# Start time: 08/05/2022, 18:49:08
# End time: 08/05/2022, 18:49:08
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:49:08
# End time: 08/05/2022, 18:49:22
# Validation: 4
# Start time: 08/05/2022, 18:49:22
# End time: 08/05/2022, 18:49:22
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:49:22
# End time: 08/05/2022, 18:49:36
# Validation: 0
# Start time: 08/05/2022, 18:49:36
# End time: 08/05/2022, 18:49:36
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:49:36
# End time: 08/05/2022, 18:49:49
# Validation: 1
# Start time: 08/05/2022, 18:49:49
# End time: 08/05/2022, 18:49:49
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:49:49
# End time: 08/05/2022, 18:50:03
# Validation: 2
# Start time: 08/05/2022, 18:50:03
# End time: 08/05/2022, 18:50:03
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:50:03
# End time: 08/05/2022, 18:50:17
# Validation: 3
# Start time: 08/05/2022, 18:50:17
# End time: 08/05/2022, 18:50:17
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:50:17
# End time: 08/05/2022, 18:50:31
# Validation: 4
# Start time: 08/05/2022, 18:50:31
# End time: 08/05/2022, 18:50:31
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:50:31
# End time: 08/05/2022, 18:50:45
# Validation: 0
# Start time: 08/05/2022, 18:50:45
# End time: 08/05/2022, 18:50:45
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:50:45
# End time: 08/05/2022, 18:50:58
# Validation: 1
# Start time: 08/05/2022, 18:50:58
# End time: 08/05/2022, 18:50:58
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:50:58
# End time: 08/05/2022, 18:51:11
# Validation: 2
# Start time: 08/05/2022, 18:51:11
# End time: 08/05/2022, 18:51:12
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:51:12
# End time: 08/05/2022, 18:51:26
# Validation: 3
# Start time: 08/05/2022, 18:51:26
# End time: 08/05/2022, 18:51:26
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:51:26
# End time: 08/05/2022, 18:51:39
# Validation: 4
# Start time: 08/05/2022, 18:51:39
# End time: 08/05/2022, 18:51:40
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:51:40
# End time: 08/05/2022, 18:51:53
# Validation: 0
# Start time: 08/05/2022, 18:51:53
# End time: 08/05/2022, 18:51:53
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:51:53
# End time: 08/05/2022, 18:52:07
# Validation: 1
# Start time: 08/05/2022, 18:52:07
# End time: 08/05/2022, 18:52:07
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:52:07
# End time: 08/05/2022, 18:52:20
# Validation: 2
# Start time: 08/05/2022, 18:52:20
# End time: 08/05/2022, 18:52:20
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:52:20
# End time: 08/05/2022, 18:52:34
# Validation: 3
# Start time: 08/05/2022, 18:52:34
# End time: 08/05/2022, 18:52:34
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:52:34
# End time: 08/05/2022, 18:52:48
# Validation: 4
# Start time: 08/05/2022, 18:52:48
# End time: 08/05/2022, 18:52:48
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:52:48
# End time: 08/05/2022, 18:53:02
# Validation: 0
# Start time: 08/05/2022, 18:53:02
# End time: 08/05/2022, 18:53:02
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:53:02
# End time: 08/05/2022, 18:53:15
# Validation: 1
# Start time: 08/05/2022, 18:53:15
# End time: 08/05/2022, 18:53:16
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:53:16
# End time: 08/05/2022, 18:53:29
# Validation: 2
# Start time: 08/05/2022, 18:53:29
# End time: 08/05/2022, 18:53:29
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:53:29
# End time: 08/05/2022, 18:53:43
# Validation: 3
# Start time: 08/05/2022, 18:53:43
# End time: 08/05/2022, 18:53:43
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:53:43
# End time: 08/05/2022, 18:53:57
# Validation: 4
# Start time: 08/05/2022, 18:53:57
# End time: 08/05/2022, 18:53:57
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:53:57
# End time: 08/05/2022, 18:54:10
# Validation: 0
# Start time: 08/05/2022, 18:54:10
# End time: 08/05/2022, 18:54:10
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:54:10
# End time: 08/05/2022, 18:54:24
# Validation: 1
# Start time: 08/05/2022, 18:54:24
# End time: 08/05/2022, 18:54:24
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:54:24
# End time: 08/05/2022, 18:54:37
# Validation: 2
# Start time: 08/05/2022, 18:54:37
# End time: 08/05/2022, 18:54:37
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:54:37
# End time: 08/05/2022, 18:54:51
# Validation: 3
# Start time: 08/05/2022, 18:54:51
# End time: 08/05/2022, 18:54:51
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:54:51
# End time: 08/05/2022, 18:55:05
# Validation: 4
# Start time: 08/05/2022, 18:55:05
# End time: 08/05/2022, 18:55:05
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:55:05
# End time: 08/05/2022, 18:55:19
# Validation: 0
# Start time: 08/05/2022, 18:55:19
# End time: 08/05/2022, 18:55:19
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:55:19
# End time: 08/05/2022, 18:55:32
# Validation: 1
# Start time: 08/05/2022, 18:55:32
# End time: 08/05/2022, 18:55:32
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:55:32
# End time: 08/05/2022, 18:55:46
# Validation: 2
# Start time: 08/05/2022, 18:55:46
# End time: 08/05/2022, 18:55:46
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:55:46
# End time: 08/05/2022, 18:56:00
# Validation: 3
# Start time: 08/05/2022, 18:56:00
# End time: 08/05/2022, 18:56:00
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:56:00
# End time: 08/05/2022, 18:56:13
# Validation: 4
# Start time: 08/05/2022, 18:56:13
# End time: 08/05/2022, 18:56:14
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:56:14
# End time: 08/05/2022, 18:56:27
# Validation: 0
# Start time: 08/05/2022, 18:56:27
# End time: 08/05/2022, 18:56:27
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:56:27
# End time: 08/05/2022, 18:56:40
# Validation: 1
# Start time: 08/05/2022, 18:56:40
# End time: 08/05/2022, 18:56:41
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:56:41
# End time: 08/05/2022, 18:56:54
# Validation: 2
# Start time: 08/05/2022, 18:56:54
# End time: 08/05/2022, 18:56:54
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:56:54
# End time: 08/05/2022, 18:57:08
# Validation: 3
# Start time: 08/05/2022, 18:57:08
# End time: 08/05/2022, 18:57:08
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:57:08
# End time: 08/05/2022, 18:57:22
# Validation: 4
# Start time: 08/05/2022, 18:57:22
# End time: 08/05/2022, 18:57:22
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:57:22
# End time: 08/05/2022, 18:57:36
# Validation: 0
# Start time: 08/05/2022, 18:57:36
# End time: 08/05/2022, 18:57:36
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:57:36
# End time: 08/05/2022, 18:57:49
# Validation: 1
# Start time: 08/05/2022, 18:57:49
# End time: 08/05/2022, 18:57:49
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:57:49
# End time: 08/05/2022, 18:58:02
# Validation: 2
# Start time: 08/05/2022, 18:58:02
# End time: 08/05/2022, 18:58:03
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:58:03
# End time: 08/05/2022, 18:58:17
# Validation: 3
# Start time: 08/05/2022, 18:58:17
# End time: 08/05/2022, 18:58:17
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:58:17
# End time: 08/05/2022, 18:58:30
# Validation: 4
# Start time: 08/05/2022, 18:58:30
# End time: 08/05/2022, 18:58:30
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:58:30
# End time: 08/05/2022, 18:58:44
# Validation: 0
# Start time: 08/05/2022, 18:58:44
# End time: 08/05/2022, 18:58:44
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:58:44
# End time: 08/05/2022, 18:58:57
# Validation: 1
# Start time: 08/05/2022, 18:58:57
# End time: 08/05/2022, 18:58:58
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 18:58:58
# End time: 08/05/2022, 18:59:11
# Validation: 2
# Start time: 08/05/2022, 18:59:11
# End time: 08/05/2022, 18:59:11
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 18:59:11
# End time: 08/05/2022, 18:59:25
# Validation: 3
# Start time: 08/05/2022, 18:59:25
# End time: 08/05/2022, 18:59:25
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 18:59:25
# End time: 08/05/2022, 18:59:39
# Validation: 4
# Start time: 08/05/2022, 18:59:39
# End time: 08/05/2022, 18:59:39
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 18:59:39
# End time: 08/05/2022, 18:59:52
# Validation: 0
# Start time: 08/05/2022, 18:59:52
# End time: 08/05/2022, 18:59:52
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 18:59:52
# End time: 08/05/2022, 19:00:06
# Validation: 1
# Start time: 08/05/2022, 19:00:06
# End time: 08/05/2022, 19:00:06
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:00:06
# End time: 08/05/2022, 19:00:19
# Validation: 2
# Start time: 08/05/2022, 19:00:19
# End time: 08/05/2022, 19:00:19
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:00:19
# End time: 08/05/2022, 19:00:33
# Validation: 3
# Start time: 08/05/2022, 19:00:33
# End time: 08/05/2022, 19:00:33
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:00:33
# End time: 08/05/2022, 19:00:47
# Validation: 4
# Start time: 08/05/2022, 19:00:47
# End time: 08/05/2022, 19:00:47
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:00:47
# End time: 08/05/2022, 19:01:00
# Validation: 0
# Start time: 08/05/2022, 19:01:00
# End time: 08/05/2022, 19:01:01
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:01:01
# End time: 08/05/2022, 19:01:14
# Validation: 1
# Start time: 08/05/2022, 19:01:14
# End time: 08/05/2022, 19:01:14
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:01:14
# End time: 08/05/2022, 19:01:28
# Validation: 2
# Start time: 08/05/2022, 19:01:28
# End time: 08/05/2022, 19:01:28
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:01:28
# End time: 08/05/2022, 19:01:41
# Validation: 3
# Start time: 08/05/2022, 19:01:41
# End time: 08/05/2022, 19:01:42
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:01:42
# End time: 08/05/2022, 19:01:56
# Validation: 4
# Start time: 08/05/2022, 19:01:56
# End time: 08/05/2022, 19:01:56
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:01:56
# End time: 08/05/2022, 19:02:09
# Validation: 0
# Start time: 08/05/2022, 19:02:09
# End time: 08/05/2022, 19:02:09
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:02:10
# End time: 08/05/2022, 19:02:23
# Validation: 1
# Start time: 08/05/2022, 19:02:23
# End time: 08/05/2022, 19:02:24
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:02:24
# End time: 08/05/2022, 19:02:37
# Validation: 2
# Start time: 08/05/2022, 19:02:37
# End time: 08/05/2022, 19:02:37
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:02:37
# End time: 08/05/2022, 19:02:51
# Validation: 3
# Start time: 08/05/2022, 19:02:51
# End time: 08/05/2022, 19:02:51
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:02:51
# End time: 08/05/2022, 19:03:05
# Validation: 4
# Start time: 08/05/2022, 19:03:05
# End time: 08/05/2022, 19:03:05
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:03:05
# End time: 08/05/2022, 19:03:19
# Validation: 0
# Start time: 08/05/2022, 19:03:19
# End time: 08/05/2022, 19:03:19
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:03:19
# End time: 08/05/2022, 19:03:32
# Validation: 1
# Start time: 08/05/2022, 19:03:32
# End time: 08/05/2022, 19:03:32
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:03:32
# End time: 08/05/2022, 19:03:45
# Validation: 2
# Start time: 08/05/2022, 19:03:45
# End time: 08/05/2022, 19:03:45
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:03:45
# End time: 08/05/2022, 19:03:59
# Validation: 3
# Start time: 08/05/2022, 19:03:59
# End time: 08/05/2022, 19:03:59
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:03:59
# End time: 08/05/2022, 19:04:13
# Validation: 4
# Start time: 08/05/2022, 19:04:13
# End time: 08/05/2022, 19:04:13
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:04:13
# End time: 08/05/2022, 19:04:26
# Validation: 0
# Start time: 08/05/2022, 19:04:26
# End time: 08/05/2022, 19:04:26
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:04:26
# End time: 08/05/2022, 19:04:40
# Validation: 1
# Start time: 08/05/2022, 19:04:40
# End time: 08/05/2022, 19:04:40
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:04:40
# End time: 08/05/2022, 19:04:53
# Validation: 2
# Start time: 08/05/2022, 19:04:53
# End time: 08/05/2022, 19:04:53
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:04:53
# End time: 08/05/2022, 19:05:07
# Validation: 3
# Start time: 08/05/2022, 19:05:07
# End time: 08/05/2022, 19:05:07
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:05:07
# End time: 08/05/2022, 19:05:21
# Validation: 4
# Start time: 08/05/2022, 19:05:21
# End time: 08/05/2022, 19:05:21
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:05:21
# End time: 08/05/2022, 19:05:34
# Validation: 0
# Start time: 08/05/2022, 19:05:34
# End time: 08/05/2022, 19:05:34
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:05:34
# End time: 08/05/2022, 19:05:48
# Validation: 1
# Start time: 08/05/2022, 19:05:48
# End time: 08/05/2022, 19:05:48
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:05:48
# End time: 08/05/2022, 19:06:01
# Validation: 2
# Start time: 08/05/2022, 19:06:01
# End time: 08/05/2022, 19:06:01
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:06:01
# End time: 08/05/2022, 19:06:15
# Validation: 3
# Start time: 08/05/2022, 19:06:15
# End time: 08/05/2022, 19:06:15
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:06:15
# End time: 08/05/2022, 19:06:29
# Validation: 4
# Start time: 08/05/2022, 19:06:29
# End time: 08/05/2022, 19:06:29
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:06:29
# End time: 08/05/2022, 19:06:42
# Validation: 0
# Start time: 08/05/2022, 19:06:42
# End time: 08/05/2022, 19:06:42
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:06:42
# End time: 08/05/2022, 19:06:55
# Validation: 1
# Start time: 08/05/2022, 19:06:55
# End time: 08/05/2022, 19:06:55
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:06:56
# End time: 08/05/2022, 19:07:09
# Validation: 2
# Start time: 08/05/2022, 19:07:09
# End time: 08/05/2022, 19:07:09
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:07:09
# End time: 08/05/2022, 19:07:23
# Validation: 3
# Start time: 08/05/2022, 19:07:23
# End time: 08/05/2022, 19:07:23
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:07:23
# End time: 08/05/2022, 19:07:36
# Validation: 4
# Start time: 08/05/2022, 19:07:36
# End time: 08/05/2022, 19:07:36
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:07:37
# End time: 08/05/2022, 19:07:50
# Validation: 0
# Start time: 08/05/2022, 19:07:50
# End time: 08/05/2022, 19:07:50
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:07:50
# End time: 08/05/2022, 19:08:03
# Validation: 1
# Start time: 08/05/2022, 19:08:03
# End time: 08/05/2022, 19:08:03
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:08:03
# End time: 08/05/2022, 19:08:17
# Validation: 2
# Start time: 08/05/2022, 19:08:17
# End time: 08/05/2022, 19:08:17
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:08:17
# End time: 08/05/2022, 19:08:31
# Validation: 3
# Start time: 08/05/2022, 19:08:31
# End time: 08/05/2022, 19:08:31
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:08:31
# End time: 08/05/2022, 19:08:44
# Validation: 4
# Start time: 08/05/2022, 19:08:44
# End time: 08/05/2022, 19:08:44
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:08:45
# End time: 08/05/2022, 19:08:58
# Validation: 0
# Start time: 08/05/2022, 19:08:58
# End time: 08/05/2022, 19:08:58
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:08:58
# End time: 08/05/2022, 19:09:12
# Validation: 1
# Start time: 08/05/2022, 19:09:12
# End time: 08/05/2022, 19:09:12
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:09:12
# End time: 08/05/2022, 19:09:25
# Validation: 2
# Start time: 08/05/2022, 19:09:25
# End time: 08/05/2022, 19:09:25
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:09:25
# End time: 08/05/2022, 19:09:39
# Validation: 3
# Start time: 08/05/2022, 19:09:39
# End time: 08/05/2022, 19:09:39
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:09:39
# End time: 08/05/2022, 19:09:53
# Validation: 4
# Start time: 08/05/2022, 19:09:53
# End time: 08/05/2022, 19:09:53
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:09:53
# End time: 08/05/2022, 19:10:06
# Validation: 0
# Start time: 08/05/2022, 19:10:06
# End time: 08/05/2022, 19:10:07
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:10:07
# End time: 08/05/2022, 19:10:20
# Validation: 1
# Start time: 08/05/2022, 19:10:20
# End time: 08/05/2022, 19:10:20
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:10:20
# End time: 08/05/2022, 19:10:33
# Validation: 2
# Start time: 08/05/2022, 19:10:33
# End time: 08/05/2022, 19:10:33
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:10:33
# End time: 08/05/2022, 19:10:47
# Validation: 3
# Start time: 08/05/2022, 19:10:47
# End time: 08/05/2022, 19:10:47
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:10:47
# End time: 08/05/2022, 19:11:01
# Validation: 4
# Start time: 08/05/2022, 19:11:01
# End time: 08/05/2022, 19:11:01
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:11:01
# End time: 08/05/2022, 19:11:15
# Validation: 0
# Start time: 08/05/2022, 19:11:15
# End time: 08/05/2022, 19:11:15
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:11:15
# End time: 08/05/2022, 19:11:29
# Validation: 1
# Start time: 08/05/2022, 19:11:29
# End time: 08/05/2022, 19:11:29
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:11:29
# End time: 08/05/2022, 19:11:42
# Validation: 2
# Start time: 08/05/2022, 19:11:42
# End time: 08/05/2022, 19:11:42
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:11:42
# End time: 08/05/2022, 19:11:56
# Validation: 3
# Start time: 08/05/2022, 19:11:56
# End time: 08/05/2022, 19:11:56
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:11:56
# End time: 08/05/2022, 19:12:10
# Validation: 4
# Start time: 08/05/2022, 19:12:10
# End time: 08/05/2022, 19:12:10
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:12:10
# End time: 08/05/2022, 19:12:23
# Validation: 0
# Start time: 08/05/2022, 19:12:23
# End time: 08/05/2022, 19:12:23
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:12:23
# End time: 08/05/2022, 19:12:37
# Validation: 1
# Start time: 08/05/2022, 19:12:37
# End time: 08/05/2022, 19:12:37
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:12:37
# End time: 08/05/2022, 19:12:50
# Validation: 2
# Start time: 08/05/2022, 19:12:50
# End time: 08/05/2022, 19:12:50
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:12:50
# End time: 08/05/2022, 19:13:04
# Validation: 3
# Start time: 08/05/2022, 19:13:04
# End time: 08/05/2022, 19:13:04
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:13:04
# End time: 08/05/2022, 19:13:18
# Validation: 4
# Start time: 08/05/2022, 19:13:18
# End time: 08/05/2022, 19:13:18
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:13:18
# End time: 08/05/2022, 19:13:31
# Validation: 0
# Start time: 08/05/2022, 19:13:31
# End time: 08/05/2022, 19:13:31
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:13:31
# End time: 08/05/2022, 19:13:44
# Validation: 1
# Start time: 08/05/2022, 19:13:44
# End time: 08/05/2022, 19:13:44
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:13:44
# End time: 08/05/2022, 19:13:57
# Validation: 2
# Start time: 08/05/2022, 19:13:57
# End time: 08/05/2022, 19:13:58
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:13:58
# End time: 08/05/2022, 19:14:11
# Validation: 3
# Start time: 08/05/2022, 19:14:11
# End time: 08/05/2022, 19:14:11
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:14:11
# End time: 08/05/2022, 19:14:25
# Validation: 4
# Start time: 08/05/2022, 19:14:25
# End time: 08/05/2022, 19:14:25
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:14:25
# End time: 08/05/2022, 19:14:39
# Validation: 0
# Start time: 08/05/2022, 19:14:39
# End time: 08/05/2022, 19:14:39
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:14:39
# End time: 08/05/2022, 19:14:52
# Validation: 1
# Start time: 08/05/2022, 19:14:52
# End time: 08/05/2022, 19:14:52
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:14:53
# End time: 08/05/2022, 19:15:06
# Validation: 2
# Start time: 08/05/2022, 19:15:06
# End time: 08/05/2022, 19:15:06
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:15:06
# End time: 08/05/2022, 19:15:20
# Validation: 3
# Start time: 08/05/2022, 19:15:20
# End time: 08/05/2022, 19:15:20
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:15:21
# End time: 08/05/2022, 19:15:34
# Validation: 4
# Start time: 08/05/2022, 19:15:34
# End time: 08/05/2022, 19:15:34
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:15:34
# End time: 08/05/2022, 19:15:47
# Validation: 0
# Start time: 08/05/2022, 19:15:47
# End time: 08/05/2022, 19:15:48
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:15:48
# End time: 08/05/2022, 19:16:01
# Validation: 1
# Start time: 08/05/2022, 19:16:01
# End time: 08/05/2022, 19:16:01
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:16:01
# End time: 08/05/2022, 19:16:14
# Validation: 2
# Start time: 08/05/2022, 19:16:14
# End time: 08/05/2022, 19:16:14
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:16:14
# End time: 08/05/2022, 19:16:28
# Validation: 3
# Start time: 08/05/2022, 19:16:28
# End time: 08/05/2022, 19:16:28
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:16:28
# End time: 08/05/2022, 19:16:42
# Validation: 4
# Start time: 08/05/2022, 19:16:42
# End time: 08/05/2022, 19:16:42
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:16:42
# End time: 08/05/2022, 19:16:55
# Validation: 0
# Start time: 08/05/2022, 19:16:55
# End time: 08/05/2022, 19:16:55
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:16:55
# End time: 08/05/2022, 19:17:09
# Validation: 1
# Start time: 08/05/2022, 19:17:09
# End time: 08/05/2022, 19:17:09
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:17:09
# End time: 08/05/2022, 19:17:22
# Validation: 2
# Start time: 08/05/2022, 19:17:22
# End time: 08/05/2022, 19:17:22
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:17:22
# End time: 08/05/2022, 19:17:36
# Validation: 3
# Start time: 08/05/2022, 19:17:36
# End time: 08/05/2022, 19:17:36
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:17:36
# End time: 08/05/2022, 19:17:50
# Validation: 4
# Start time: 08/05/2022, 19:17:50
# End time: 08/05/2022, 19:17:50
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:17:50
# End time: 08/05/2022, 19:18:04
# Validation: 0
# Start time: 08/05/2022, 19:18:04
# End time: 08/05/2022, 19:18:04
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:18:04
# End time: 08/05/2022, 19:18:20
# Validation: 1
# Start time: 08/05/2022, 19:18:20
# End time: 08/05/2022, 19:18:20
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:18:20
# End time: 08/05/2022, 19:18:34
# Validation: 2
# Start time: 08/05/2022, 19:18:34
# End time: 08/05/2022, 19:18:35
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:18:35
# End time: 08/05/2022, 19:18:49
# Validation: 3
# Start time: 08/05/2022, 19:18:49
# End time: 08/05/2022, 19:18:49
# TRAIN: [    0     1     2 ... 37249 37250 37251] TEST: [37252 37253 37254 ... 46561 46562 46563]
# Training : 4
# Start time: 08/05/2022, 19:18:49
# End time: 08/05/2022, 19:19:03
# Validation: 4
# Start time: 08/05/2022, 19:19:03
# End time: 08/05/2022, 19:19:03
# TRAIN: [ 9313  9314  9315 ... 46561 46562 46563] TEST: [   0    1    2 ... 9310 9311 9312]
# Training : 0
# Start time: 08/05/2022, 19:19:03
# End time: 08/05/2022, 19:19:17
# Validation: 0
# Start time: 08/05/2022, 19:19:17
# End time: 08/05/2022, 19:19:17
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [ 9313  9314  9315 ... 18623 18624 18625]
# Training : 1
# Start time: 08/05/2022, 19:19:18
# End time: 08/05/2022, 19:19:31
# Validation: 1
# Start time: 08/05/2022, 19:19:31
# End time: 08/05/2022, 19:19:31
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [18626 18627 18628 ... 27936 27937 27938]
# Training : 2
# Start time: 08/05/2022, 19:19:31
# End time: 08/05/2022, 19:19:44
# Validation: 2
# Start time: 08/05/2022, 19:19:44
# End time: 08/05/2022, 19:19:44
# TRAIN: [    0     1     2 ... 46561 46562 46563] TEST: [27939 27940 27941 ... 37249 37250 37251]
# Training : 3
# Start time: 08/05/2022, 19:19:44
