# %%
import sys
print(sys.path)
# Out:
# ['D:\\Github\\Bitcoin-Transaction-Graph-Elliptic-Data-Set\\Data Preprocessing', 'D:\\Program Files\\Python39\\python39.zip', 'D:\\Program Files\\Python39\\DLLs', 'D:\\Program Files\\Python39\\lib', 'D:\\Program Files\\Python39', 'd:\\github\\bitcoin-transaction-graph-elliptic-data-set\\env', '', 'd:\\github\\bitcoin-transaction-graph-elliptic-data-set\\env\\lib\\site-packages', 'd:\\github\\bitcoin-transaction-graph-elliptic-data-set\\env\\lib\\site-packages\\win32', 'd:\\github\\bitcoin-transaction-graph-elliptic-data-set\\env\\lib\\site-packages\\win32\\lib', 'd:\\github\\bitcoin-transaction-graph-elliptic-data-set\\env\\lib\\site-packages\\Pythonwin']

# %%
# Environment path
main_path = "D:/Github/Bitcoin-Transaction-Graph-Elliptic-Data-Set/Data/Elliptic Data Set/elliptic_bitcoin_dataset"
csv_path = main_path + "/elliptic_txs_features.csv"

# %%
import pandas as pd
data = pd.read_csv(csv_path)
data.head()
# Out:
#    230425980  1  -0.1714692896288031  -0.18466755143291433  \
# 0    5530458  1            -0.171484             -0.184668
# 1  232022460  1            -0.172107             -0.184668
# 2  232438397  1             0.163054              1.963790
# 3  230460314  1             1.011523             -0.081127
# 4  230459870  1             0.961040             -0.081127
#
#    -1.2013688016765636  -0.12196959975910057  -0.04387454791734898  \
# 0            -1.201369             -0.121970             -0.043875
# 1            -1.201369             -0.121970             -0.043875
# 2            -0.646376             12.409294             -0.063725
# 3            -1.201369              1.153668              0.333276
# 4            -1.201369              1.303743              0.333276
#
#    -0.11300200928476244  -0.06158379407303222  -0.16209679981659642  ...  \
# 0             -0.113002             -0.061584             -0.162112  ...
# ...

# %%
chunk_size = 5000
def write_chunk(part, lines):
    with open(main_path + "/" + str(part) +'.csv', 'w') as f_out:
        f_out.write(header)
        f_out.writelines(lines)
with open(csv_path, "r") as f:
    count = 0
    header = f.readline()
    lines = []
    for line in f:
        count += 1
        lines.append(line)
        if count % chunk_size == 0:
            write_chunk(count // chunk_size, lines)
            lines = []
    # write remainder
    if len(lines) > 0:
        write_chunk((count // chunk_size) + 1, lines)
