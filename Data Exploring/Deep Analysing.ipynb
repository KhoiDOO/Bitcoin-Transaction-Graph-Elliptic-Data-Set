# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %%
main_data_dir = "D:/Github/Bitcoin-Transaction-Graph-Elliptic-Data-Set/Data/Elliptic Data Set/elliptic_bitcoin_dataset"
features_data_path = main_data_dir + "/elliptic_txs_features.csv"
class_data_path = main_data_dir + "/elliptic_txs_classes.csv"
egdelist_data_path = main_data_dir + "/elliptic_txs_edgelist.csv"

# %%
features_df = pd.read_csv(features_data_path)
classes_df = pd.read_csv(class_data_path)
edges_df = pd.read_csv(egdelist_data_path)

# %%
print('Shape of classes', classes_df.shape)
print('Shape of edges', edges_df.shape)
print('Shape of features', features_df.shape)
# Out:
# Shape of classes (203769, 2)
# Shape of edges (234355, 2)
# Shape of features (203769, 167)

# %%
features_df.corr()
# Out:
#                           txId  Time step  Local_feature_1  Local_feature_2  \
# txId                  1.000000  -0.238670        -0.013186        -0.096023
# Time step            -0.238670   1.000000        -0.026173         0.155124
# Local_feature_1      -0.013186  -0.026173         1.000000         0.022768
# Local_feature_2      -0.096023   0.155124         0.022768         1.000000
# Local_feature_3      -0.169648   0.573155        -0.051000         0.201354
# ...                        ...        ...              ...              ...
# Aggregate_feature_68 -0.057812   0.033076         0.067026         0.124242
# Aggregate_feature_69 -0.040098   0.064363         0.049349         0.039426
# Aggregate_feature_70 -0.029940   0.066486         0.016022         0.031678
# Aggregate_feature_71  0.015109  -0.035550        -0.004498        -0.008382
# Aggregate_feature_72  0.015833  -0.034651        -0.004607        -0.008042
#
#                       Local_feature_3  Local_feature_4  Local_feature_5  \
# txId                        -0.169648        -0.006038        -0.055143
# Time step                    0.573155        -0.001716         0.000802
# Local_feature_1             -0.051000         0.005998         0.029854
# Local_feature_2              0.201354         0.537526         0.151754
# Local_feature_3              1.000000         0.098263         0.032058
# ...                               ...              ...              ...
# Aggregate_feature_68         0.053472         0.023207         0.300775
# Aggregate_feature_69         0.062677         0.023738         0.040036
# Aggregate_feature_70         0.044375         0.030678         0.001550
# Aggregate_feature_71        -0.075097        -0.010297        -0.003557
# Aggregate_feature_72        -0.074849        -0.010511        -0.003770
#
#                       Local_feature_6  Local_feature_7  Local_feature_8  ...  \
# txId                        -0.006227        -0.003027        -0.010428  ...
# Time step                    0.003263        -0.015631        -0.026856  ...
# Local_feature_1              0.005604        -0.000375         0.977687  ...
# Local_feature_2              0.543661         0.102848         0.001016  ...
# Local_feature_3              0.100424         0.011711        -0.058288  ...
# ...                               ...              ...              ...  ...
# Aggregate_feature_68         0.016966         0.029386         0.020856  ...
# Aggregate_feature_69         0.018210         0.026762         0.005333  ...
# Aggregate_feature_70         0.028049         0.017301        -0.003712  ...
# Aggregate_feature_71        -0.010978        -0.000262        -0.004089  ...
# Aggregate_feature_72        -0.011281        -0.000002        -0.004307  ...
#
#                       Aggregate_feature_63  Aggregate_feature_64  \
# txId                             -0.095978             -0.090391
# Time step                        -0.015104              0.005773
# Local_feature_1                  -0.003407             -0.026918
# Local_feature_2                   0.019406              0.009287
# Local_feature_3                   0.064664              0.074712
# ...                                    ...                   ...
# Aggregate_feature_68              0.025519              0.019604
# Aggregate_feature_69              0.018767              0.011535
# Aggregate_feature_70             -0.015989             -0.006996
# Aggregate_feature_71              0.073394              0.046898
# Aggregate_feature_72              0.073382              0.047113
#
#                       Aggregate_feature_65  Aggregate_feature_66  \
# txId                             -0.049699             -0.049168
# Time step                         0.031137              0.031177
# Local_feature_1                   0.013384              0.013022
# Local_feature_2                   0.027470              0.027323
# Local_feature_3                   0.134380              0.134615
# ...                                    ...                   ...
# Aggregate_feature_68              0.015780              0.016117
# Aggregate_feature_69              0.017728              0.018403
# Aggregate_feature_70              0.019538              0.019859
# Aggregate_feature_71             -0.222746             -0.223925
# Aggregate_feature_72             -0.224267             -0.224898
#
#                       Aggregate_feature_67  Aggregate_feature_68  \
# txId                             -0.005442             -0.057812
# Time step                         0.014212              0.033076
# Local_feature_1                  -0.003097              0.067026
# Local_feature_2                   0.013291              0.124242
# Local_feature_3                  -0.007702              0.053472
# ...                                    ...                   ...
# Aggregate_feature_68              0.159304              1.000000
# Aggregate_feature_69             -0.003340              0.789525
# Aggregate_feature_70              0.733368              0.505704
# Aggregate_feature_71             -0.014021             -0.015389
# Aggregate_feature_72             -0.013925             -0.013127
#
#                       Aggregate_feature_69  Aggregate_feature_70  \
# txId                             -0.040098             -0.029940
# Time step                         0.064363              0.066486
# Local_feature_1                   0.049349              0.016022
# Local_feature_2                   0.039426              0.031678
# Local_feature_3                   0.062677              0.044375
# ...                                    ...                   ...
# Aggregate_feature_68              0.789525              0.505704
# Aggregate_feature_69              1.000000              0.619731
# Aggregate_feature_70              0.619731              1.000000
# Aggregate_feature_71             -0.021097             -0.027716
# Aggregate_feature_72             -0.018472             -0.026379
#
#                       Aggregate_feature_71  Aggregate_feature_72
# txId                              0.015109              0.015833
# Time step                        -0.035550             -0.034651
# Local_feature_1                  -0.004498             -0.004607
# Local_feature_2                  -0.008382             -0.008042
# Local_feature_3                  -0.075097             -0.074849
# ...                                    ...                   ...
# Aggregate_feature_68             -0.015389             -0.013127
# Aggregate_feature_69             -0.021097             -0.018472
# Aggregate_feature_70             -0.027716             -0.026379
# Aggregate_feature_71              1.000000              0.996221
# Aggregate_feature_72              0.996221              1.000000
#
# [167 rows x 167 columns]

# %%
sns.heatmap(features_df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,30))
sns.heatmap(features_df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(features_df.isnull())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,30))
sns.heatmap(features_df.corr().ge(0.7))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,30))
sns.heatmap(features_df.corr().ge(0.8))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,30))
sns.heatmap(features_df.corr().ge(1))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,30))
sns.heatmap(features_df.corr().ge(0.9))
# Out:
# <AxesSubplot:>
